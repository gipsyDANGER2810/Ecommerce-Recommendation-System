# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import LabelEncoder
from sqlalchemy import create_engine

# %%
df = pd.read_csv(r"C:/Users/swapn/Desktop/for evaluation/merged_data.csv")

# %%
# engine = create_engine('mysql+pymysql://root:sunny106133@localhost/project')

# # Fetch data into Pandas DataFrames
# products_df = pd.read_sql("SELECT * FROM products", con=engine)
# users_df = pd.read_sql("SELECT * FROM users", con=engine)
# reviews_df = pd.read_sql("SELECT * FROM product_reviews", con=engine)

# missing_users = set(reviews_df['user_id'].unique()) - set(users_df['user_id'].unique())
# missing_products = set(reviews_df['product_id'].unique()) - set(products_df['product_id'].unique())

# merged_1 = pd.merge(reviews_df, products_df, how='outer', on='product_id')


# merged_2 = pd.merge(merged_1, users_df, how='outer', on='user_id')
# merged_df = merged_2

# %%
# merged_df.fillna(value=np.nan, inplace=True)


# # Now merged_df contains your merged data
# df = merged_df
# mask_all_nan_except_credentials = df.drop(columns=['user_id', 'user_name', 'password']).isna().all(axis=1)

# # Create a mask for rows where rating and rating_count are NOT NaN.
# mask_valid_ratings = ~(df['rating'].isna() | df['rating_count'].isna())

# # Combine both conditions using OR (|)
# final_mask = mask_all_nan_except_credentials | mask_valid_ratings

# # Filter the dataframe using the combined mask
# df = df[final_mask]

# %%
df['discounted_price'] = df['discounted_price'].astype(str).str.replace('₹', '').str.replace(',', '').astype(float)
df['actual_price'] = df['actual_price'].astype(str).str.replace('₹', '').str.replace(',', '').astype(float)
df['discount_percentage'] = df['discount_percentage'].astype(str).str.replace('%','').astype(float)/100
df['rating'] = df['rating'].astype(str)
count = df['rating'].str.contains('\|').sum()

df = df[df['rating'].apply(lambda x: '|' not in str(x))]
count = df['rating'].str.contains('\|').sum()


df['rating'] = df['rating'].astype(str).str.replace(',', '').astype(float)
df['rating_count'] = df['rating_count'].astype(str).str.replace(',', '').astype(float)

# %%
le = LabelEncoder()
df['user_id_encoded'] = le.fit_transform(df['user_id'])

def userIdEncoder(userID):
    uuid = userID
    encoded_value = le.transform([uuid])[0]
    return encoded_value

# %%
# Calculate the mean rating across all products
C = df['rating'].mean()

# Calculate the 90th percentile of the number of ratings
m = df['rating_count'].quantile(0.9)

# Filter out movies that have a rating count less than m
qualified_products = df[df['rating_count'] >= m]

# Compute the weighted rating for each qualified product
def weighted_rating(x, m=m, C=C):
    v = x['rating_count']
    R = x['rating']
    return (v / (v + m) * R) + (m / (v + m) * C)

# Apply the function to the DataFrame
qualified_products['weighted_rating'] = qualified_products.apply(weighted_rating, axis=1)

# Sort products based on score
qualified_products = qualified_products.sort_values('weighted_rating', ascending=False)
# Out:
# C:\Users\swapn\AppData\Local\Temp\ipykernel_14148\837953868.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   qualified_products['weighted_rating'] = qualified_products.apply(weighted_rating, axis=1)

# %%
from sklearn.model_selection import LeavePOut

def leave_p_out_cv(df, p, user_column, item_column):
    lpo = LeavePOut(p)
    train_sets = []
    test_sets = []

    for user in df[user_column].unique():
        user_data = df[df[user_column] == user]
        
        # Ensure that the user has more than 'p' interactions
        if len(user_data) > p:
            for train_index, test_index in lpo.split(user_data):
                train = user_data.iloc[train_index]
                test = user_data.iloc[test_index]
                train_sets.append(train)
                test_sets.append(test)

    # Concatenate all the different train and test dataframes
    train_data = pd.concat(train_sets, ignore_index=True)
    test_data = pd.concat(test_sets, ignore_index=True)

    return train_data, test_data

# Example usage
p = 1
train, test = leave_p_out_cv(df, p, 'user_id', 'product_id')

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import pandas as pd
import numpy as np

def content_based_filtering(train):
    train['combined_text'] = train['about_product'].fillna('') + ' ' + train['review_title'].fillna('') + ' ' + train['review_content'].fillna('')
    index_mapping = {index: i for i, index in enumerate(train.index)}
    tfidf = TfidfVectorizer(stop_words='english')
    tfidf_matrix = tfidf.fit_transform(train['combined_text'])
    user_profiles = {}


    for user_id_encoded in train['user_id_encoded'].unique():
        user_data = train[train['user_id_encoded'] == user_id_encoded]
        tfidf_indices = [index_mapping[idx] for idx in user_data.index.tolist()]

        user_vector = np.sum(tfidf_matrix[tfidf_indices], axis=0)
        user_vector = np.asarray(user_vector).reshape(1, -1)

        if np.linalg.norm(user_vector) != 0:
            user_vector_norm = user_vector / np.linalg.norm(user_vector)
            user_profiles[user_id_encoded] = user_vector_norm
        else:
            print(f"Zero norm detected for user_id_encoded: {user_id_encoded}")
    

    def recommend_products_with_profiles(user_id_encoded):
        user_vector = user_profiles.get(user_id_encoded, None)
        if user_vector is None:
            return qualified_products

        cosine_sim_user = cosine_similarity(user_vector, tfidf_matrix)
    
        # Getting products already interacted with by the user
        interacted_products = train.loc[train['user_id_encoded'] == user_id_encoded]['product_id'].tolist()

        # Sorting the similarity scores
        similarity_scores = sorted(list(enumerate(cosine_sim_user[0])), key=lambda x: x[1], reverse=True)

        all_top_products = []
        for idx, score in similarity_scores:
            if len(all_top_products) == 5:  # break if we already have 5 recommendations
                break
            product_id = train.iloc[idx]['product_id']
            if product_id not in interacted_products and product_id not in [prod['product_id'] for prod in all_top_products]:
                all_top_products.append(train.iloc[idx])

        recommendation_response = []
        for product in all_top_products:
            model_response = {}
            model_response['product_id'] = product['product_id']
            model_response['product_name'] = product['product_name']
            model_response['img_link'] = product['img_link']
            model_response['actual_price'] = product['actual_price']
            model_response['discounted_price'] = product['discounted_price']
            model_response['discount_percentage'] = product['discount_percentage']
            recommendation_response.append(model_response)

        valid_scores = [score for idx, score in similarity_scores if train.iloc[idx]['product_id'] in [prod['product_id'] for prod in all_top_products]][:5]

        results_df = pd.DataFrame({
            'Id_Encoded': [user_id_encoded] * len(recommendation_response),
            'recommended_product': recommendation_response,
            'score_recommendation': valid_scores
        })
        
        return results_df
    return recommend_products_with_profiles, tfidf_matrix

recommender_function, tfidf_matrix_out = content_based_filtering(train)

# %%
def prerequisites_collaborative():
    # Filter users who've rated at least 1 product
    x = train.groupby('user_id_encoded').count()['rating'] > 1
    users_rated = x[x].index
    filtered_df = train[train['user_id_encoded'].isin(users_rated)]

    # Consider all products that have been rated at least once
    y = filtered_df.groupby('product_id').count()['rating'] > 1
    high_rated_products = y[y].index
    final_rating = filtered_df[filtered_df['product_id'].isin(high_rated_products)]

    # Create a user-item matrix
    pt = final_rating.pivot_table(index='user_id_encoded', columns='product_id', values='rating')

    pt.fillna(0, inplace=True)
    return pt


pt = prerequisites_collaborative()


# OGG
from sklearn.metrics.pairwise import cosine_similarity
similarity_score = cosine_similarity(pt)



def get_recommendations(user_id_encoded):
    """Return a list of recommended products for a given user."""
    if user_id_encoded not in pt.index:
        print(f"Error: user_id_encoded {user_id_encoded} not found in index.")
        return qualified_products[['product_name', 'rating', 'rating_count', 'weighted_rating']]

    # Find similar users
    index = pt.index.get_loc(user_id_encoded)
    similar_users = sorted(list(enumerate(similarity_score[index])), key=lambda x: x[1], reverse=True)[1:6]

    # Get the items that these users have interacted with
    recommended_products = {}
    for i in similar_users:
        user_id = pt.index[i[0]]
        rated_products = pt.columns[(pt.loc[user_id] > 0)].tolist()
        for product in rated_products:
            if product not in recommended_products:
                recommended_products[product] = i[1]
            else:
                recommended_products[product] += i[1]

    # Filter out products with a score of 0 and format the top products
    top_products = sorted([(product, score) for product, score in recommended_products.items() if score > 0], key=lambda x: x[1], reverse=True)[:5]

    # Extracting product details
    recommendation_response = []
    scores = []  # New list to keep track of the scores for products that weren't skipped
    for product_id, score in top_products:
        product_data = train[train['product_id'] == product_id]
        if product_data.empty:
            print(f"Warning: No data found for product_id: {product_id}")
            continue
        
        product = product_data.iloc[0]
        model_response = {}
        model_response['product_id'] = product['product_id']
        model_response['product_name'] = product['product_name']
        model_response['img_link'] = product['img_link']
        model_response['actual_price'] = product['actual_price']
        model_response['discounted_price'] = product['discounted_price']
        model_response['discount_percentage'] = product['discount_percentage']
        recommendation_response.append(model_response)
        scores.append(score)  # Add the score for this product

    # Now use the adjusted lists to construct the DataFrame
    results_df = pd.DataFrame({
        'Id_Encoded': [user_id_encoded] * len(recommendation_response),
        'recommended_product': recommendation_response,
        'score_recommendation': scores
    })
    return results_df

# %%
from sklearn.metrics import mean_squared_error
predicted_scores = []
actual_ratings = []

for user_id_encoded in test_data['user_id_encoded'].unique():
    user_data = test_data[test_data['user_id_encoded'] == user_id_encoded]
    recommendations_df = get_recommendations(user_id_encoded)
    
    if user_id_encoded not in pt.index or 'recommended_product' not in recommendations_df.columns:
        continue

    for idx, row in user_data.iterrows():
        product_name = row['product_name']
        predicted_score = recommendations_df[recommendations_df['recommended_product'].apply(lambda x: x['product_name']) == product_name]['score_recommendation'].values
        predicted_scores.append(predicted_score[0] if len(predicted_score) > 0 else 0)
        actual_ratings.append(row['rating'])

rmse = np.sqrt(mean_squared_error(actual_ratings, predicted_scores))
print("RMSE:", rmse)
# Out:
# Error: user_id_encoded 5292 not found in index.
# Error: user_id_encoded 1826 not found in index.
# Error: user_id_encoded 8331 not found in index.
# Error: user_id_encoded 8846 not found in index.
# Error: user_id_encoded 323 not found in index.
# Error: user_id_encoded 1645 not found in index.
# Error: user_id_encoded 4777 not found in index.
# Error: user_id_encoded 8264 not found in index.
# Error: user_id_encoded 4848 not found in index.
# Error: user_id_encoded 1838 not found in index.
# Error: user_id_encoded 5713 not found in index.
# Error: user_id_encoded 5414 not found in index.
# Error: user_id_encoded 3100 not found in index.
# Error: user_id_encoded 4207 not found in index.
# Error: user_id_encoded 4269 not found in index.
# Error: user_id_encoded 4879 not found in index.
# Error: user_id_encoded 7975 not found in index.
# Error: user_id_encoded 1750 not found in index.
# Error: user_id_encoded 4425 not found in index.
# Error: user_id_encoded 619 not found in index.
# Error: user_id_encoded 5838 not found in index.
# Error: user_id_encoded 966 not found in index.
# Error: user_id_encoded 2889 not found in index.
# Error: user_id_encoded 3004 not found in index.
# Error: user_id_encoded 7526 not found in index.
# Error: user_id_encoded 2382 not found in index.
# Error: user_id_encoded 2103 not found in index.
# Error: user_id_encoded 4309 not found in index.
# Error: user_id_encoded 108 not found in index.
# Error: user_id_encoded 4098 not found in index.
# Error: user_id_encoded 3420 not found in index.
# Error: user_id_encoded 6554 not found in index.
# Error: user_id_encoded 7209 not found in index.
# Error: user_id_encoded 6579 not found in index.
# Error: user_id_encoded 7368 not found in index.
# Error: user_id_encoded 7332 not found in index.
# Error: user_id_encoded 2578 not found in index.
# Error: user_id_encoded 57 not found in index.
# Error: user_id_encoded 7194 not found in index.
# Error: user_id_encoded 2455 not found in index.
# Error: user_id_encoded 9021 not found in index.
# Error: user_id_encoded 8852 not found in index.
# Error: user_id_encoded 2553 not found in index.
# Error: user_id_encoded 5453 not found in index.
# Error: user_id_encoded 824 not found in index.
# Error: user_id_encoded 8668 not found in index.
# Error: user_id_encoded 5762 not found in index.
# Error: user_id_encoded 3538 not found in index.
# Error: user_id_encoded 4265 not found in index.
# Error: user_id_encoded 8324 not found in index.
# Error: user_id_encoded 4474 not found in index.
# Error: user_id_encoded 7029 not found in index.
# Error: user_id_encoded 8821 not found in index.
# Error: user_id_encoded 100 not found in index.
# Error: user_id_encoded 1371 not found in index.
# Error: user_id_encoded 2819 not found in index.
# Error: user_id_encoded 4896 not found in index.
# Error: user_id_encoded 1777 not found in index.
# Error: user_id_encoded 3041 not found in index.
# Error: user_id_encoded 7657 not found in index.
# Error: user_id_encoded 8301 not found in index.
# Error: user_id_encoded 3726 not found in index.
# Error: user_id_encoded 8081 not found in index.
# Error: user_id_encoded 7943 not found in index.
# Error: user_id_encoded 3505 not found in index.
# Error: user_id_encoded 5882 not found in index.
# Error: user_id_encoded 5177 not found in index.
# Error: user_id_encoded 4259 not found in index.
# Error: user_id_encoded 2129 not found in index.
# Error: user_id_encoded 4940 not found in index.
# Error: user_id_encoded 7579 not found in index.
# Error: user_id_encoded 3506 not found in index.
# Error: user_id_encoded 5759 not found in index.
# Error: user_id_encoded 3818 not found in index.
# Error: user_id_encoded 3618 not found in index.
# Error: user_id_encoded 6678 not found in index.
# Error: user_id_encoded 4537 not found in index.
# Error: user_id_encoded 8951 not found in index.
# Error: user_id_encoded 2576 not found in index.
# Error: user_id_encoded 438 not found in index.
# Error: user_id_encoded 1018 not found in index.
# Error: user_id_encoded 6528 not found in index.
# Error: user_id_encoded 3929 not found in index.
# Error: user_id_encoded 2025 not found in index.
# Error: user_id_encoded 5409 not found in index.
# Error: user_id_encoded 6079 not found in index.
# RMSE: 3.6954167507571047

# %%
true_positives = 0
false_positives = 0
false_negatives = 0

for user_id_encoded in test_data['user_id_encoded'].unique():
    user_data = test_data[test_data['user_id_encoded'] == user_id_encoded]
    actual_products = set(user_data['product_name'])
    
    recommendations_df = get_recommendations(user_id_encoded)
    
    # Check if the user was found and if 'recommended_product' exists in the DataFrame
    if user_id_encoded not in pt.index or 'recommended_product' not in recommendations_df.columns:
        continue
    
    recommended_products = set([item['product_name'] for item in recommendations_df['recommended_product']])

    true_positives += len(recommended_products.intersection(actual_products))
    false_positives += len(recommended_products - actual_products)
    false_negatives += len(actual_products - recommended_products)

precision = true_positives / (true_positives + false_positives) if (true_positives + false_positives) != 0 else 0
recall = true_positives / (true_positives + false_negatives) if (true_positives + false_negatives) != 0 else 0

print("Precision:", precision)
print("Recall:", recall)
# Out:
# Error: user_id_encoded 5292 not found in index.
# Error: user_id_encoded 1826 not found in index.
# Error: user_id_encoded 8331 not found in index.
# Error: user_id_encoded 8846 not found in index.
# Error: user_id_encoded 323 not found in index.
# Error: user_id_encoded 1645 not found in index.
# Error: user_id_encoded 4777 not found in index.
# Error: user_id_encoded 8264 not found in index.
# Error: user_id_encoded 4848 not found in index.
# Error: user_id_encoded 1838 not found in index.
# Error: user_id_encoded 5713 not found in index.
# Error: user_id_encoded 5414 not found in index.
# Error: user_id_encoded 3100 not found in index.
# Error: user_id_encoded 4207 not found in index.
# Error: user_id_encoded 4269 not found in index.
# Error: user_id_encoded 4879 not found in index.
# Error: user_id_encoded 7975 not found in index.
# Error: user_id_encoded 1750 not found in index.
# Error: user_id_encoded 4425 not found in index.
# Error: user_id_encoded 619 not found in index.
# Error: user_id_encoded 5838 not found in index.
# Error: user_id_encoded 966 not found in index.
# Error: user_id_encoded 2889 not found in index.
# Error: user_id_encoded 3004 not found in index.
# Error: user_id_encoded 7526 not found in index.
# Error: user_id_encoded 2382 not found in index.
# Error: user_id_encoded 2103 not found in index.
# Error: user_id_encoded 4309 not found in index.
# Error: user_id_encoded 108 not found in index.
# Error: user_id_encoded 4098 not found in index.
# Error: user_id_encoded 3420 not found in index.
# Error: user_id_encoded 6554 not found in index.
# Error: user_id_encoded 7209 not found in index.
# Error: user_id_encoded 6579 not found in index.
# Error: user_id_encoded 7368 not found in index.
# Error: user_id_encoded 7332 not found in index.
# Error: user_id_encoded 2578 not found in index.
# Error: user_id_encoded 57 not found in index.
# Error: user_id_encoded 7194 not found in index.
# Error: user_id_encoded 2455 not found in index.
# Error: user_id_encoded 9021 not found in index.
# Error: user_id_encoded 8852 not found in index.
# Error: user_id_encoded 2553 not found in index.
# Error: user_id_encoded 5453 not found in index.
# Error: user_id_encoded 824 not found in index.
# Error: user_id_encoded 8668 not found in index.
# Error: user_id_encoded 5762 not found in index.
# Error: user_id_encoded 3538 not found in index.
# Error: user_id_encoded 4265 not found in index.
# Error: user_id_encoded 8324 not found in index.
# Error: user_id_encoded 4474 not found in index.
# Error: user_id_encoded 7029 not found in index.
# Error: user_id_encoded 8821 not found in index.
# Error: user_id_encoded 100 not found in index.
# Error: user_id_encoded 1371 not found in index.
# Error: user_id_encoded 2819 not found in index.
# Error: user_id_encoded 4896 not found in index.
# Error: user_id_encoded 1777 not found in index.
# Error: user_id_encoded 3041 not found in index.
# Error: user_id_encoded 7657 not found in index.
# Error: user_id_encoded 8301 not found in index.
# Error: user_id_encoded 3726 not found in index.
# Error: user_id_encoded 8081 not found in index.
# Error: user_id_encoded 7943 not found in index.
# Error: user_id_encoded 3505 not found in index.
# Error: user_id_encoded 5882 not found in index.
# Error: user_id_encoded 5177 not found in index.
# Error: user_id_encoded 4259 not found in index.
# Error: user_id_encoded 2129 not found in index.
# Error: user_id_encoded 4940 not found in index.
# Error: user_id_encoded 7579 not found in index.
# Error: user_id_encoded 3506 not found in index.
# Error: user_id_encoded 5759 not found in index.
# Error: user_id_encoded 3818 not found in index.
# Error: user_id_encoded 3618 not found in index.
# Error: user_id_encoded 6678 not found in index.
# Error: user_id_encoded 4537 not found in index.
# Error: user_id_encoded 8951 not found in index.
# Error: user_id_encoded 2576 not found in index.
# Error: user_id_encoded 438 not found in index.
# Error: user_id_encoded 1018 not found in index.
# Error: user_id_encoded 6528 not found in index.
# Error: user_id_encoded 3929 not found in index.
# Error: user_id_encoded 2025 not found in index.
# Error: user_id_encoded 5409 not found in index.
# Error: user_id_encoded 6079 not found in index.
# Precision: 0.5464684014869888
# Recall: 0.592741935483871

# %%
def hybrid_recommendation_v2(user_id_encoded, alpha=0.5, N=50):
    # Get top N recommendations from both systems
    content_based_recommendations = recommender_function(user_id_encoded)[:N]
    collaborative_recommendations = get_recommendations(user_id_encoded)[:N]
    
    # Normalize scores for collaborative recommendations using Min-Max scaling
    max_collab_score = collaborative_recommendations['score_recommendation'].max()
    collaborative_recommendations['normalized_score'] = collaborative_recommendations['score_recommendation'] / max_collab_score

    # Create a dictionary for both content and collab recommendations for O(1) access
    content_dict = {row['recommended_product']['product_id']: row['score_recommendation'] for _, row in content_based_recommendations.iterrows()}
    collab_dict = {row['recommended_product']['product_id']: row['normalized_score'] for _, row in collaborative_recommendations.iterrows()}

    # Combine both recommendation lists
    combined_recommendations = list(set(content_dict.keys()) | set(collab_dict.keys()))

    # Compute combined score for each product in combined_recommendations
    combined_scores = {}
    for product_id in combined_recommendations:
        content_score = content_dict.get(product_id, 0)
        collab_score = collab_dict.get(product_id, 0)
        combined_scores[product_id] = alpha * content_score + (1 - alpha) * collab_score

    # Sort products based on combined scores
    sorted_recommendations = sorted(combined_scores.items(), key=lambda x: x[1], reverse=True)[:5]

    # Extract product details for the top 5 sorted recommendations
    final_recommendations = []
    final_scores = []
    for product_id, score in sorted_recommendations:
        product_data = train[train['product_id'] == product_id].iloc[0]
        model_response = {}
        model_response['product_id'] = product_data['product_id']
        model_response['product_name'] = product_data['product_name']
        model_response['img_link'] = product_data['img_link']
        model_response['actual_price'] = product_data['actual_price']
        model_response['discounted_price'] = product_data['discounted_price']
        model_response['discount_percentage'] = product_data['discount_percentage']
        final_recommendations.append(model_response)
        final_scores.append(score)

    return pd.DataFrame({'Product': final_recommendations, 'Score': final_scores})

# %%
true_positives = 0
false_positives = 0
false_negatives = 0
actual_scores = []  # to store the actual scores (ratings)
predicted_scores = []  # to store the predicted scores

for user_id_encoded in test['user_id_encoded'].unique():
    
    # Check if user_id_encoded exists in the matrix
    if user_id_encoded not in pt.index:
        continue

    user_data = test[test['user_id_encoded'] == user_id_encoded]
    
    actual_products = set(user_data['product_name'])
    
    if len(user_data) > 0:
        print(f"User {user_id_encoded} has {len(user_data)} interactions in the test_data.")
    else:
        print(f"User {user_id_encoded} has no interactions in the test_data.")
    # Get hybrid recommendations
    recommendations_df = hybrid_recommendation_v2(user_id_encoded)
    print(recommendations_df.head())

    


    recommended_products = set([item['product_name'] for item in recommendations_df['Product']])
    
    true_positives += len(recommended_products.intersection(actual_products))
    false_positives += len(recommended_products - actual_products)
    false_negatives += len(actual_products - recommended_products)
    
    # Assuming you have a column that denotes the actual rating/score given by the user
    for _, interaction in user_data.iterrows():
        actual_product_name = interaction['product_name']

        recommended_product_ids = [item['product_id'] for item in recommendations_df['Product']]
        
        # Check if the actual product id is in the recommended product ids
        if actual_product_name not in [item['product_name'] for item in recommendations_df['Product']]:
            print(f"Product name {actual_product_name} not found in recommendations.")
            continue

        predicted_score = recommendations_df[recommendations_df['Product'].apply(lambda x: x['product_name'] == actual_product_name)]['Score'].values[0]

        # Assuming 'score_interaction' column exists in test_data
        actual_score = interaction['rating']

        actual_scores.append(actual_score)
        predicted_scores.append(predicted_score)

print(f"Length of actual scores: {len(actual_scores)}")
print(f"Length of predicted scores: {len(predicted_scores)}")


precision = true_positives / (true_positives + false_positives) if (true_positives + false_positives) != 0 else 0
recall = true_positives / (true_positives + false_negatives) if (true_positives + false_negatives) != 0 else 0

rmse = np.sqrt(mean_squared_error(actual_scores, predicted_scores))

print("Precision for Hybrid System:", precision)
print("Recall for Hybrid System:", recall)
print("RMSE for Hybrid System:", rmse)
# Out:
# User 4901 has 2 interactions in the test_data.
#                                              Product     Score
# 0  {'product_id': 'B098K3H92Z', 'product_name': '...  0.500000
# 1  {'product_id': 'B07L9FW9GF', 'product_name': '...  0.455664
# 2  {'product_id': 'B01LONQBDG', 'product_name': '...  0.182929
# 3  {'product_id': 'B07G3YNLJB', 'product_name': '...  0.182929
# 4  {'product_id': 'B086Q3QMFS', 'product_name': '...  0.160714
# User 5475 has 2 interactions in the test_data.
#                                              Product     Score
# 0  {'product_id': 'B098K3H92Z', 'product_name': '...  0.500000
# 1  {'product_id': 'B07L9FW9GF', 'product_name': '...  0.279648
# 2  {'product_id': 'B01LONQBDG', 'product_name': '...  0.220352
# 3  {'product_id': 'B07G3YNLJB', 'product_name': '...  0.220352
# 4  {'product_id': 'B01J0XWYKQ', 'product_name': '...  0.171201
# Product name Logitech M221 Wireless Mouse, Silent Buttons, 2.4 GHz with USB Mini Receiver, 1000 DPI Optical Tracking, 18-Month Battery Life, Ambidextrous PC / Mac / Laptop - Charcoal Grey not found in recommendations.
# User 6963 has 3 interactions in the test_data.
#                                              Product     Score
# 0  {'product_id': 'B098K3H92Z', 'product_name': '...  0.500000
# 1  {'product_id': 'B07G3YNLJB', 'product_name': '...  0.225776
# 2  {'product_id': 'B09NVPSCQT', 'product_name': '...  0.225776
# 3  {'product_id': 'B01GGKZ0V6', 'product_name': '...  0.222477
# 4  {'product_id': 'B07L9FW9GF', 'product_name': '...  0.211348
# Product name AmazonBasics USB Type-C to Micro-B 2.0 Cable - 6 Inches (15.2 Centimeters) - White not found in recommendations.
# User 2128 has 3 interactions in the test_data.
#                                              Product     Score
# 0  {'product_id': 'B07VZH6ZBB', 'product_name': '...  0.500000
# 1  {'product_id': 'B0B3X2BY3M', 'product_name': '...  0.500000
# 2  {'product_id': 'B08YRMBK9R', 'product_name': '...  0.159986
# 3  {'product_id': 'B097MKZHNV', 'product_name': '...  0.152228
# 4  {'product_id': 'B00HZIOGXW', 'product_name': '...  0.142680
# Product name iBELL Castor CTEK15L Premium 1.5 Litre Stainless Steel Electric Kettle,1500W Auto Cut-Off Feature,Silver not found in recommendations.
# User 6116 has 2 interactions in the test_data.
#                                              Product     Score
# 0  {'product_id': 'B0B3X2BY3M', 'product_name': '...  0.639598
# 1  {'product_id': 'B07VZH6ZBB', 'product_name': '...  0.500000
# 2  {'product_id': 'B08C7TYHPB', 'product_name': '...  0.500000
# 3  {'product_id': 'B00HZIOGXW', 'product_name': '...  0.139598
# 4  {'product_id': 'B097MKZHNV', 'product_name': '...  0.137645
# Product name INDIAS®™ Electro-Instant Water Geyser A.B.S. Body Shock Proof Can be Used in Bathroom, Kitchen, wash Area, Hotels, Hospital etc. not found in recommendations.
# User 3898 has 2 interactions in the test_data.
#                                              Product     Score
# 0  {'product_id': 'B01486F4G6', 'product_name': '...  0.500000
# 1  {'product_id': 'B0BBWJFK5C', 'product_name': '...  0.183084
# 2  {'product_id': 'B097MKZHNV', 'product_name': '...  0.061202
# 3  {'product_id': 'B0B5RP43VN', 'product_name': '...  0.060516
# 4  {'product_id': 'B07S851WX5', 'product_name': '...  0.056481
# Product name AGARO Supreme High Pressure Washer, 1800 Watts, 120 Bars, 6.5L/Min Flow Rate, 8 Meters Outlet Hose, Portable, for Car,Bike and Home Cleaning Purpose, Black and Orange not found in recommendations.
# User 3187 has 2 interactions in the test_data.
#                                              Product     Score
# 0  {'product_id': 'B01486F4G6', 'product_name': '...  0.500000
# 1  {'product_id': 'B0B61DSF17', 'product_name': '...  0.184271
# 2  {'product_id': 'B0B694PXQJ', 'product_name': '...  0.169723
# 3  {'product_id': 'B07VQGVL68', 'product_name': '...  0.137211
# 4  {'product_id': 'B07Q4NJQC5', 'product_name': '...  0.109418
# Product name Themisto TH-WS20 Digital Kitchen Weighing Scale Stainless Steel (5Kg) not found in recommendations.
# User 1102 has 2 interactions in the test_data.
#                                              Product     Score
# 0  {'product_id': 'B08ZJDWTJ1', 'product_name': '...  0.687799
# 1  {'product_id': 'B0765B3TH7', 'product_name': '...  0.500000
# 2  {'product_id': 'B00NNQMYNE', 'product_name': '...  0.168688
# 3  {'product_id': 'B07VTFN6HM', 'product_name': '...  0.126834
# 4  {'product_id': 'B0BG62HMDJ', 'product_name': '...  0.126834
# Product name Seagate One Touch 2TB External HDD with Password Protection – Black, for Windows and Mac, with 3 yr Data Recovery Services, and 4 Months Adobe CC Photography (STKY2000400) not found in recommendations.
# User 1374 has 2 interactions in the test_data.
#                                              Product     Score
# 0  {'product_id': 'B0765B3TH7', 'product_name': '...  0.500000
# 1  {'product_id': 'B0B9RZ4G4W', 'product_name': '...  0.373705
# 2  {'product_id': 'B08ZJDWTJ1', 'product_name': '...  0.373705
# 3  {'product_id': 'B094QZLJQ6', 'product_name': '...  0.180754
# 4  {'product_id': 'B07VTFN6HM', 'product_name': '...  0.121645
# User 7344 has 2 interactions in the test_data.
#                                              Product     Score
# 0  {'product_id': 'B07YL54NVJ', 'product_name': '...  0.500000
# 1  {'product_id': 'B09VKWGZD7', 'product_name': '...  0.180361
# 2  {'product_id': 'B097C564GC', 'product_name': '...  0.112980
# 3  {'product_id': 'B081FG1QYX', 'product_name': '...  0.112350
# 4  {'product_id': 'B01LONQBDG', 'product_name': '...  0.098814
# Product name Shakti Technology S3 High Pressure Car Washer Machine 1800 Watts and Pressure 120 Bar for Cleaning Car, Bike & Home not found in recommendations.
# User 4268 has 2 interactions in the test_data.
#                                              Product     Score
# 0  {'product_id': 'B07232M876', 'product_name': '...  0.500000
# 1  {'product_id': 'B08D9NDZ1Y', 'product_name': '...  0.293497
# 2  {'product_id': 'B00NH11PEY', 'product_name': '...  0.293497
# 3  {'product_id': 'B00NH11KIK', 'product_name': '...  0.261051
# 4  {'product_id': 'B09YLXYP7Y', 'product_name': '...  0.185496
# User 6611 has 2 interactions in the test_data.
#                                              Product     Score
# 0  {'product_id': 'B07232M876', 'product_name': '...  0.567250
# 1  {'product_id': 'B08D9NDZ1Y', 'product_name': '...  0.500000
# 2  {'product_id': 'B00NH11PEY', 'product_name': '...  0.469964
# 3  {'product_id': 'B00NH11KIK', 'product_name': '...  0.208990
# 4  {'product_id': 'B01EJ5MM5M', 'product_name': '...  0.144045
# User 7854 has 2 interactions in the test_data.
#                                              Product     Score
# 0  {'product_id': 'B07TCN5VR9', 'product_name': '...  0.500000
# 1  {'product_id': 'B098NS6PVG', 'product_name': '...  0.500000
# 2  {'product_id': 'B07PFJ5VQD', 'product_name': '...  0.500000
# 3  {'product_id': 'B0B4DT8MKT', 'product_name': '...  0.130382
# 4  {'product_id': 'B09YLXYP7Y', 'product_name': '...  0.123472
# Product name STRIFF Laptop Stand Adjustable Laptop Computer Stand Multi-Angle Stand Phone Stand Portable Foldable Laptop Riser Notebook Holder Stand Compatible for 9 to 15.6” Laptops Black(Black) not found in recommendations.
# User 4326 has 2 interactions in the test_data.
#                                              Product     Score
# 0  {'product_id': 'B08GYG6T12', 'product_name': '...  0.500000
# 1  {'product_id': 'B07JF9B592', 'product_name': '...  0.155770
# 2  {'product_id': 'B00RFWNJMC', 'product_name': '...  0.108941
# 3  {'product_id': 'B09X7DY7Q4', 'product_name': '...  0.091062
# 4  {'product_id': 'B07YFWVRCM', 'product_name': '...  0.090219
# Product name HUMBLE Dynamic Lapel Collar Mic Voice Recording Filter Microphone for Singing Youtube SmartPhones, Black not found in recommendations.
# User 7993 has 2 interactions in the test_data.
#                                              Product     Score
# 0  {'product_id': 'B09RF2QXGX', 'product_name': '...  0.500000
# 1  {'product_id': 'B0B2DJ5RVQ', 'product_name': '...  0.068407
# 2  {'product_id': 'B0BCVJ3PVP', 'product_name': '...  0.067132
# 3  {'product_id': 'B09JPC82QC', 'product_name': '...  0.067132
# 4  {'product_id': 'B09CYTJV3N', 'product_name': '...  0.066338
# Product name Caprigo Heavy Duty TV Wall Mount Stand for 12 to 27 inches LED/LCD/Monitor Screen's, Full Motion Rotatable Universal TV & Monitor Wall Mount Bracket with Swivel & Tilt Adjustments (Single Arm - M416) not found in recommendations.
# User 1326 has 2 interactions in the test_data.
#                                              Product     Score
# 0  {'product_id': 'B09RF2QXGX', 'product_name': '...  0.500000
# 1  {'product_id': 'B08FTFXNNB', 'product_name': '...  0.107648
# 2  {'product_id': 'B07YFWVRCM', 'product_name': '...  0.081869
# 3  {'product_id': 'B00MUTWLW4', 'product_name': '...  0.073350
# 4  {'product_id': 'B08HD7JQHX', 'product_name': '...  0.066441
# Product name Logitech C270 Digital HD Webcam with Widescreen HD Video Calling, HD Light Correction, Noise-Reducing Mic, for Skype, FaceTime, Hangouts, WebEx, PC/Mac/Laptop/MacBook/Tablet - (Black, HD 720p/30fps) not found in recommendations.
# User 8616 has 2 interactions in the test_data.
#                                              Product     Score
# 0  {'product_id': 'B08WJ86PV2', 'product_name': '...  0.500000
# 1  {'product_id': 'B0BCVJ3PVP', 'product_name': '...  0.241395
# 2  {'product_id': 'B0819HZPXL', 'product_name': '...  0.208456
# 3  {'product_id': 'B09MZ6WZ6V', 'product_name': '...  0.188166
# 4  {'product_id': 'B0926V9CTV', 'product_name': '...  0.159150
# Product name Dyazo 6 Angles Adjustable Aluminum Ergonomic Foldable Portable Tabletop Laptop/Desktop Riser Stand Holder Compatible for MacBook, HP, Dell, Lenovo & All Other Notebook (Silver) not found in recommendations.
# User 424 has 2 interactions in the test_data.
#                                              Product     Score
# 0  {'product_id': 'B07R99NBVB', 'product_name': '...  0.500000
# 1  {'product_id': 'B0148NPH9I', 'product_name': '...  0.500000
# 2  {'product_id': 'B00MUTWLW4', 'product_name': '...  0.239900
# 3  {'product_id': 'B087FXHB6J', 'product_name': '...  0.156052
# 4  {'product_id': 'B00CEQEGPI', 'product_name': '...  0.148762
# Product name Logitech Pebble M350 Wireless Mouse with Bluetooth or USB - Silent, Slim Computer Mouse with Quiet Click for Laptop, Notebook, PC and Mac - Graphite not found in recommendations.
# User 3694 has 2 interactions in the test_data.
#                                              Product     Score
# 0  {'product_id': 'B01M4GGIVU', 'product_name': '...  0.500000
# 1  {'product_id': 'B09HCH3JZG', 'product_name': '...  0.376292
# 2  {'product_id': 'B00LZLQ624', 'product_name': '...  0.248514
# 3  {'product_id': 'B06XR9PR5X', 'product_name': '...  0.234796
# 4  {'product_id': 'B07RZZ1QSW', 'product_name': '...  0.151223
# Product name WeCool B1 Mobile Holder for Bikes or Bike Mobile Holder for Maps and GPS Navigation, one Click Locking, Firm Gripping, Anti Shake and Stable Cradle Clamp with 360° Rotation Bicycle Phone Mount not found in recommendations.
# User 6603 has 3 interactions in the test_data.
#                                              Product     Score
# 0  {'product_id': 'B0B4DT8MKT', 'product_name': '...  0.500000
# 1  {'product_id': 'B0993BB11X', 'product_name': '...  0.500000
# 2  {'product_id': 'B094JNXNPV', 'product_name': '...  0.136518
# 3  {'product_id': 'B098NS6PVG', 'product_name': '...  0.130279
# 4  {'product_id': 'B085DTN6R2', 'product_name': '...  0.130279
# Product name CARDEX Digital Kitchen Weighing Machine Multipurpose Electronic Weight Scale With Back Lite LCD Display for Measuring Food, Cake, Vegetable, Fruit (KITCHEN SCALE) not found in recommendations.
# Product name AirCase Rugged Hard Drive Case for 2.5-inch Western Digital, Seagate, Toshiba, Portable Storage Shell for Gadget Hard Disk USB Cable Power Bank Mobile Charger Earphone, Waterproof (Black) not found in recommendations.
# User 5460 has 2 interactions in the test_data.
#                                              Product     Score
# 0  {'product_id': 'B0993BB11X', 'product_name': '...  0.500000
# 1  {'product_id': 'B085DTN6R2', 'product_name': '...  0.289039
# 2  {'product_id': 'B07RD611Z8', 'product_name': '...  0.289039
# 3  {'product_id': 'B098NS6PVG', 'product_name': '...  0.282974
# 4  {'product_id': 'B09CMP1SC8', 'product_name': '...  0.211801
# Product name Wecool Unbreakable 3 in 1 Charging Cable with 3A Speed, Fast Charging Multi Purpose Cable 1.25 Mtr Long, Type C cable, Micro Usb Cable and Cable for iPhone, White not found in recommendations.
# User 6341 has 2 interactions in the test_data.
#                                              Product     Score
# 0  {'product_id': 'B08MTLLSL8', 'product_name': '...  0.500000
# 1  {'product_id': 'B078W65FJ7', 'product_name': '...  0.500000
# 2  {'product_id': 'B07KY3FNQP', 'product_name': '...  0.107340
# 3  {'product_id': 'B07CD2BN46', 'product_name': '...  0.106864
# 4  {'product_id': 'B07S9S86BF', 'product_name': '...  0.106471
# User 3098 has 2 interactions in the test_data.
#                                              Product     Score
# 0  {'product_id': 'B08MTLLSL8', 'product_name': '...  0.500000
# 1  {'product_id': 'B078W65FJ7', 'product_name': '...  0.500000
# 2  {'product_id': 'B00Y4ORQ46', 'product_name': '...  0.114225
# 3  {'product_id': 'B07CD2BN46', 'product_name': '...  0.105558
# 4  {'product_id': 'B07TCN5VR9', 'product_name': '...  0.105558
# Product name HP w100 480P 30 FPS Digital Webcam with Built-in Mic, Plug and Play Setup, Wide-Angle View for Video Calling on Skype, Zoom, Microsoft Teams and Other Apps (Black) not found in recommendations.
# User 8518 has 2 interactions in the test_data.
#                                              Product     Score
# 0  {'product_id': 'B00LUGTJGO', 'product_name': '...  0.500000
# 1  {'product_id': 'B009P2LK08', 'product_name': '...  0.210237
# 2  {'product_id': 'B00P0R95EA', 'product_name': '...  0.130360
# 3  {'product_id': 'B097R4D42G', 'product_name': '...  0.123292
# 4  {'product_id': 'B07LG96SDB', 'product_name': '...  0.116897
# Product name Bajaj Splendora 3 Litre 3KW IWH Instant Water Heater (Geyser), White not found in recommendations.
# User 5616 has 2 interactions in the test_data.
#                                              Product     Score
# 0  {'product_id': 'B09SGGRKV8', 'product_name': '...  0.500000
# 1  {'product_id': 'B00H47GVGY', 'product_name': '...  0.114689
# 2  {'product_id': 'B07CD2BN46', 'product_name': '...  0.102352
# 3  {'product_id': 'B07TXCY3YK', 'product_name': '...  0.102352
# 4  {'product_id': 'B0B9F9PT8R', 'product_name': '...  0.102015
# Product name Lifelong LLFH921 Regalia 2000 W Fan Heater, 3 Air Settings, Room Heater with Overheating Protection, 1 Year Warranty ( White, (ISI Certified, Ideal for small to medium room/area) not found in recommendations.
# User 4448 has 2 interactions in the test_data.
#                                              Product     Score
# 0  {'product_id': 'B09SGGRKV8', 'product_name': '...  0.500000
# 1  {'product_id': 'B07CD2BN46', 'product_name': '...  0.153974
# 2  {'product_id': 'B07TCN5VR9', 'product_name': '...  0.153063
# 3  {'product_id': 'B00Y4ORQ46', 'product_name': '...  0.119604
# 4  {'product_id': 'B078W65FJ7', 'product_name': '...  0.119604
# Product name boAt Bassheads 152 in Ear Wired Earphones with Mic(Active Black) not found in recommendations.
# User 3370 has 2 interactions in the test_data.
#                                              Product     Score
# 0  {'product_id': 'B097C564GC', 'product_name': '...  0.500000
# 1  {'product_id': 'B01LONQBDG', 'product_name': '...  0.218660
# 2  {'product_id': 'B01GGKZ0V6', 'product_name': '...  0.218660
# 3  {'product_id': 'B07924P3C5', 'product_name': '...  0.208706
# 4  {'product_id': 'B08Y1TFSP6', 'product_name': '...  0.171483
# Product name Portronics MPORT 31C 4-in-1 USB Hub (Type C to 4 USB-A Ports) with Fast Data Transfer not found in recommendations.
# User 2840 has 2 interactions in the test_data.
#                                              Product     Score
# 0  {'product_id': 'B097C564GC', 'product_name': '...  0.500000
# 1  {'product_id': 'B07DC4RZPY', 'product_name': '...  0.194500
# 2  {'product_id': 'B07GVGTSLN', 'product_name': '...  0.185314
# 3  {'product_id': 'B081FG1QYX', 'product_name': '...  0.147958
# 4  {'product_id': 'B01LONQBDG', 'product_name': '...  0.145589
# Product name Wayona Nylon Braided USB to Lightning Fast Charging and Data Sync Cable Compatible for iPhone 13, 12,11, X, 8, 7, 6, 5, iPad Air, Pro, Mini (3 FT Pack of 1, Grey) not found in recommendations.
# User 4267 has 3 interactions in the test_data.
#                                              Product     Score
# 0  {'product_id': 'B00LZLQ624', 'product_name': '...  0.280844
# 1  {'product_id': 'B00P93X0VO', 'product_name': '...  0.271542
# 2  {'product_id': 'B00LZLPYHW', 'product_name': '...  0.255010
# 3  {'product_id': 'B086Q3QMFS', 'product_name': '...  0.254031
# 4  {'product_id': 'B08MTCKDYN', 'product_name': '...  0.190324
# Product name 3M Post-it Sticky Note Cube, 200 Sheets (4 Colors x 50 Sheets) | 3" x 3" Size | For notes, reminders, study, school and organizing not found in recommendations.
# Product name Classmate Soft Cover 6 Subject Spiral Binding Notebook, Unruled, 300 Pages not found in recommendations.
# Product name STRIFF 12 Pieces Highly Flexible Silicone Micro USB Protector, Mouse Cable Protector, Suit for All Cell Phones, Computers and Chargers (White) not found in recommendations.
# User 2268 has 2 interactions in the test_data.
#                                              Product     Score
# 0  {'product_id': 'B09YLXYP7Y', 'product_name': '...  0.500000
# 1  {'product_id': 'B07CD2BN46', 'product_name': '...  0.231212
# 2  {'product_id': 'B0949SBKMP', 'product_name': '...  0.231212
# 3  {'product_id': 'B07GLNJC25', 'product_name': '...  0.184858
# 4  {'product_id': 'B09ZPL5VYM', 'product_name': '...  0.184858
# User 8384 has 2 interactions in the test_data.
#                                              Product     Score
# 0  {'product_id': 'B0949SBKMP', 'product_name': '...  0.500000
# 1  {'product_id': 'B07CD2BN46', 'product_name': '...  0.366838
# 2  {'product_id': 'B09YLXYP7Y', 'product_name': '...  0.366838
# 3  {'product_id': 'B0BNXFDTZ2', 'product_name': '...  0.124486
# 4  {'product_id': 'B09NVPSCQT', 'product_name': '...  0.117005
# User 6925 has 2 interactions in the test_data.
#                                              Product     Score
# 0  {'product_id': 'B08WJ86PV2', 'product_name': '...  0.500000
# 1  {'product_id': 'B0819HZPXL', 'product_name': '...  0.244444
# 2  {'product_id': 'B09MZ6WZ6V', 'product_name': '...  0.220552
# 3  {'product_id': 'B087FXHB6J', 'product_name': '...  0.178776
# 4  {'product_id': 'B073BRXPZX', 'product_name': '...  0.165029
# User 8202 has 2 interactions in the test_data.
#                                              Product     Score
# 0  {'product_id': 'B08WJ86PV2', 'product_name': '...  0.500000
# 1  {'product_id': 'B09MZ6WZ6V', 'product_name': '...  0.228738
# 2  {'product_id': 'B0819HZPXL', 'product_name': '...  0.208456
# 3  {'product_id': 'B01J1CFO5I', 'product_name': '...  0.116838
# 4  {'product_id': 'B087FXHB6J', 'product_name': '...  0.114705
# Product name Lapster Gel Mouse pad with Wrist Rest , Gaming Mouse Pad with Lycra Cloth Nonslip for Laptop , Computer, , Home & Office (Black) not found in recommendations.
# User 1681 has 2 interactions in the test_data.
#                                              Product     Score
# 0  {'product_id': 'B01M4GGIVU', 'product_name': '...  0.636000
# 1  {'product_id': 'B09HCH3JZG', 'product_name': '...  0.500000
# 2  {'product_id': 'B07VSG5SXZ', 'product_name': '...  0.160516
# 3  {'product_id': 'B06XR9PR5X', 'product_name': '...  0.145530
# 4  {'product_id': 'B08TGG316Z', 'product_name': '...  0.139519
# Product name Cablet 2.5 Inch SATA USB 3.0 HDD/SSD Portable External Enclosure for 7mm and 9.5mm, Tool-Free Design, Supports UASP Max 6TB not found in recommendations.
# User 5858 has 2 interactions in the test_data.
#                                              Product     Score
# 0  {'product_id': 'B08GYG6T12', 'product_name': '...  0.500000
# 1  {'product_id': 'B09HCH3JZG', 'product_name': '...  0.138945
# 2  {'product_id': 'B07VSG5SXZ', 'product_name': '...  0.138755
# 3  {'product_id': 'B01M4GGIVU', 'product_name': '...  0.132096
# 4  {'product_id': 'B09X7DY7Q4', 'product_name': '...  0.118890
# Product name 10k 8k 4k HDMI Cable, Certified 48Gbps 1ms Ultra High Speed HDMI 2.1 Cable 4k 120Hz 144Hz 2k 165Hz 8k 60Hz Dynamic HDR ARC eARC DTS:X Compatible for Mac Gaming PC Soundbar TV Monitor Laptop PS5 4 Xbox not found in recommendations.
# User 7374 has 2 interactions in the test_data.
#                                              Product     Score
# 0  {'product_id': 'B07DC4RZPY', 'product_name': '...  0.500000
# 1  {'product_id': 'B075DB1F13', 'product_name': '...  0.500000
# 2  {'product_id': 'B00N3XLDW0', 'product_name': '...  0.142002
# 3  {'product_id': 'B0993BB11X', 'product_name': '...  0.087241
# 4  {'product_id': 'B00BN5SNF0', 'product_name': '...  0.084175
# User 5855 has 2 interactions in the test_data.
#                                              Product     Score
# 0  {'product_id': 'B075DB1F13', 'product_name': '...  0.500000
# 1  {'product_id': 'B07DC4RZPY', 'product_name': '...  0.321512
# 2  {'product_id': 'B086394NY5', 'product_name': '...  0.321512
# 3  {'product_id': 'B07JW9H4J1', 'product_name': '...  0.152848
# 4  {'product_id': 'B08CF3B7N1', 'product_name': '...  0.128178
# User 4632 has 2 interactions in the test_data.
#                                              Product     Score
# 0  {'product_id': 'B086394NY5', 'product_name': '...  0.500000
# 1  {'product_id': 'B017PDR9N0', 'product_name': '...  0.467434
# 2  {'product_id': 'B0926V9CTV', 'product_name': '...  0.284664
# 3  {'product_id': 'B07DC4RZPY', 'product_name': '...  0.209933
# 4  {'product_id': 'B08LHTJTBB', 'product_name': '...  0.096442
# User 3108 has 2 interactions in the test_data.
#                                              Product     Score
# 0  {'product_id': 'B086394NY5', 'product_name': '...  0.500000
# 1  {'product_id': 'B07DC4RZPY', 'product_name': '...  0.250000
# 2  {'product_id': 'B017PDR9N0', 'product_name': '...  0.250000
# 3  {'product_id': 'B0B61DSF17', 'product_name': '...  0.215427
# 4  {'product_id': 'B09W9V2PXG', 'product_name': '...  0.120899
# Product name Glun Multipurpose Portable Electronic Digital Weighing Scale Weight Machine (10 Kg - with Back Light) not found in recommendations.
# User 4909 has 2 interactions in the test_data.
#                                              Product     Score
# 0  {'product_id': 'B086394NY5', 'product_name': '...  0.500000
# 1  {'product_id': 'B017PDR9N0', 'product_name': '...  0.209933
# 2  {'product_id': 'B075DB1F13', 'product_name': '...  0.188549
# 3  {'product_id': 'B07DC4RZPY', 'product_name': '...  0.188549
# 4  {'product_id': 'B07JW9H4J1', 'product_name': '...  0.136152
# User 7119 has 2 interactions in the test_data.
#                                              Product     Score
# 0  {'product_id': 'B00NH11PEY', 'product_name': '...  0.500000
# 1  {'product_id': 'B08D9NDZ1Y', 'product_name': '...  0.500000
# 2  {'product_id': 'B0148NPH9I', 'product_name': '...  0.219771
# 3  {'product_id': 'B01EJ5MM5M', 'product_name': '...  0.207924
# 4  {'product_id': 'B00CEQEGPI', 'product_name': '...  0.155367
# Product name Logitech K480 Wireless Multi-Device Keyboard for Windows, macOS, iPadOS, Android or Chrome OS, Bluetooth, Compact, Compatible with PC, Mac, Laptop, Smartphone, Tablet - Black not found in recommendations.
# User 2213 has 2 interactions in the test_data.
#                                              Product     Score
# 0  {'product_id': 'B00GZLB57U', 'product_name': '...  0.500000
# 1  {'product_id': 'B014SZO90Y', 'product_name': '...  0.500000
# 2  {'product_id': 'B01HJI0FS2', 'product_name': '...  0.500000
# 3  {'product_id': 'B003B00484', 'product_name': '...  0.134478
# 4  {'product_id': 'B08Y57TPDM', 'product_name': '...  0.085461
# Product name Duracell Ultra Alkaline AAA Battery, 8 Pcs not found in recommendations.
# User 5820 has 3 interactions in the test_data.
#                                              Product     Score
# 0  {'product_id': 'B01HJI0FS2', 'product_name': '...  0.500000
# 1  {'product_id': 'B01DJJVFPC', 'product_name': '...  0.256091
# 2  {'product_id': 'B014SZO90Y', 'product_name': '...  0.250000
# 3  {'product_id': 'B00GZLB57U', 'product_name': '...  0.191302
# 4  {'product_id': 'B08YDFX7Y1', 'product_name': '...  0.191302
# User 2665 has 5 interactions in the test_data.
#                                              Product     Score
# 0  {'product_id': 'B07232M876', 'product_name': '...  0.500000
# 1  {'product_id': 'B07VTFN6HM', 'product_name': '...  0.311362
# 2  {'product_id': 'B008YW8M0G', 'product_name': '...  0.217678
# 3  {'product_id': 'B01N6LU1VF', 'product_name': '...  0.217678
# 4  {'product_id': 'B00NH11PEY', 'product_name': '...  0.202791
# Product name Philips GC1905 1440-Watt Steam Iron with Spray (Blue) not found in recommendations.
# Product name Sennheiser CX 80S in-Ear Wired Headphones with in-line One-Button Smart Remote with Microphone Black not found in recommendations.
# User 5064 has 3 interactions in the test_data.
#                                              Product    Score
# 0  {'product_id': 'B07RD611Z8', 'product_name': '...  0.50000
# 1  {'product_id': 'B08TDJNM3G', 'product_name': '...  0.50000
# 2  {'product_id': 'B01N6LU1VF', 'product_name': '...  0.32266
# 3  {'product_id': 'B07232M876', 'product_name': '...  0.32266
# 4  {'product_id': 'B008QTK47Q', 'product_name': '...  0.32266
# Product name Philips PowerPro FC9352/01 Compact Bagless Vacuum Cleaner (Blue) not found in recommendations.
# User 6998 has 2 interactions in the test_data.
#                                              Product     Score
# 0  {'product_id': 'B0B21C4BMX', 'product_name': '...  0.500000
# 1  {'product_id': 'B085DTN6R2', 'product_name': '...  0.259618
# 2  {'product_id': 'B08CF3B7N1', 'product_name': '...  0.216603
# 3  {'product_id': 'B0B4DT8MKT', 'product_name': '...  0.173722
# 4  {'product_id': 'B098NS6PVG', 'product_name': '...  0.173722
# Product name Portronics Konnect L POR-1403 Fast Charging 3A Type-C Cable 1.2 Meter with Charge & Sync Function for All Type-C Devices (White) not found in recommendations.
# User 6469 has 2 interactions in the test_data.
#                                              Product     Score
# 0  {'product_id': 'B0B21C4BMX', 'product_name': '...  0.500000
# 1  {'product_id': 'B0B2DJ5RVQ', 'product_name': '...  0.113265
# 2  {'product_id': 'B07RZZ1QSW', 'product_name': '...  0.074915
# 3  {'product_id': 'B0926V9CTV', 'product_name': '...  0.074510
# 4  {'product_id': 'B0B9BXKBC7', 'product_name': '...  0.063991
# Product name Portronics CLAMP X Car-Vent Mobile Holder 360 Degree Rotational(Black) not found in recommendations.
# User 4759 has 2 interactions in the test_data.
#                                              Product     Score
# 0  {'product_id': 'B07L1N3TJX', 'product_name': '...  0.500000
# 1  {'product_id': 'B0BCVJ3PVP', 'product_name': '...  0.061396
# 2  {'product_id': 'B07DC4RZPY', 'product_name': '...  0.057575
# 3  {'product_id': 'B0B2CPVXHX', 'product_name': '...  0.054083
# 4  {'product_id': 'B00F159RIK', 'product_name': '...  0.053600
# Product name Panasonic SR-WA22H (E) Automatic Rice Cooker, Apple Green, 2.2 Liters not found in recommendations.
# User 7221 has 2 interactions in the test_data.
#                                              Product     Score
# 0  {'product_id': 'B07L1N3TJX', 'product_name': '...  0.500000
# 1  {'product_id': 'B00GGGOYEK', 'product_name': '...  0.088298
# 2  {'product_id': 'B097C564GC', 'product_name': '...  0.069042
# 3  {'product_id': 'B07DC4RZPY', 'product_name': '...  0.068912
# 4  {'product_id': 'B07LFWP97N', 'product_name': '...  0.064141
# Product name Zebronics ZEB-90HB USB Hub, 4 Ports, Pocket Sized, Plug & Play, for Laptop & Computers not found in recommendations.
# User 2953 has 3 interactions in the test_data.
#                                              Product     Score
# 0  {'product_id': 'B09GYBZPHF', 'product_name': '...  0.128779
# 1  {'product_id': 'B01M0505SJ', 'product_name': '...  0.128282
# 2  {'product_id': 'B095PWLLY6', 'product_name': '...  0.120639
# 3  {'product_id': 'B08KDBLMQP', 'product_name': '...  0.119158
# 4  {'product_id': 'B08CFJBZRK', 'product_name': '...  0.107539
# Product name Butterfly Hero Mixer Grinder, 500W, 3 Jars (Grey) not found in recommendations.
# Product name Havells Ambrose 1200mm Ceiling Fan (Gold Mist Wood) not found in recommendations.
# Product name Havells Ventil Air DSP 230mm Exhaust Fan (Pista Green) not found in recommendations.
# User 4833 has 2 interactions in the test_data.
#                                              Product     Score
# 0  {'product_id': 'B01M4GGIVU', 'product_name': '...  0.500000
# 1  {'product_id': 'B09HCH3JZG', 'product_name': '...  0.311362
# 2  {'product_id': 'B06XR9PR5X', 'product_name': '...  0.292207
# 3  {'product_id': 'B00GG59HU2', 'product_name': '...  0.209671
# 4  {'product_id': 'B07VSG5SXZ', 'product_name': '...  0.209215
# User 910 has 2 interactions in the test_data.
#                                              Product     Score
# 0  {'product_id': 'B09YLXYP7Y', 'product_name': '...  0.500000
# 1  {'product_id': 'B09ZPL5VYM', 'product_name': '...  0.500000
# 2  {'product_id': 'B07GLNJC25', 'product_name': '...  0.500000
# 3  {'product_id': 'B07N8RQ6W7', 'product_name': '...  0.259003
# 4  {'product_id': 'B098NS6PVG', 'product_name': '...  0.259003
# Product name Ambrane Unbreakable 3A Fast Charging Braided Type C Cable    1.5 Meter (RCT15, Blue) Supports QC 2.0/3.0 Charging not found in recommendations.
# User 2844 has 2 interactions in the test_data.
#                                              Product     Score
# 0  {'product_id': 'B07Z53L5QL', 'product_name': '...  0.500000
# 1  {'product_id': 'B08MTCKDYN', 'product_name': '...  0.340175
# 2  {'product_id': 'B09Z6WH2N1', 'product_name': '...  0.196168
# 3  {'product_id': 'B08CF3B7N1', 'product_name': '...  0.196168
# 4  {'product_id': 'B08KRMK9LZ', 'product_name': '...  0.113537
# Product name LAPSTER 12pcs Spiral Cable Protectors for Charger, Wires, Data Charger Cable Protector for Computers, Cell Phones etc.(Grey) not found in recommendations.
# User 814 has 2 interactions in the test_data.
#                                              Product     Score
# 0  {'product_id': 'B083T5G5PM', 'product_name': '...  0.500000
# 1  {'product_id': 'B09JPC82QC', 'product_name': '...  0.500000
# 2  {'product_id': 'B076B8G5D8', 'product_name': '...  0.500000
# 3  {'product_id': 'B09F9YQQ7B', 'product_name': '...  0.325223
# 4  {'product_id': 'B08CS3BT4L', 'product_name': '...  0.249346
# Product name Croma 80 cm (32 Inches) HD Ready LED TV (CREL7369, Black) (2021 Model) not found in recommendations.
# User 4630 has 3 interactions in the test_data.
#                                              Product     Score
# 0  {'product_id': 'B09YLXYP7Y', 'product_name': '...  0.500000
# 1  {'product_id': 'B09ZPL5VYM', 'product_name': '...  0.301768
# 2  {'product_id': 'B07CD2BN46', 'product_name': '...  0.205592
# 3  {'product_id': 'B08Y1TFSP6', 'product_name': '...  0.136499
# 4  {'product_id': 'B098NS6PVG', 'product_name': '...  0.129156
# Product name ZEBRONICS Zeb-100HB 4 Ports USB Hub for Laptop, PC Computers, Plug & Play, Backward Compatible - Black not found in recommendations.
# User 1486 has 2 interactions in the test_data.
#                                              Product     Score
# 0  {'product_id': 'B08YDFX7Y1', 'product_name': '...  0.500000
# 1  {'product_id': 'B00GZLB57U', 'product_name': '...  0.357469
# 2  {'product_id': 'B014SZO90Y', 'product_name': '...  0.357469
# 3  {'product_id': 'B01HJI0FS2', 'product_name': '...  0.357469
# 4  {'product_id': 'B087FXHB6J', 'product_name': '...  0.177121
# User 1306 has 2 interactions in the test_data.
#                                              Product     Score
# 0  {'product_id': 'B0993BB11X', 'product_name': '...  0.743471
# 1  {'product_id': 'B08TDJNM3G', 'product_name': '...  0.500000
# 2  {'product_id': 'B072J83V9W', 'product_name': '...  0.434368
# 3  {'product_id': 'B008QTK47Q', 'product_name': '...  0.434368
# 4  {'product_id': 'B07RD611Z8', 'product_name': '...  0.434368
# User 8914 has 2 interactions in the test_data.
#                                              Product     Score
# 0  {'product_id': 'B0993BB11X', 'product_name': '...  0.500000
# 1  {'product_id': 'B07RD611Z8', 'product_name': '...  0.416234
# 2  {'product_id': 'B085DTN6R2', 'product_name': '...  0.225136
# 3  {'product_id': 'B09TP5KBN7', 'product_name': '...  0.216014
# 4  {'product_id': 'B0B4DT8MKT', 'product_name': '...  0.204082
# Product name E-COSMOS 5V 1.2W Portable Flexible USB LED Light (Colors May Vary, Small) - Set of 2 Pieces not found in recommendations.
# User 2253 has 2 interactions in the test_data.
#                                              Product     Score
# 0  {'product_id': 'B07232M876', 'product_name': '...  0.500000
# 1  {'product_id': 'B00NH11PEY', 'product_name': '...  0.303764
# 2  {'product_id': 'B00GE55L22', 'product_name': '...  0.227765
# 3  {'product_id': 'B07VTFN6HM', 'product_name': '...  0.196236
# 4  {'product_id': 'B008QTK47Q', 'product_name': '...  0.196236
# Product name Storite High Speed Micro USB 3.0 Cable A to Micro B for External & Desktop Hard Drives 45cm not found in recommendations.
# User 7794 has 2 interactions in the test_data.
#                                              Product     Score
# 0  {'product_id': 'B017PDR9N0', 'product_name': '...  0.500000
# 1  {'product_id': 'B0926V9CTV', 'product_name': '...  0.310276
# 2  {'product_id': 'B086394NY5', 'product_name': '...  0.204155
# 3  {'product_id': 'B08LHTJTBB', 'product_name': '...  0.197267
# 4  {'product_id': 'B0BCVJ3PVP', 'product_name': '...  0.134767
# User 6730 has 2 interactions in the test_data.
#                                              Product     Score
# 0  {'product_id': 'B017PDR9N0', 'product_name': '...  0.500000
# 1  {'product_id': 'B0926V9CTV', 'product_name': '...  0.250000
# 2  {'product_id': 'B086394NY5', 'product_name': '...  0.250000
# 3  {'product_id': 'B08LHTJTBB', 'product_name': '...  0.102913
# 4  {'product_id': 'B07Q4QV1DL', 'product_name': '...  0.091610
# Product name Robustrion Anti-Scratch & Smudge Proof Tempered Glass Screen Protector for Xiaomi Mi Pad 5 11 inch not found in recommendations.
# User 8046 has 3 interactions in the test_data.
#                                              Product     Score
# 0  {'product_id': 'B0811VCGL5', 'product_name': '...  0.500000
# 1  {'product_id': 'B09KRHXTLN', 'product_name': '...  0.073745
# 2  {'product_id': 'B008LN8KDM', 'product_name': '...  0.072635
# 3  {'product_id': 'B097MKZHNV', 'product_name': '...  0.072438
# 4  {'product_id': 'B09NFSHCWN', 'product_name': '...  0.069271
# Product name BlueRigger Digital Optical Audio Toslink Cable (3.3 Feet / 1 Meter) With 8 Channel (7.1) Audio Support (for Home Theatre, Xbox, Playstation etc.) not found in recommendations.
# Product name Havells OFR 13 Wave Fin with PTC Fan Heater 2900 Watts (Black) not found in recommendations.
# User 608 has 3 interactions in the test_data.
#                                              Product     Score
# 0  {'product_id': 'B07PFJ5VQD', 'product_name': '...  0.500000
# 1  {'product_id': 'B0BFWGBX61', 'product_name': '...  0.237548
# 2  {'product_id': 'B0B4DT8MKT', 'product_name': '...  0.182611
# 3  {'product_id': 'B09YLXYP7Y', 'product_name': '...  0.175684
# 4  {'product_id': 'B094JNXNPV', 'product_name': '...  0.175684
# Product name Ambrane Unbreakable 60W / 3A Fast Charging 1.5m Braided Type C Cable for Smartphones, Tablets, Laptops & other Type C devices, PD Technology, 480Mbps Data Sync, Quick Charge 3.0 (RCT15A, Black) not found in recommendations.
# Product name Boult Audio BassBuds X1 in-Ear Wired Earphones with 10mm Extra Bass Driver and HD Sound with mic(Black) not found in recommendations.
# User 7155 has 2 interactions in the test_data.
#                                              Product     Score
# 0  {'product_id': 'B08MTLLSL8', 'product_name': '...  0.500000
# 1  {'product_id': 'B078W65FJ7', 'product_name': '...  0.500000
# 2  {'product_id': 'B08CFJBZRK', 'product_name': '...  0.077140
# 3  {'product_id': 'B07Y9PY6Y1', 'product_name': '...  0.069931
# 4  {'product_id': 'B07TXCY3YK', 'product_name': '...  0.069931
# Product name Bajaj Rex 750W Mixer Grinder with Nutri Pro Feature, 4 Jars, White not found in recommendations.
# User 7304 has 2 interactions in the test_data.
#                                              Product     Score
# 0  {'product_id': 'B07L9FW9GF', 'product_name': '...  0.500000
# 1  {'product_id': 'B098K3H92Z', 'product_name': '...  0.277777
# 2  {'product_id': 'B086Q3QMFS', 'product_name': '...  0.222223
# 3  {'product_id': 'B08CTQP51L', 'product_name': '...  0.222223
# 4  {'product_id': 'B087FXHB6J', 'product_name': '...  0.110555
# Product name Duracell Plus AAA Rechargeable Batteries (750 mAh) Pack of 4 not found in recommendations.
# User 6040 has 3 interactions in the test_data.
#                                              Product     Score
# 0  {'product_id': 'B07L9FW9GF', 'product_name': '...  0.500000
# 1  {'product_id': 'B098K3H92Z', 'product_name': '...  0.202576
# 2  {'product_id': 'B00P93X6EK', 'product_name': '...  0.181890
# 3  {'product_id': 'B00LZLQ624', 'product_name': '...  0.181890
# 4  {'product_id': 'B00P93X0VO', 'product_name': '...  0.176866
# Product name Robustrion [Anti-Scratch] & [Smudge Proof] [S Pen Compatible] Premium Tempered Glass Screen Protector for Samsung Tab S6 Lite 10.4 inch SM-P610/615 [Bubble Free] not found in recommendations.
# Product name Classmate Drawing Book - Unruled, 40 Pages, 210 mm x 297 mm - Pack Of 4 not found in recommendations.
# User 226 has 2 interactions in the test_data.
#                                              Product     Score
# 0  {'product_id': 'B087FXHB6J', 'product_name': '...  0.500000
# 1  {'product_id': 'B09NHVCHS9', 'product_name': '...  0.500000
# 2  {'product_id': 'B09PNR6F8Q', 'product_name': '...  0.113509
# 3  {'product_id': 'B01LONQBDG', 'product_name': '...  0.113509
# 4  {'product_id': 'B09ZPL5VYM', 'product_name': '...  0.107519
# Product name Portronics MODESK POR-122 Universal Mobile Tabletop Holder (Black) not found in recommendations.
# User 164 has 2 interactions in the test_data.
#                                              Product     Score
# 0  {'product_id': 'B07R99NBVB', 'product_name': '...  0.500000
# 1  {'product_id': 'B0148NPH9I', 'product_name': '...  0.500000
# 2  {'product_id': 'B00MUTWLW4', 'product_name': '...  0.214418
# 3  {'product_id': 'B00CEQEGPI', 'product_name': '...  0.118612
# 4  {'product_id': 'B087FXHB6J', 'product_name': '...  0.100642
# User 4108 has 2 interactions in the test_data.
#                                              Product     Score
# 0  {'product_id': 'B08WJ86PV2', 'product_name': '...  0.625301
# 1  {'product_id': 'B0819HZPXL', 'product_name': '...  0.500000
# 2  {'product_id': 'B087FXHB6J', 'product_name': '...  0.168310
# 3  {'product_id': 'B08YDFX7Y1', 'product_name': '...  0.162476
# 4  {'product_id': 'B073BRXPZX', 'product_name': '...  0.134624
# Product name Redragon K617 Fizz 60% Wired RGB Gaming Keyboard, 61 Keys Compact Mechanical Keyboard w/White and Grey Color Keycaps, Linear Red Switch, Pro Driver/Software Supported not found in recommendations.
# User 2544 has 2 interactions in the test_data.
#                                              Product     Score
# 0  {'product_id': 'B0B2RBP83P', 'product_name': '...  0.500000
# 1  {'product_id': 'B09XB8GFBQ', 'product_name': '...  0.248119
# 2  {'product_id': 'B09QS8V5N8', 'product_name': '...  0.242724
# 3  {'product_id': 'B08VB34KJ1', 'product_name': '...  0.203189
# 4  {'product_id': 'B09LHYZ3GJ', 'product_name': '...  0.163793
# Product name Redmi 11 Prime 5G (Meadow Green, 4GB RAM 64GB ROM) | Prime Design | MTK Dimensity 700 | 50 MP Dual Cam | 5000mAh | 7 Band 5G not found in recommendations.
# User 5913 has 2 interactions in the test_data.
#                                              Product     Score
# 0  {'product_id': 'B07WKBD37W', 'product_name': '...  0.500000
# 1  {'product_id': 'B00LZLQ624', 'product_name': '...  0.371336
# 2  {'product_id': 'B0819ZZK5K', 'product_name': '...  0.371336
# 3  {'product_id': 'B084PJSSQ1', 'product_name': '...  0.323979
# 4  {'product_id': 'B097C564GC', 'product_name': '...  0.307922
# User 1293 has 2 interactions in the test_data.
#                                              Product     Score
# 0  {'product_id': 'B07WKBD37W', 'product_name': '...  0.500000
# 1  {'product_id': 'B0819ZZK5K', 'product_name': '...  0.500000
# 2  {'product_id': 'B08KDBLMQP', 'product_name': '...  0.107947
# 3  {'product_id': 'B08CFJBZRK', 'product_name': '...  0.102874
# 4  {'product_id': 'B07TXCY3YK', 'product_name': '...  0.102874
# Product name Lifelong LLMG93 500 Watt Duos Mixer Grinder, 2 Stainless Steel Jar (Liquidizing and Chutney Jar)| ABS Body, Stainless Steel Blades, 3 Speed Options with Whip (1 Year Warranty, Black) not found in recommendations.
# User 863 has 2 interactions in the test_data.
#                                              Product     Score
# 0  {'product_id': 'B07R99NBVB', 'product_name': '...  0.500000
# 1  {'product_id': 'B0148NPH9I', 'product_name': '...  0.500000
# 2  {'product_id': 'B09Z6WH2N1', 'product_name': '...  0.060412
# 3  {'product_id': 'B09CGLY5CX', 'product_name': '...  0.060412
# 4  {'product_id': 'B08MTCKDYN', 'product_name': '...  0.053478
# Product name ELV Car Mount Adjustable Car Phone Holder Universal Long Arm, Windshield for Smartphones - Black not found in recommendations.
# User 4493 has 2 interactions in the test_data.
#                                              Product     Score
# 0  {'product_id': 'B0926V9CTV', 'product_name': '...  0.500000
# 1  {'product_id': 'B017PDR9N0', 'product_name': '...  0.500000
# 2  {'product_id': 'B08LHTJTBB', 'product_name': '...  0.123886
# 3  {'product_id': 'B0BCVJ3PVP', 'product_name': '...  0.091882
# 4  {'product_id': 'B0B2DJ5RVQ', 'product_name': '...  0.091553
# Product name Larrito wooden Cool Mist Humidifiers Essential Oil Diffuser Aroma Air Humidifier with Colorful Change for Car, Office, Babies, humidifiers for home, air humidifier for room (WOODEN HUMIDIFIRE-A) not found in recommendations.
# User 7343 has 2 interactions in the test_data.
#                                              Product     Score
# 0  {'product_id': 'B08H21B6V7', 'product_name': '...  0.500000
# 1  {'product_id': 'B0B9RZ4G4W', 'product_name': '...  0.086728
# 2  {'product_id': 'B07TXCY3YK', 'product_name': '...  0.086728
# 3  {'product_id': 'B08KDBLMQP', 'product_name': '...  0.082518
# 4  {'product_id': 'B09QS8V5N8', 'product_name': '...  0.082412
# Product name TTK Prestige Limited Orion Mixer Grinder 500 Watts, 3 Jars (1200ml, 1000ml, 500ml) (Red) not found in recommendations.
# User 5075 has 2 interactions in the test_data.
#                                              Product     Score
# 0  {'product_id': 'B0B9RZ4G4W', 'product_name': '...  0.500000
# 1  {'product_id': 'B0765B3TH7', 'product_name': '...  0.397748
# 2  {'product_id': 'B08ZJDWTJ1', 'product_name': '...  0.397748
# 3  {'product_id': 'B094QZLJQ6', 'product_name': '...  0.152770
# 4  {'product_id': 'B07VTFN6HM', 'product_name': '...  0.096507
# User 3837 has 2 interactions in the test_data.
#                                              Product     Score
# 0  {'product_id': 'B0B9RZ4G4W', 'product_name': '...  0.500000
# 1  {'product_id': 'B08ZJDWTJ1', 'product_name': '...  0.500000
# 2  {'product_id': 'B09ZDVL7L8', 'product_name': '...  0.096980
# 3  {'product_id': 'B08KDBLMQP', 'product_name': '...  0.087394
# 4  {'product_id': 'B008YW8M0G', 'product_name': '...  0.084202
# Product name Usha Goliath GO1200WG Heavy Weight 1200-Watt Dry Iron, 1.8 Kg(Red) not found in recommendations.
# User 166 has 2 interactions in the test_data.
#                                              Product     Score
# 0  {'product_id': 'B07S9S86BF', 'product_name': '...  0.500000
# 1  {'product_id': 'B07KCMR8D6', 'product_name': '...  0.500000
# 2  {'product_id': 'B09GFN8WZL', 'product_name': '...  0.086370
# 3  {'product_id': 'B07L9FW9GF', 'product_name': '...  0.074116
# 4  {'product_id': 'B07YZG8PPY', 'product_name': '...  0.055940
# Product name Classmate Octane Colour Burst-Multicolour Gel Pens (Pack of 10) | Gold & Silver Glitter Sparkle Pens|10 colour ink shades for art lovers and kids|Fun at home essentials not found in recommendations.
# User 1943 has 2 interactions in the test_data.
#                                              Product     Score
# 0  {'product_id': 'B07KCMR8D6', 'product_name': '...  0.500000
# 1  {'product_id': 'B07S9S86BF', 'product_name': '...  0.476744
# 2  {'product_id': 'B078W65FJ7', 'product_name': '...  0.069431
# 3  {'product_id': 'B01MF8MB65', 'product_name': '...  0.063355
# 4  {'product_id': 'B07CD2BN46', 'product_name': '...  0.062265
# User 3197 has 3 interactions in the test_data.
#                                              Product     Score
# 0  {'product_id': 'B008QTK47Q', 'product_name': '...  0.115993
# 1  {'product_id': 'B07DC4RZPY', 'product_name': '...  0.115993
# 2  {'product_id': 'B08CF3B7N1', 'product_name': '...  0.113347
# 3  {'product_id': 'B008LN8KDM', 'product_name': '...  0.113347
# 4  {'product_id': 'B07Z53L5QL', 'product_name': '...  0.113347
# Product name MI 360° Home Security Wireless Camera 2K Pro with Bluetooth Gateway BLE 4.2 l Dual Band Wi-fi Connection l 3 Million 1296p| Full Color in Low-Light | AI Human Detection, White not found in recommendations.
# Product name Tukzer Stylus Pen, iPad Pencil with Palm Rejection Tilt Sensor| 2nd Gen for 2018-2022 iPad 6/7/8/9th Gen; iPad 10.2", Pro 12.9/11", Mini 6/5th, Air 5/4/3rd, Precise for Writing/Drawing (3 Spare Tips) not found in recommendations.
# Product name Black + Decker BD BXIR2201IN 2200-Watt Cord & Cordless Steam Iron (Green) not found in recommendations.
# User 4503 has 3 interactions in the test_data.
#                                              Product     Score
# 0  {'product_id': 'B09JKNF147', 'product_name': '...  0.150782
# 1  {'product_id': 'B09B125CFJ', 'product_name': '...  0.145331
# 2  {'product_id': 'B07CD2BN46', 'product_name': '...  0.072129
# 3  {'product_id': 'B00NNQMYNE', 'product_name': '...  0.070495
# 4  {'product_id': 'B07Z1X6VFC', 'product_name': '...  0.070495
# Product name SaleOn™ Portable Storage Organizer Bag for Earphone USB Cable Power Bank Mobile Charger Digital Gadget Hard Disk, Water Resistance Material - Dark Grey not found in recommendations.
# Product name LUNAGARIYA®, Protective Case Compatible with JIO Settop Box Remote Control,PU Leather Cover Holder (Before Placing Order,Please Compare The Dimensions of The Product with Your Remote) not found in recommendations.
# Product name Cotbolt Silicone Case Cover Compatible for Samsung BN59-01312A QLED 8K 4K Smart TV Remote Shockproof Protective Remote Cover (Black) not found in recommendations.
# User 4105 has 2 interactions in the test_data.
#                                              Product     Score
# 0  {'product_id': 'B07VZH6ZBB', 'product_name': '...  0.645020
# 1  {'product_id': 'B0B3X2BY3M', 'product_name': '...  0.500000
# 2  {'product_id': 'B08C7TYHPB', 'product_name': '...  0.500000
# 3  {'product_id': 'B08D9NDZ1Y', 'product_name': '...  0.153453
# 4  {'product_id': 'B07W4HTS8Q', 'product_name': '...  0.132331
# Product name Canon PIXMA MG2577s All-in-One Inkjet Colour Printer with 1 Additional Colour Cartridge not found in recommendations.
# User 3136 has 2 interactions in the test_data.
#                                              Product     Score
# 0  {'product_id': 'B07S9S86BF', 'product_name': '...  0.500000
# 1  {'product_id': 'B07KCMR8D6', 'product_name': '...  0.500000
# 2  {'product_id': 'B078W65FJ7', 'product_name': '...  0.067695
# 3  {'product_id': 'B07W9KYT62', 'product_name': '...  0.067380
# 4  {'product_id': 'B098NS6PVG', 'product_name': '...  0.067380
# Product name Portronics Key2 Combo Multimedia USB Wireless Keyboard and Mouse Set with 2.4 GHz Wireless Technology, Soft & Silent Button, Compact Size (Grey) not found in recommendations.
# User 4532 has 2 interactions in the test_data.
#                                              Product     Score
# 0  {'product_id': 'B0993BB11X', 'product_name': '...  0.500000
# 1  {'product_id': 'B08TDJNM3G', 'product_name': '...  0.256246
# 2  {'product_id': 'B0B4DT8MKT', 'product_name': '...  0.243754
# ...
# 4  {'product_id': 'B0B2DJ5RVQ', 'product_name': '...  0.098473
# Product name Ionix Jewellery Scale | Weight Scale | Digital Weight Machine | weight machine for gold | Electronic weighing machines for Jewellery 0.01G to 200G Small Weight Machine for Shop - Silver not found in recommendations.
# User 7321 has 3 interactions in the test_data.
#                                              Product     Score
# 0  {'product_id': 'B09JPC82QC', 'product_name': '...  0.500000
# 1  {'product_id': 'B09F9YQQ7B', 'product_name': '...  0.212077
# 2  {'product_id': 'B07232M876', 'product_name': '...  0.205140
# 3  {'product_id': 'B008QTK47Q', 'product_name': '...  0.205140
# 4  {'product_id': 'B07VTFN6HM', 'product_name': '...  0.205140
# Product name Boya ByM1 Auxiliary Omnidirectional Lavalier Condenser Microphone with 20ft Audio Cable (Black) not found in recommendations.
# Product name Sennheiser CX 80S in-Ear Wired Headphones with in-line One-Button Smart Remote with Microphone Black not found in recommendations.
# User 5445 has 2 interactions in the test_data.
#                                              Product     Score
# 0  {'product_id': 'B09NVPSCQT', 'product_name': '...  0.500000
# 1  {'product_id': 'B01LONQBDG', 'product_name': '...  0.339620
# 2  {'product_id': 'B07G3YNLJB', 'product_name': '...  0.339620
# 3  {'product_id': 'B098K3H92Z', 'product_name': '...  0.339620
# 4  {'product_id': 'B09PLFJ7ZW', 'product_name': '...  0.192029
# User 7862 has 2 interactions in the test_data.
#                                              Product     Score
# 0  {'product_id': 'B008YW8M0G', 'product_name': '...  0.500000
# 1  {'product_id': 'B07232M876', 'product_name': '...  0.231014
# 2  {'product_id': 'B07VTFN6HM', 'product_name': '...  0.231014
# 3  {'product_id': 'B008QTK47Q', 'product_name': '...  0.231014
# 4  {'product_id': 'B01N6LU1VF', 'product_name': '...  0.231014
# User 6246 has 2 interactions in the test_data.
#                                              Product     Score
# 0  {'product_id': 'B08H21B6V7', 'product_name': '...  0.500000
# 1  {'product_id': 'B07L9FW9GF', 'product_name': '...  0.067327
# 2  {'product_id': 'B08FTFXNNB', 'product_name': '...  0.065266
# 3  {'product_id': 'B07JB2Y4SR', 'product_name': '...  0.059648
# 4  {'product_id': 'B0BD3T6Z1D', 'product_name': '...  0.059100
# Product name TATA SKY HD Connection with 1 month basic package and free installation not found in recommendations.
# User 2358 has 2 interactions in the test_data.
#                                              Product     Score
# 0  {'product_id': 'B01M4GGIVU', 'product_name': '...  0.500000
# 1  {'product_id': 'B00P93X6EK', 'product_name': '...  0.337297
# 2  {'product_id': 'B00LZLPYHW', 'product_name': '...  0.337297
# 3  {'product_id': 'B00P93X0VO', 'product_name': '...  0.317696
# 4  {'product_id': 'B06XR9PR5X', 'product_name': '...  0.300752
# Product name Classmate Soft Cover 6 Subject Spiral Binding Notebook, Single Line, 300 Pages not found in recommendations.
# User 2210 has 2 interactions in the test_data.
#                                              Product     Score
# 0  {'product_id': 'B00LZLQ624', 'product_name': '...  0.500000
# 1  {'product_id': 'B01M4GGIVU', 'product_name': '...  0.500000
# 2  {'product_id': 'B0819ZZK5K', 'product_name': '...  0.478517
# 3  {'product_id': 'B07WKBD37W', 'product_name': '...  0.478517
# 4  {'product_id': 'B00P93X6EK', 'product_name': '...  0.326213
# User 3287 has 2 interactions in the test_data.
#                                              Product     Score
# 0  {'product_id': 'B00GZLB57U', 'product_name': '...  0.500000
# 1  {'product_id': 'B08YDFX7Y1', 'product_name': '...  0.500000
# 2  {'product_id': 'B087FXHB6J', 'product_name': '...  0.172542
# 3  {'product_id': 'B08Y7MXFMK', 'product_name': '...  0.160141
# 4  {'product_id': 'B0819HZPXL', 'product_name': '...  0.153661
# Product name Amozo Ultra Hybrid Camera and Drop Protection Back Cover Case for iPhone 13 (TPU + Polycarbonate | Crystal Transparent) not found in recommendations.
# User 5004 has 2 interactions in the test_data.
#                                              Product     Score
# 0  {'product_id': 'B01HJI0FS2', 'product_name': '...  0.500000
# 1  {'product_id': 'B00GZLB57U', 'product_name': '...  0.183870
# 2  {'product_id': 'B014SZO90Y', 'product_name': '...  0.183870
# 3  {'product_id': 'B073BRXPZX', 'product_name': '...  0.107765
# 4  {'product_id': 'B08JW1GVS7', 'product_name': '...  0.086295
# Product name MI Xiaomi 22.5W Fast USB Type C Charger Combo for Tablets - White not found in recommendations.
# User 6988 has 2 interactions in the test_data.
#                                              Product     Score
# 0  {'product_id': 'B00LUGTJGO', 'product_name': '...  0.500000
# 1  {'product_id': 'B009P2LK08', 'product_name': '...  0.185688
# 2  {'product_id': 'B09B125CFJ', 'product_name': '...  0.128693
# 3  {'product_id': 'B099FDW2ZF', 'product_name': '...  0.117157
# 4  {'product_id': 'B08YXJJW8H', 'product_name': '...  0.117157
# Product name Electvision Remote Control Compatible with Kodak/Thomson Smart led tv (Without Voice) Before Placing Order for verification Contact Our coustmer Care 7738090464 not found in recommendations.
# User 6806 has 2 interactions in the test_data.
#                                              Product     Score
# 0  {'product_id': 'B08MZNT7GP', 'product_name': '...  0.500000
# 1  {'product_id': 'B005LJQMCK', 'product_name': '...  0.500000
# 2  {'product_id': 'B0811VCGL5', 'product_name': '...  0.500000
# 3  {'product_id': 'B07W9KYT62', 'product_name': '...  0.051646
# 4  {'product_id': 'B01I1LDZGA', 'product_name': '...  0.050906
# Product name APC Back-UPS BX600C-IN 600VA / 360W, 230V, UPS System, an Ideal Power Backup & Protection for Home Office, Desktop PC & Home Electronics not found in recommendations.
# User 5114 has 2 interactions in the test_data.
#                                              Product     Score
# 0  {'product_id': 'B09NVPSCQT', 'product_name': '...  0.500000
# 1  {'product_id': 'B07G3YNLJB', 'product_name': '...  0.500000
# 2  {'product_id': 'B09PLFJ7ZW', 'product_name': '...  0.195181
# 3  {'product_id': 'B0B5LVS732', 'product_name': '...  0.134400
# 4  {'product_id': 'B0BNXFDTZ2', 'product_name': '...  0.111348
# Product name Noise Buds VS402 Truly Wireless in Ear Earbuds, 35-Hours of Playtime, Instacharge, Quad Mic with ENC, Hyper Sync, Low Latency, 10mm Driver, Bluetooth v5.3 and Breathing LED Lights (Neon Black) not found in recommendations.
# User 8843 has 2 interactions in the test_data.
#                                              Product     Score
# 0  {'product_id': 'B084PJSSQ1', 'product_name': '...  0.500000
# 1  {'product_id': 'B0819ZZK5K', 'product_name': '...  0.319857
# 2  {'product_id': 'B09XB8GFBQ', 'product_name': '...  0.260427
# 3  {'product_id': 'B0BBFJ9M3X', 'product_name': '...  0.239620
# 4  {'product_id': 'B08VB34KJ1', 'product_name': '...  0.226860
# Product name Redmi Note 11 (Space Black, 4GB RAM, 64GB Storage)|90Hz FHD+ AMOLED Display | Qualcomm® Snapdragon™ 680-6nm | 33W Charger Included not found in recommendations.
# User 4505 has 2 interactions in the test_data.
#                                              Product  Score
# 0  {'product_id': 'B083T5G5PM', 'product_name': '...    0.5
# 1  {'product_id': 'B07232M876', 'product_name': '...    0.5
# 2  {'product_id': 'B07VTFN6HM', 'product_name': '...    0.5
# 3  {'product_id': 'B008QTK47Q', 'product_name': '...    0.5
# 4  {'product_id': 'B01N6LU1VF', 'product_name': '...    0.5
# Product name Crucial RAM 8GB DDR4 3200MHz CL22 (or 2933MHz or 2666MHz) Laptop Memory CT8G4SFRA32A not found in recommendations.
# User 146 has 2 interactions in the test_data.
#                                              Product     Score
# 0  {'product_id': 'B09LMMFW3S', 'product_name': '...  0.500000
# 1  {'product_id': 'B09LHYZ3GJ', 'product_name': '...  0.115728
# 2  {'product_id': 'B09FKDH6FS', 'product_name': '...  0.111379
# 3  {'product_id': 'B0BD3T6Z1D', 'product_name': '...  0.101677
# 4  {'product_id': 'B09QS8V5N8', 'product_name': '...  0.099460
# Product name realme narzo 50 (Speed Blue, 4GB RAM+64GB Storage) Helio G96 Processor | 50MP AI Triple Camera | 120Hz Ultra Smooth Display not found in recommendations.
# User 8428 has 2 interactions in the test_data.
#                                              Product     Score
# 0  {'product_id': 'B07Z53L5QL', 'product_name': '...  0.500000
# 1  {'product_id': 'B078W65FJ7', 'product_name': '...  0.098124
# 2  {'product_id': 'B08KRMK9LZ', 'product_name': '...  0.097137
# 3  {'product_id': 'B07JF9B592', 'product_name': '...  0.094365
# 4  {'product_id': 'B08CF3B7N1', 'product_name': '...  0.094365
# Product name Logitech H111 Wired On Ear Headphones With Mic Black not found in recommendations.
# User 8367 has 2 interactions in the test_data.
#                                              Product     Score
# 0  {'product_id': 'B0B5B6PQCT', 'product_name': '...  0.500000
# 1  {'product_id': 'B0949SBKMP', 'product_name': '...  0.124319
# 2  {'product_id': 'B0BNXFDTZ2', 'product_name': '...  0.117778
# 3  {'product_id': 'B09NVPSCQT', 'product_name': '...  0.112423
# 4  {'product_id': 'B0B5LVS732', 'product_name': '...  0.110245
# Product name Cubetek 3 in 1 LCD Display V5.0 Bluetooth Transmitter Receiver, Bypass Audio Adapter with Aux, Optical, Dual Link Support for TV, Home Stereo, PC, Headphones, Speakers, Model: CB-BT27 not found in recommendations.
# User 5201 has 2 interactions in the test_data.
#                                              Product     Score
# 0  {'product_id': 'B0B5B6PQCT', 'product_name': '...  0.500000
# 1  {'product_id': 'B08MVXPTDG', 'product_name': '...  0.121577
# 2  {'product_id': 'B09CGLY5CX', 'product_name': '...  0.108313
# 3  {'product_id': 'B09NFSHCWN', 'product_name': '...  0.098885
# 4  {'product_id': 'B0BMTZ4T1D', 'product_name': '...  0.095215
# Product name Candes Gloster All in One Silent Blower Fan Room Heater Ideal for Small and Medium Area, 2000 Watts (White) not found in recommendations.
# User 8679 has 2 interactions in the test_data.
#                                              Product     Score
# 0  {'product_id': 'B07YL54NVJ', 'product_name': '...  0.500000
# 1  {'product_id': 'B08GYG6T12', 'product_name': '...  0.162478
# 2  {'product_id': 'B097C564GC', 'product_name': '...  0.133108
# 3  {'product_id': 'B07DJLFMPS', 'product_name': '...  0.094475
# 4  {'product_id': 'B07GVGTSLN', 'product_name': '...  0.093867
# Product name SanDisk Extreme SD UHS I 64GB Card for 4K Video for DSLR and Mirrorless Cameras 170MB/s Read & 80MB/s Write not found in recommendations.
# User 2859 has 2 interactions in the test_data.
#                                              Product     Score
# 0  {'product_id': 'B07RZZ1QSW', 'product_name': '...  0.587735
# 1  {'product_id': 'B074CWD7MS', 'product_name': '...  0.500000
# 2  {'product_id': 'B08HD7JQHX', 'product_name': '...  0.153192
# 3  {'product_id': 'B00Y4ORQ46', 'product_name': '...  0.093833
# 4  {'product_id': 'B076B8G5D8', 'product_name': '...  0.088407
# Product name MAONO AU-400 Lavalier Auxiliary Omnidirectional Microphone (Black) not found in recommendations.
# User 428 has 2 interactions in the test_data.
#                                              Product     Score
# 0  {'product_id': 'B074CWD7MS', 'product_name': '...  0.500000
# 1  {'product_id': 'B07RZZ1QSW', 'product_name': '...  0.500000
# 2  {'product_id': 'B0B9BXKBC7', 'product_name': '...  0.153153
# 3  {'product_id': 'B0B2DJ5RVQ', 'product_name': '...  0.131780
# 4  {'product_id': 'B07N42JB4S', 'product_name': '...  0.119074
# User 7706 has 2 interactions in the test_data.
#                                              Product     Score
# 0  {'product_id': 'B074CWD7MS', 'product_name': '...  0.500000
# 1  {'product_id': 'B07RZZ1QSW', 'product_name': '...  0.500000
# 2  {'product_id': 'B0B2DJ5RVQ', 'product_name': '...  0.137906
# 3  {'product_id': 'B0B9BXKBC7', 'product_name': '...  0.126997
# 4  {'product_id': 'B07GNC2592', 'product_name': '...  0.083726
# Product name PrettyKrafts Laundry Basket for clothes with Lid & Handles, Toys Organiser, 75 Ltr Grey not found in recommendations.
# User 4773 has 2 interactions in the test_data.
#                                              Product     Score
# 0  {'product_id': 'B09NHVCHS9', 'product_name': '...  0.500000
# 1  {'product_id': 'B087FXHB6J', 'product_name': '...  0.437500
# 2  {'product_id': 'B08YDFX7Y1', 'product_name': '...  0.166825
# 3  {'product_id': 'B08Y7MXFMK', 'product_name': '...  0.159236
# 4  {'product_id': 'B073BRXPZX', 'product_name': '...  0.157569
# User 2383 has 2 interactions in the test_data.
#                                              Product     Score
# 0  {'product_id': 'B008YW8M0G', 'product_name': '...  0.500000
# 1  {'product_id': 'B01N6LU1VF', 'product_name': '...  0.500000
# 2  {'product_id': 'B099Z83VRC', 'product_name': '...  0.202134
# 3  {'product_id': 'B00F159RIK', 'product_name': '...  0.184763
# 4  {'product_id': 'B08MV82R99', 'product_name': '...  0.075901
# Product name GILTON Egg Boiler Electric Automatic Off 7 Egg Poacher for Steaming, Cooking Also Boiling and Frying, Multi Color not found in recommendations.
# User 4500 has 2 interactions in the test_data.
#                                              Product     Score
# 0  {'product_id': 'B087FXHB6J', 'product_name': '...  0.500000
# 1  {'product_id': 'B09NHVCHS9', 'product_name': '...  0.500000
# 2  {'product_id': 'B08YDFX7Y1', 'product_name': '...  0.175649
# 3  {'product_id': 'B08Y7MXFMK', 'product_name': '...  0.169930
# 4  {'product_id': 'B07L9FW9GF', 'product_name': '...  0.143639
# Product name Myvn 30W Warp/20W Dash Charging Usb Type C Charger Cable Compatible For Cellular Phones Oneplus 8T 8 8Pro 7 Pro / 7T / 7T Pro Nord And Oneplus 3 / 3T / 5 / 5T / 6 / 6T / 7 not found in recommendations.
# User 3031 has 2 interactions in the test_data.
#                                              Product     Score
# 0  {'product_id': 'B09YLXYP7Y', 'product_name': '...  0.500000
# 1  {'product_id': 'B07CD2BN46', 'product_name': '...  0.271740
# 2  {'product_id': 'B07GLNJC25', 'product_name': '...  0.228260
# 3  {'product_id': 'B09ZPL5VYM', 'product_name': '...  0.228260
# 4  {'product_id': 'B08Y1TFSP6', 'product_name': '...  0.133729
# Product name HP 32GB Class 10 MicroSD Memory Card (U1 TF Card 32GB) not found in recommendations.
# User 7015 has 2 interactions in the test_data.
#                                              Product     Score
# 0  {'product_id': 'B084PJSSQ1', 'product_name': '...  0.500000
# 1  {'product_id': 'B0819ZZK5K', 'product_name': '...  0.328538
# 2  {'product_id': 'B09JPC82QC', 'product_name': '...  0.279657
# 3  {'product_id': 'B09WN3SRC7', 'product_name': '...  0.249855
# 4  {'product_id': 'B08CS3BT4L', 'product_name': '...  0.249855
# Product name Redmi 80 cm (32 inches) Android 11 Series HD Ready Smart LED TV | L32M6-RA/L32M7-RA (Black) not found in recommendations.
# User 6935 has 2 interactions in the test_data.
#                                              Product     Score
# 0  {'product_id': 'B01HJI0FS2', 'product_name': '...  0.500000
# 1  {'product_id': 'B07W14CHV8', 'product_name': '...  0.291805
# 2  {'product_id': 'B00GZLB57U', 'product_name': '...  0.183870
# 3  {'product_id': 'B014SZO90Y', 'product_name': '...  0.183870
# 4  {'product_id': 'B073BRXPZX', 'product_name': '...  0.126567
# Product name Lapster Caddy for ssd and HDD, Optical Bay 2nd Hard Drive Caddy, Caddy 9.5mm for Laptop not found in recommendations.
# User 7086 has 2 interactions in the test_data.
#                                              Product     Score
# 0  {'product_id': 'B07CD2BN46', 'product_name': '...  0.500000
# 1  {'product_id': 'B0949SBKMP', 'product_name': '...  0.500000
# 2  {'product_id': 'B0BNXFDTZ2', 'product_name': '...  0.117289
# 3  {'product_id': 'B0B5B6PQCT', 'product_name': '...  0.112562
# 4  {'product_id': 'B0B5LVS732', 'product_name': '...  0.111400
# Product name GIZGA Club-laptop Neoprene Reversible for 15.6-inches Laptop Sleeve - Black-Red not found in recommendations.
# Length of actual scores: 145
# Length of predicted scores: 145
# Precision for Hybrid System: 0.2482758620689655
# Recall for Hybrid System: 0.5806451612903226
# RMSE for Hybrid System: 3.710947931922696

# %%
predicted_scores = []
actual_scores = []

for user_id_encoded in test_data['user_id_encoded'].unique():
    user_data = test_data[test_data['user_id_encoded'] == user_id_encoded]
    if user_id_encoded not in pt.index or 'recommended_product' not in recommendations_df.columns:
        continue
    
    recommendations_df = hybrid_recommendation_v2(user_id_encoded)
    for _, row in user_data.iterrows():
        product_name = row['product_name']
        actual_score = row['rating']  # assuming you have a column 'rating' in test_data
        predicted_score = recommendations_df[recommendations_df['Product']['product_name'] == product_name]['Score'].values
        predicted_scores.append(predicted_score[0] if len(predicted_score) > 0 else 0)
        actual_scores.append(actual_score)

rmse = np.sqrt(mean_squared_error(actual_scores, predicted_scores))
print("RMSE for Hybrid System:", rmse)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\swapn\Desktop\hybrid for eval.ipynb Cell 16 line 1
#      <a href='vscode-notebook-cell:/c%3A/Users/swapn/Desktop/hybrid%20for%20eval.ipynb#X21sZmlsZQ%3D%3D?line=13'>14</a>         predicted_scores.append(predicted_score[0] if len(predicted_score) > 0 else 0)
#      <a href='vscode-notebook-cell:/c%3A/Users/swapn/Desktop/hybrid%20for%20eval.ipynb#X21sZmlsZQ%3D%3D?line=14'>15</a>         actual_scores.append(actual_score)
# ---> <a href='vscode-notebook-cell:/c%3A/Users/swapn/Desktop/hybrid%20for%20eval.ipynb#X21sZmlsZQ%3D%3D?line=16'>17</a> rmse = np.sqrt(mean_squared_error(actual_scores, predicted_scores))
#      <a href='vscode-notebook-cell:/c%3A/Users/swapn/Desktop/hybrid%20for%20eval.ipynb#X21sZmlsZQ%3D%3D?line=17'>18</a> print("RMSE for Hybrid System:", rmse)
#
# File c:\Python311\Lib\site-packages\sklearn\utils\_param_validation.py:211, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     205 try:
#     206     with config_context(
#     207         skip_parameter_validation=(
#     208             prefer_skip_nested_validation or global_skip_validation
#     209         )
#     210     ):
# --> 211         return func(*args, **kwargs)
#     212 except InvalidParameterError as e:
#     213     # When the function is just a wrapper around an estimator, we allow
#     214     # the function to delegate validation to the estimator, but we replace
#     215     # the name of the estimator by the name of the function in the error
#     216     # message to avoid confusion.
#     217     msg = re.sub(
#     218         r"parameter of \w+ must be",
#     219         f"parameter of {func.__qualname__} must be",
#     220         str(e),
#     221     )
#
# File c:\Python311\Lib\site-packages\sklearn\metrics\_regression.py:474, in mean_squared_error(y_true, y_pred, sample_weight, multioutput, squared)
#     404 @validate_params(
#     405     {
#     406         "y_true": ["array-like"],
#    (...)
#     415     y_true, y_pred, *, sample_weight=None, multioutput="uniform_average", squared=True
#     416 ):
#     417     """Mean squared error regression loss.
#     418
#     419     Read more in the :ref:`User Guide <mean_squared_error>`.
#    (...)
#     472     0.825...
#     473     """
# --> 474     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#     475         y_true, y_pred, multioutput
#     476     )
#     477     check_consistent_length(y_true, y_pred, sample_weight)
#     478     output_errors = np.average((y_true - y_pred) ** 2, axis=0, weights=sample_weight)
#
# File c:\Python311\Lib\site-packages\sklearn\metrics\_regression.py:100, in _check_reg_targets(y_true, y_pred, multioutput, dtype)
#      66 """Check that y_true and y_pred belong to the same regression task.
#      67
#      68 Parameters
#    (...)
#      97     correct keyword.
#      98 """
#      99 check_consistent_length(y_true, y_pred)
# --> 100 y_true = check_array(y_true, ensure_2d=False, dtype=dtype)
#     101 y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#     103 if y_true.ndim == 1:
#
# File c:\Python311\Lib\site-packages\sklearn\utils\validation.py:969, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     967     n_samples = _num_samples(array)
#     968     if n_samples < ensure_min_samples:
# --> 969         raise ValueError(
#     970             "Found array with %d sample(s) (shape=%s) while a"
#     971             " minimum of %d is required%s."
#     972             % (n_samples, array.shape, ensure_min_samples, context)
#     973         )
#     975 if ensure_min_features > 0 and array.ndim == 2:
#     976     n_features = array.shape[1]
#
# ValueError: Found array with 0 sample(s) (shape=(0,)) while a minimum of 1 is required.
