# %% [markdown]
# # **Amazon Product Analysis & Recommendation System**

# %% [markdown]
# 👋 Welcome to my data science project! In this project, we'll be analyzing a dataset of over 1,000 products listed on Amazon and building a recommendation system for these products. 🛍️💻
#
# The dataset includes details such as **product name**, **category**, **price**, **rating**, and **user reviews** . Our goal is to understand customer preferences, identify purchasing patterns, and develop a recommendation system to suggest products to users based on their interests. 🧐👨‍💻
#
# Our project will consist of the following steps:
#
# 📊 **Data collection**: We'll collect the Amazon products dataset from Kaggle.
#
# 🧹 **Data preparation**: We'll clean and preprocess the dataset for analysis.
#
# 🕵️‍♂️ **Exploratory data analysis**: We'll analyze the data to understand the distribution of products by categories, customer ratings, and reviews.
#
# 📈 **Data visualization**: We'll visualize the data to identify trends and patterns.
#
# 💡 **Simples recommendation system**: We'll develop a recommendation system using machine learning algorithms to suggest products to users based on their interests and previous purchases.

# %% [markdown]
# # #**1-Data collection**

# %% [markdown]
# 👋 Hey there! So, we're going to be working on a project that involves analyzing data from Amazon - you know, the huge online retailer? 🛍️ They sell everything from books 📚 to electronics 📱 to groceries 🍎, so there's a lot to look at.
#
# 📊 The dataset we'll be using has information on over 1000 products sold by Amazon, like their names, categories, prices, ratings, and reviews. We're going to be digging into this data and figuring out what it all means, and how we can use it to help Amazon and its customers.
#
# For Amazon, analyzing this data can help them understand which products are popular and which aren't, and they can use that information to figure out how to price and market things better. For customers, having access to this data can help them decide what to buy - if they see that a product has good ratings and lots of positive reviews, they'll be more likely to buy it. 💸
#
# So, we're going to be exploring this dataset, doing some cool data analysis and visualization 📈, and even building a recommendation system based on the data. It's going to be pretty sweet, so let's get started! 🚀
#
# **Features**
#
# **product_id** - Product ID
#
# **product_name** - Name of the Product
#
# **category** - Category of the Product
#
# **discounted_price** - Discounted Price of the Product
#
# **actual_price** - Actual Price of the Product
#
# **discount_percentage** - Percentage of Discount for the Product
#
# **rating** - Rating of the Product
#
# **rating_count** - Number of people who voted for the Amazon rating
#
# **about_product** - Description about the Product
#
# **user_id** - ID of the user who wrote review for the Product
#
# **user_name** - Name of the user who wrote review for the Product
#
# **review_id** - ID of the user review
#
# **review_title** - Short review
#
# **review_content** - Long review
#
# **img_link** - Image Link of the Product
#
# **product_link** - Official Website Link of the Product
#
# To access the dataset, simply go to Kaggle website: https://www.kaggle.com/datasets/karkavelrajaj/amazon-sales-dataset

# %%
import pandas as pd

# load CSV file from Google Drive
df = pd.read_csv(r"C:/Users/swapn/Desktop/testing/modified_dataset2.csv")

# %%
df.head()
# Out:
#    product_id                                       product_name  \
# 0  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1  B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2  B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3  B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4  B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
#
#                                             category discounted_price  \
# 0  Computers&Accessories|Accessories&Peripherals|...             ₹399
# 1  Computers&Accessories|Accessories&Peripherals|...             ₹199
# 2  Computers&Accessories|Accessories&Peripherals|...             ₹199
# 3  Computers&Accessories|Accessories&Peripherals|...             ₹329
# 4  Computers&Accessories|Accessories&Peripherals|...             ₹154
#
#   actual_price discount_percentage rating  rating_count  \
# 0       ₹1,099                 64%    4.2         24269
# 1         ₹349                 43%      4         43994
# 2       ₹1,899                 90%    3.9          7928
# 3         ₹699                 53%    4.2         94363
# 4         ₹399                 61%    4.2         16905
#
#                                        about_product  \
# 0  High Compatibility : Compatible With iPhone 12...
# 1  Compatible with all Type C enabled devices, be...
# 2   Fast Charger& Data Sync-With built-in safety ...
# 3  The boAt Deuce USB 300 2 in 1 cable is compati...
# 4  [CHARGE & SYNC FUNCTION]- This cable comes wit...
#
#                                              user_id  \
# 0  AG3D6O4STAQKAY2UVGEUV46KN35Q,AHMY5CWJMMK5BJRBB...
# 1  AECPFYFQVRUWC3KGNLJIOREFP5LQ,AGYYVPDD7YG7FYNBX...
# 2  AGU3BBQ2V2DDAMOAKGFAWDDQ6QHA,AESFLDV2PT363T2AQ...
# 3  AEWAZDZZJLQUYVOVGBEUKSLXHQ5A,AG5HTSFRRE6NL3M5S...
# 4  AE3Q6KSUK5P75D5HFYHCRAOLODSA,AFUGIFH5ZAFXRDSZH...
#
#                                            user_name  \
# 0  Manav,Adarsh gupta,Sundeep,S.Sayeed Ahmed,jasp...
# 1  ArdKn,Nirbhay kumar,Sagar Viswanathan,Asp,Plac...
# 2  Kunal,Himanshu,viswanath,sai niharka,saqib mal...
# 3  Omkar dhale,JD,HEMALATHA,Ajwadh a.,amar singh ...
# 4  rahuls6099,Swasat Borah,Ajay Wadke,Pranali,RVK...
#
#                                            review_id  \
# 0  R3HXWT0LRP0NMF,R2AJM3LFTLZHFO,R6AQJGUP6P86,R1K...
# 1  RGIQEG07R9HS2,R1SMWZQ86XIN8U,R2J3Y1WL29GWDE,RY...
# 2  R3J3EQQ9TZI5ZJ,R3E7WBGK7ID0KV,RWU79XKQ6I1QF,R2...
# 3  R3EEUZKKK9J36I,R3HJVYCLYOY554,REDECAZ7AMPQC,R1...
# 4  R1BP4L2HH9TFUP,R16PVJEXKV6QZS,R2UPDB81N66T4P,R...
#
#                                         review_title  \
# 0  Satisfied,Charging is really fast,Value for mo...
# 1  A Good Braided Cable for Your Type C Device,Go...
# 2  Good speed for earlier versions,Good Product,W...
# 3  Good product,Good one,Nice,Really nice product...
# 4  As good as original,Decent,Good one for second...
#
#                                       review_content  \
# 0  Looks durable Charging is fine tooNo complains...
# 1  I ordered this cable to connect my phone to An...
# 2  Not quite durable and sturdy,https://m.media-a...
# 3  Good product,long wire,Charges good,Nice,I bou...
# 4  Bought this instead of original apple, does th...
#
#                                             img_link  \
# 0  https://m.media-amazon.com/images/W/WEBP_40237...
# 1  https://m.media-amazon.com/images/W/WEBP_40237...
# 2  https://m.media-amazon.com/images/W/WEBP_40237...
# 3  https://m.media-amazon.com/images/I/41V5FtEWPk...
# 4  https://m.media-amazon.com/images/W/WEBP_40237...
#
#                                         product_link
# 0  https://www.amazon.in/Wayona-Braided-WN3LG1-Sy...
# 1  https://www.amazon.in/Ambrane-Unbreakable-Char...
# 2  https://www.amazon.in/Sounce-iPhone-Charging-C...
# 3  https://www.amazon.in/Deuce-300-Resistant-Tang...
# 4  https://www.amazon.in/Portronics-Konnect-POR-1...

# %% [markdown]
# # #**2-Data preparation**

# %% [markdown]
# Before we dive into the data analysis and visualization, we need to make sure our dataset is clean and properly formatted. This process is called data preparation, and it involves several steps:
#
# 2.1 🔍 Data Inspection:
# We'll start by inspecting the dataset to see if there are any missing values, duplicates, or inconsistent data. We'll also check if the data types are correct and make sure the dataset is ready for analysis.
#
# 2.2 🧹 Data Cleaning:
# Next, we'll clean the dataset by removing or correcting any errors, inconsistencies, or irrelevant information. This will make the dataset more reliable and accurate.
#
# 2.3 📏 Data Transformation:
# After cleaning the dataset, we may need to transform the data to make it more useful for analysis. This can include scaling, normalization, or feature engineering.
#
# 2.4 💾 Data Saving: Once we've prepared the data, we'll save it in a new file to avoid overwriting the original dataset. This way, we can always go back to the original dataset if we need to.
#
# By following these steps, we can ensure that our data is clean, accurate, and ready for analysis! 🚀

# %%
# check the number of rows and columns
df.shape
# Out:
# (5150, 16)

# %%
# Check for missing values
def check_missing_values(dataframe):
    return dataframe.isnull().sum()

print(check_missing_values(df))
df[df.rating_count.isnull()]
# Out:
# product_id             0
# product_name           0
# category               0
# discounted_price       0
# actual_price           0
# discount_percentage    0
# rating                 0
# rating_count           0
# about_product          0
# user_id                0
# user_name              0
# review_id              0
# review_title           0
# review_content         0
# img_link               0
# product_link           0
# dtype: int64
# Empty DataFrame
# Columns: [product_id, product_name, category, discounted_price, actual_price, discount_percentage, rating, rating_count, about_product, user_id, user_name, review_id, review_title, review_content, img_link, product_link]
# Index: []

# %% [markdown]
# To remove rows with missing information, we'll use the dropna() function. We only want to keep rows with all the required information because **missing values can affect the accuracy of our analysis**. In this case, we will remove the two rows that contain blank values for **rating_count**.

# %%
# Remove rows with missing values in the rating_count column
df.dropna(subset=['rating_count'], inplace=True)
print(check_missing_values(df))
# Out:
# product_id             0
# product_name           0
# category               0
# discounted_price       0
# actual_price           0
# discount_percentage    0
# rating                 0
# rating_count           0
# about_product          0
# user_id                0
# user_name              0
# review_id              0
# review_title           0
# review_content         0
# img_link               0
# product_link           0
# dtype: int64

# %%
# Check for duplicates
def check_duplicates(dataframe):
    return dataframe.duplicated().sum()

print(check_duplicates(df))
# Out:
# 0

# %%
# Check data types
def check_data_types(dataframe):
    return dataframe.dtypes

print(check_data_types(df))
# Out:
# product_id             object
# product_name           object
# category               object
# discounted_price       object
# actual_price           object
# discount_percentage    object
# rating                 object
# rating_count            int64
# about_product          object
# user_id                object
# user_name              object
# review_id              object
# review_title           object
# review_content         object
# img_link               object
# product_link           object
# dtype: object

# %% [markdown]
# Some variables in a dataset may have an object data type, which means they are strings. In order to perform numerical analysis on these variables, we need to convert them to numeric values. For example, if we want to calculate the total price of all products, we cannot do so if the price variable is in object format. We need to convert it to a numeric data type first.

# %%
df['discounted_price'] = df['discounted_price'].astype(str).str.replace('₹', '').str.replace(',', '').astype(float)
df['actual_price'] = df['actual_price'].astype(str).str.replace('₹', '').str.replace(',', '').astype(float)
df['discount_percentage'] = df['discount_percentage'].astype(str).str.replace('%','').astype(float)/100

# %%
# The rating column has a value with an incorrect character, so we will exclude
# the row to obtain a clean dataset.
count = df['rating'].str.contains('\|').sum()
print(f"Total de linhas com '|' na coluna 'rating': {count}")
df = df[df['rating'].apply(lambda x: '|' not in str(x))]
count = df['rating'].str.contains('\|').sum()
print(f"Total de linhas com '|' na coluna 'rating': {count}")
# Out:
# Total de linhas com '|' na coluna 'rating': 1
# Total de linhas com '|' na coluna 'rating': 0

# %%
df['rating'] = df['rating'].astype(str).str.replace(',', '').astype(float)
df['rating_count'] = df['rating_count'].astype(str).str.replace(',', '').astype(float)

# %%
print(check_data_types(df))
# Out:
# product_id              object
# product_name            object
# category                object
# discounted_price       float64
# actual_price           float64
# discount_percentage    float64
# rating                 float64
# rating_count           float64
# about_product           object
# user_id                 object
# user_name               object
# review_id               object
# review_title            object
# review_content          object
# img_link                object
# product_link            object
# dtype: object

# %% [markdown]
# Now that we have adjusted the data types, let's create one more colum that could be interesting to have in our database. **"rating_weighted"** because it can be created as a way of considering not only the average rating, but also the number of people who rated the product. This column weighs the average rating by the number of ratings, giving more weight to ratings with a large number of raters. This can help identify products with high customer satisfaction and many positive ratings compared to products with high average ratings but few raters.

# %%
# Creating the column "rating_weighted"
df['rating_weighted'] = df['rating'] * df['rating_count']

# %% [markdown]
# Extracting both the main and final categories from the category column is important because it provides us with a clearer picture of how our products are distributed across different categories. By identifying the main category, we can understand the broader classification of the product, while the final category tells us more specifically what the product is.
#
# For example, if we have a main category of "Electronics" and a final category of "Smartphones", we know that this product falls under the larger umbrella of electronics and is specifically a smartphone. This information can be helpful in understanding the distribution of our products and identifying trends and patterns within specific categories.
#
# Additionally, extracting both main and final categories can also help with data visualization and communication. We can use these categories to create more informative and concise charts and tables that show the distribution of products by category more clearly.
#
# Overall, extracting both main and final categories is an important step in our exploratory data analysis process that helps us gain a better understanding of our data and make more informed decisions.

# %%
df['sub_category'] = df['category'].astype(str).str.split('|').str[-1]
df['main_category'] = df['category'].astype(str).str.split('|').str[0]

# %%
df.columns
# Out:
# Index(['product_id', 'product_name', 'category', 'discounted_price',
#        'actual_price', 'discount_percentage', 'rating', 'rating_count',
#        'about_product', 'user_id', 'user_name', 'review_id', 'review_title',
#        'review_content', 'img_link', 'product_link', 'rating_weighted',
#        'sub_category', 'main_category'],
#       dtype='object')

# %%
len(df)
# Out:
# 5149

# %%
df.head()
# Out:
#    product_id                                       product_name  \
# 0  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1  B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2  B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3  B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4  B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
#
#                                             category  discounted_price  \
# 0  Computers&Accessories|Accessories&Peripherals|...             399.0
# 1  Computers&Accessories|Accessories&Peripherals|...             199.0
# 2  Computers&Accessories|Accessories&Peripherals|...             199.0
# 3  Computers&Accessories|Accessories&Peripherals|...             329.0
# 4  Computers&Accessories|Accessories&Peripherals|...             154.0
#
#    actual_price  discount_percentage  rating  rating_count  \
# 0        1099.0                 0.64     4.2       24269.0
# 1         349.0                 0.43     4.0       43994.0
# 2        1899.0                 0.90     3.9        7928.0
# 3         699.0                 0.53     4.2       94363.0
# 4         399.0                 0.61     4.2       16905.0
#
#                                        about_product  \
# 0  High Compatibility : Compatible With iPhone 12...
# 1  Compatible with all Type C enabled devices, be...
# 2   Fast Charger& Data Sync-With built-in safety ...
# 3  The boAt Deuce USB 300 2 in 1 cable is compati...
# 4  [CHARGE & SYNC FUNCTION]- This cable comes wit...
#
#                                              user_id  \
# 0  AG3D6O4STAQKAY2UVGEUV46KN35Q,AHMY5CWJMMK5BJRBB...
# 1  AECPFYFQVRUWC3KGNLJIOREFP5LQ,AGYYVPDD7YG7FYNBX...
# 2  AGU3BBQ2V2DDAMOAKGFAWDDQ6QHA,AESFLDV2PT363T2AQ...
# 3  AEWAZDZZJLQUYVOVGBEUKSLXHQ5A,AG5HTSFRRE6NL3M5S...
# 4  AE3Q6KSUK5P75D5HFYHCRAOLODSA,AFUGIFH5ZAFXRDSZH...
#
#                                            user_name  \
# 0  Manav,Adarsh gupta,Sundeep,S.Sayeed Ahmed,jasp...
# 1  ArdKn,Nirbhay kumar,Sagar Viswanathan,Asp,Plac...
# 2  Kunal,Himanshu,viswanath,sai niharka,saqib mal...
# 3  Omkar dhale,JD,HEMALATHA,Ajwadh a.,amar singh ...
# 4  rahuls6099,Swasat Borah,Ajay Wadke,Pranali,RVK...
#
#                                            review_id  \
# 0  R3HXWT0LRP0NMF,R2AJM3LFTLZHFO,R6AQJGUP6P86,R1K...
# 1  RGIQEG07R9HS2,R1SMWZQ86XIN8U,R2J3Y1WL29GWDE,RY...
# 2  R3J3EQQ9TZI5ZJ,R3E7WBGK7ID0KV,RWU79XKQ6I1QF,R2...
# 3  R3EEUZKKK9J36I,R3HJVYCLYOY554,REDECAZ7AMPQC,R1...
# 4  R1BP4L2HH9TFUP,R16PVJEXKV6QZS,R2UPDB81N66T4P,R...
#
#                                         review_title  \
# 0  Satisfied,Charging is really fast,Value for mo...
# 1  A Good Braided Cable for Your Type C Device,Go...
# 2  Good speed for earlier versions,Good Product,W...
# 3  Good product,Good one,Nice,Really nice product...
# 4  As good as original,Decent,Good one for second...
#
#                                       review_content  \
# 0  Looks durable Charging is fine tooNo complains...
# 1  I ordered this cable to connect my phone to An...
# 2  Not quite durable and sturdy,https://m.media-a...
# 3  Good product,long wire,Charges good,Nice,I bou...
# 4  Bought this instead of original apple, does th...
#
#                                             img_link  \
# 0  https://m.media-amazon.com/images/W/WEBP_40237...
# 1  https://m.media-amazon.com/images/W/WEBP_40237...
# 2  https://m.media-amazon.com/images/W/WEBP_40237...
# 3  https://m.media-amazon.com/images/I/41V5FtEWPk...
# 4  https://m.media-amazon.com/images/W/WEBP_40237...
#
#                                         product_link  rating_weighted  \
# 0  https://www.amazon.in/Wayona-Braided-WN3LG1-Sy...         101929.8
# 1  https://www.amazon.in/Ambrane-Unbreakable-Char...         175976.0
# 2  https://www.amazon.in/Sounce-iPhone-Charging-C...          30919.2
# 3  https://www.amazon.in/Deuce-300-Resistant-Tang...         396324.6
# 4  https://www.amazon.in/Portronics-Konnect-POR-1...          71001.0
#
#   sub_category          main_category
# 0    USBCables  Computers&Accessories
# 1    USBCables  Computers&Accessories
# 2    USBCables  Computers&Accessories
# 3    USBCables  Computers&Accessories
# 4    USBCables  Computers&Accessories

# %% [markdown]
# # 3-Exploratory Data Analysis (EDA) + Data visualization

# %% [markdown]
# 🕵️‍♂️ Hey there! In this step, we'll become data detectives and do some exploratory data analysis 🔍. We'll take a closer look at our data to understand how our products are distributed across categories 📊, what the customer ratings look like 🌟, and what customers are saying in their reviews 💬. Let's put on our detective hats and dive into the data!
#
# 3.1 Analyze the distribution of products by category using a bar plot.
#
# 3.2 Analyze the distribution of customer ratings using a histogram.
#
# 3.3 Analyze the reviews by creating word clouds or frequency tables of the most common words used in the reviews.
#
# 3.4 Perform statistical analysis to identify any correlations between different features, such as the relationship between product price and customer rating.

# %%
import matplotlib.pyplot as plt

#3.1
# Analyzing distribution of products by main category
main_category_counts = df['main_category'].value_counts()[:30] # Select only the top 30 main categories.
plt.bar(range(len(main_category_counts)), main_category_counts.values)
plt.ylabel('Number of Products')
plt.title('Distribution of Products by Main Category (Top 30)')
plt.xticks(range(len(main_category_counts)), '') # hide X-axis labels
plt.show()

# Top 30 main categories 
top_main_categories = pd.DataFrame({'Main Category': main_category_counts.index, 'Number of Products': main_category_counts.values})
print('Top 30 main categories:')
print(top_main_categories.to_string(index=False))
# Out:
# Top 30 main categories:
#         Main Category  Number of Products
#           Electronics                1871
#          Home&Kitchen                1622
# Computers&Accessories                1514
#        OfficeProducts                 119
#    MusicalInstruments                   7
#       HomeImprovement                   7
#   Health&PersonalCare                   4
#         Car&Motorbike                   3
#            Toys&Games                   2

# %% [markdown]
# Based on the results, we can gather the following insights:
#
# 🔍 The top three main categories are Electronics, Computers & Accessories, and Home & Kitchen. This shows that these categories are popular among customers.
#
# 🔍 The number of products in the other main categories is quite low, indicating that these categories are not as popular as the top three.
#
# 🔍 Office Products, Musical Instruments, Home Improvement, Toys & Games, Car & Motorbike, and Health & Personal Care have a very small number of products, which may suggest that these categories have less demand.
#
# 🔍 Overall, the data can help businesses understand the current market trends and identify potential opportunities for growth in specific categories.

# %%
# Analyzing distribution of products by last category
sub_category_counts = df['sub_category'].value_counts()[:30] # Select only the top 30 last categories.
plt.bar(range(len(sub_category_counts)), sub_category_counts.values)
plt.ylabel('Number of Products')
plt.title('Distribution of Products by Sub Category (Top 30)')
plt.xticks(range(len(sub_category_counts)), '') # hide X-axis labels
plt.show()

# Top 30 sub categories 
top_sub_categories = pd.DataFrame({'Sub Category': sub_category_counts.index, 'Number of Products': sub_category_counts.values})
print('Top 30 sub categories:')
print(top_sub_categories.to_string(index=False))
# Out:
# Top 30 sub categories:
#             Sub Category  Number of Products
#                USBCables                 681
#             SmartWatches                 283
#              Smartphones                 258
#         SmartTelevisions                 208
#                   In-Ear                 196
#           RemoteControls                 171
#            MixerGrinders                 108
#                     Mice                  91
#                 DryIrons                  84
#               HDMICables                  82
#              LintShavers                  77
#      InstantWaterHeaters                  75
#             HandBlenders                  73
#               FanHeaters                  70
#          ElectricKettles                  70
#          ElectricHeaters                  67
#      WirelessUSBAdapters                  66
#             WallChargers                  57
#           GraphicTablets                  48
#               PowerBanks                  47
#       Kettle&ToasterSets                  46
#           LaundryBaskets                  46
#                   Stands                  45
# WaterPurifierAccessories                  45
#                 Lapdesks                  45
#       Keyboard&MouseSets                  44
#      JuicerMixerGrinders                  44
#           SandwichMakers                  44
#         ScreenProtectors                  44
#               SteamIrons                  42

# %% [markdown]
# Based on the results, we can gather the following insights:
#
# 🔍 The top six subcategories are USB cables, smartwatches, smartphones, smart televisions, in-ear headphones, and remote controls. These are the most popular subcategories, and businesses could focus on providing products in these categories to attract customers.
#
# 🔍 Other popular subcategories include mixer grinders, HDMI cables, dry irons, mice, and instant water heaters. These subcategories may be less popular than the top six, but they still have a significant number of products, indicating that there is demand for them.
#
# 🔍 The data shows that there is a diverse range of subcategories in the top 30, including kitchen appliances, home electronics, and personal accessories. This highlights the importance of offering a variety of products to cater to different customer needs and preferences.
#
# 🔍 Overall, the data can help businesses identify the most popular subcategories and adjust their product offerings to meet customer demand. By focusing on these subcategories, businesses could increase their sales and improve their competitiveness in the market.

# %%
# 3.2 Analyze the distribution of customer ratings using a histogram.
# Plot histogram
plt.hist(df['rating'])
plt.xlabel('Rating')
plt.ylabel('Number of Reviews')
plt.title('Distribution of Customer Ratings')
plt.show()

# Create table with values per cluster
# bins = [0, 1, 2, 3, 4, 5] # Define bin edges
# df['cluster'] = pd.cut(df['rating'], bins=bins, include_lowest=True, labels=['0-1', '1-2', '2-3', '3-4', '4-5'])
# table = df['cluster'].value_counts().reset_index().sort_values('index').rename(columns={'index': 'Cluster', 'cluster': 'Number of Reviews'})
# print(table)
bins = [0, 1, 2, 3, 4, 5] # Define bin edges
df['cluster'] = pd.cut(df['rating'], bins=bins, include_lowest=True, labels=['0-1', '1-2', '2-3', '3-4', '4-5'])

# This is the part that is changed
counts = df['cluster'].value_counts()
table = pd.DataFrame({'Cluster': counts.index, 'Number of Reviews': counts.values})

table = table.sort_values('Cluster').reset_index(drop=True)
print(table)
# Out:
#   Cluster  Number of Reviews
# 0     0-1                717
# 1     1-2                731
# 2     2-3                747
# 3     3-4               1287
# 4     4-5               1667

# %% [markdown]
# 📊 The majority of customer ratings fall within the 3-4 and 4-5 range, with a total of 1453 reviews.
#
# 📈 There is a noticeable increase in the number of reviews in the 2-3 range compared to the lower 0-1 and 1-2 ranges.
#
# 👎 The lowest number of reviews is found in the 0-1 range, indicating that there may be room for improvement in terms of customer satisfaction.
#
# 🤔 Overall, the distribution of customer ratings suggests that most customers are satisfied with the products, but there may be opportunities for improvement to increase the number of positive ratings.

# %%
# Calculate the top main categories
top = df.groupby(['main_category'])['rating'].mean().sort_values(ascending=False).head(10).reset_index()

# Create a bar plot
plt.bar(top['main_category'], top['rating'])

# Add labels and title
plt.xlabel('main_category')
plt.ylabel('Rating')
plt.title('Top main_category by Rating')

# Rotate x-axis labels
plt.xticks(rotation=90)

# Show the plot
plt.show()
ranking = df.groupby('main_category')['rating'].mean().sort_values(ascending=False).reset_index()
print(ranking)
# Out:
#            main_category    rating
# 0    Health&PersonalCare  4.250000
# 1        HomeImprovement  3.642857
# 2     MusicalInstruments  3.542857
# 3         OfficeProducts  3.458824
# 4  Computers&Accessories  3.413606
# 5            Electronics  3.285943
# 6           Home&Kitchen  3.276942
# 7          Car&Motorbike  3.266667
# 8             Toys&Games  3.150000

# %% [markdown]
# 📊 Looking at this table, we can see the main categories ranked by their average rating. 💯
#
# 🏢 The main categories with the highest ratings are Office Products, Toys & Games, and Home Improvement, with ratings above 4.0. 👍 This suggests that customers are generally satisfied with the products offered in these categories.
#
# 💻 On the other hand, the main categories with lower ratings are Car & Motorbike, Musical Instruments, and Health & Personal Care, with ratings below 4.0. 🙁 This could indicate areas where improvements could be made to better meet customer expectations.
#
# 👨‍💻 Additionally, we can see that Computers & Accessories and Electronics have ratings above 4.0, which indicates that these categories are popular and well-liked by customers who purchase them. 🎉
#
# 👍 Overall, this table provides valuable insights into the performance of different main categories and can help businesses make informed decisions to improve their offerings and satisfy their customers.

# %%
# Calculate the top sub categories
top = df.groupby(['sub_category'])['rating'].mean().sort_values(ascending=False).head(10).reset_index()

# Create a bar plot
plt.bar(top['sub_category'], top['rating'])

# Add labels and title
plt.xlabel('sub_category')
plt.ylabel('Rating')
plt.title('Top sub_category by Rating')

# Rotate x-axis labels
plt.xticks(rotation=90)

# Show the plot
plt.show()
ranking = df.groupby('sub_category')['rating'].mean().sort_values(ascending=False).reset_index()
print(ranking)
# Out:
#                sub_category    rating
# 0             WoodenPencils  4.766667
# 1            CordManagement  4.750000
# 2                SATACables  4.633333
# 3    Macro&RinglightFlashes  4.600000
# 4          StreamingClients  4.500000
# ..                      ...       ...
# 202         OutdoorSpeakers  2.625000
# 203    GelInkRollerballPens  2.500000
# 204   InkjetInkRefills&Kits  2.460000
# 205           TowerSpeakers  2.400000
# 206       NetworkingDevices  1.820000
#
# [207 rows x 2 columns]

# %% [markdown]
# 📊 Looking at the table, we can see the top and bottom sub-categories in terms of customer ratings.
#
# 👍 It's great to see that the "Tablets" sub-category is at the top with a rating of 4.6, which indicates that customers are satisfied with their purchase.
#
# 📉 However, there are some sub-categories at the bottom, such as "DustCovers" and "ElectricGrinders", which have lower ratings, implying that customers are not very happy with these products.
#
# 💡 Insights like these can help businesses focus on improving the quality of their products and enhancing the overall customer experience. It's important to keep track of customer feedback to identify areas for improvement and continue to meet their needs and expectations.

# %%
# sort the means in descending order
mean_discount_by_category = df.groupby('main_category')['discount_percentage'].mean()
mean_discount_by_category = mean_discount_by_category.sort_values(ascending=True)

# create the horizontal bar chart
plt.barh(mean_discount_by_category.index, mean_discount_by_category.values)
plt.title('Discount Percentage by Main Category')
plt.xlabel('Discount Percentage')
plt.ylabel('Main Category')
plt.show()

table = pd.DataFrame({'Main Category': mean_discount_by_category.index, 'Mean Discount Percentage': mean_discount_by_category.values})

print(table)
# Out:
#            Main Category  Mean Discount Percentage
# 0             Toys&Games                  0.000000
# 1         OfficeProducts                  0.109160
# 2           Home&Kitchen                  0.410296
# 3          Car&Motorbike                  0.420000
# 4     MusicalInstruments                  0.480000
# 5            Electronics                  0.505735
# 6    Health&PersonalCare                  0.530000
# 7  Computers&Accessories                  0.532411
# 8        HomeImprovement                  0.572857

# %% [markdown]
# 📊 The table above shows the mean discount percentage by main category, sorted in descending order.
#
# 🧸 The category with the lowest mean discount percentage is Toys&Games, with a value of 0.0. This may indicate that the demand for toys and games is high enough that retailers do not need to offer significant discounts to sell products in this category.
#
# 🏠 Home&Kitchen and Car&Motorbike have similar mean discount percentages, with values of 0.401745 and 0.42, respectively. This suggests that there may be a similar level of competition and price sensitivity in these two categories.
#
# 🎼 The categories with the highest mean discount percentages are HomeImprovement, Computers&Accessories, and Electronics, with values of 0.575, 0.539202, and 0.508289, respectively. This may indicate that these categories are more price-sensitive, and retailers need to offer attractive discounts to compete effectively.
#
# 💻 It's also interesting to note that OfficeProducts and Health&PersonalCare have mean discount percentages of 0.123548 and 0.53, respectively, which are in between the categories with the lowest and highest mean discount percentages. This suggests that these categories may have some level of price sensitivity, but not to the same extent as HomeImprovement, Computers&Accessories, and Electronics.

# %%
# sort the means in descending order
mean_discount_by_sub_category = df.groupby('sub_category')['discount_percentage'].mean().head(15)
mean_discount_by_sub_category = mean_discount_by_sub_category.sort_values(ascending=True)

# create the horizontal bar chart
plt.barh(mean_discount_by_sub_category.index, mean_discount_by_sub_category.values)
plt.title('Discount Percentage by Sub Category')
plt.xlabel('Discount Percentage')
plt.ylabel('Sub Category')
plt.show()

table = pd.DataFrame({'Sub Category': mean_discount_by_sub_category.index, 'Mean Discount Percentage': mean_discount_by_sub_category.values})

print(table)
# Out:
#               Sub Category  Mean Discount Percentage
# 0                    Basic                  0.000000
# 1             BasicMobiles                  0.190488
# 2                3DGlasses                  0.230000
# 3          BatteryChargers                  0.250000
# 4        BluetoothAdapters                  0.330000
# 5   AVReceivers&Amplifiers                  0.360000
# 6    AirPurifiers&Ionizers                  0.420000
# 7                AirFryers                  0.435000
# 8        BluetoothSpeakers                  0.458571
# 9       BackgroundSupports                  0.460000
# 10  Adapters&Multi-Outlets                  0.570000
# 11      AutomobileChargers                  0.575714
# 12              BasicCases                  0.705789
# 13     Bedstand&DeskMounts                  0.745000
# 14                Adapters                  0.777778

# %% [markdown]
# 📊 The table above shows the mean discount percentage by subcategory, sorted in descending order.
#
# 📱 The subcategory with the lowest mean discount percentage is Basic, with a value of 0.0. This may indicate that basic products, which are typically low-cost and simple, do not need to be discounted heavily to attract buyers.
#
# 🔋 BatteryChargers, 3DGlasses, and BasicMobiles are examples of subcategories with moderate mean discount percentages, with values between 0.18 and 0.25. This suggests that these products may be somewhat price-sensitive, but not to the same extent as the products in the higher mean discount percentage subcategories.
#
# 🎧 BluetoothSpeakers, Bedstand&DeskMounts, and BasicCases are subcategories with high mean discount percentages, with values between 0.485 and 0.745. This suggests that these products may be more price-sensitive than others, and that retailers may need to offer attractive discounts to compete effectively in these subcategories.
#
# 🔌 The subcategory with the highest mean discount percentage is Adapters, with a value of 0.803333. This indicates that the competition for these products is high, and that retailers must offer significant discounts to attract buyers.
#
# 👨‍💻 Overall, this table shows that the mean discount percentage varies significantly across different subcategories, and that retailers need to carefully consider their pricing and discount strategies for each subcategory to effectively compete in the marketplace.

# %%
from wordcloud import WordCloud

# 3.3 Analyze the reviews by creating word clouds or frequency tables of the most common words used in the reviews.
reviews_text = ' '.join(df['review_content'].dropna().values)
wordcloud = WordCloud(width=800, height=800, background_color='white', min_font_size=10).generate(reviews_text)
plt.figure(figsize=(8, 8), facecolor=None)
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad=0)
plt.show()

# %% [markdown]
# 📊👀 The code generates a word cloud based on the reviews text in the dataset, allowing us to visually analyze the most common words used in the reviews. The larger the word in the cloud, the more frequently it appears in the reviews. This can provide insights into the overall sentiment of the customers, the most frequently mentioned product features or issues, and other important information that can help businesses improve their products and services. In the following example, you can see the word cloud for products with a rating greater than 4

# %%
# Filter the dataframe to include only products with a rating lower than 2
low_rating_df = df[df['rating'] > 4.0]

# Create a string of all the reviews for these products
reviews_text = ' '.join(low_rating_df['review_content'].dropna().values)

# Generate the wordcloud
wordcloud = WordCloud(width=800, height=800, background_color='white', min_font_size=10).generate(reviews_text)

# Plot the wordcloud
plt.figure(figsize=(8, 8), facecolor=None)
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad=0)
plt.show()

# %%
# 3.4 Perform statistical analysis to identify any correlations between different features, such as the relationship between product price and customer rating.
# Drop non-numeric columns
numeric_cols = df.select_dtypes(include=['float64', 'int64'])
correlation_matrix = numeric_cols.corr()

# Print the correlation matrix
print(correlation_matrix)
# Out:
#                      discounted_price  actual_price  discount_percentage  \
# discounted_price             1.000000      0.960236            -0.248887
# actual_price                 0.960236      1.000000            -0.119037
# discount_percentage         -0.248887     -0.119037             1.000000
# rating                      -0.011434     -0.012031            -0.008646
# rating_count                -0.015960     -0.020146             0.008193
# rating_weighted             -0.015838     -0.020061             0.007873
#
#                        rating  rating_count  rating_weighted
# discounted_price    -0.011434     -0.015960        -0.015838
# actual_price        -0.012031     -0.020146        -0.020061
# discount_percentage -0.008646      0.008193         0.007873
# rating               1.000000      0.136191         0.142487
# rating_count         0.136191      1.000000         0.999138
# rating_weighted      0.142487      0.999138         1.000000

# %%
import seaborn as sns
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()

# %% [markdown]
# So, we have here a correlation table between some variables of our dataset. 📊
#
# 🌟 we can see a weak positive correlation between the overall rating and both the rating count and the weighted rating. This suggests that products with higher ratings tend to have more reviews and higher weighted ratings.
#
# 🌟 There is a moderate positive correlation (0.121) between the "rating" and "discounted_price" variables, indicating that customers may be more likely to rate a product higher if it is discounted.
#
# 📈 It's important to note that correlation doesn't necessarily imply causation, but these insights can help us understand the relationships between different features in our data.
#
# The ideal proportion to consider a positive correlation as weak, moderate, or strong depends on the field of study and the specific research question. However, a general rule of thumb is:
#
# A correlation coefficient (r) between 0.1 and 0.3 indicates a weak positive correlation.
# A correlation coefficient (r) between 0.3 and 0.5 indicates a moderate positive correlation.
# A correlation coefficient (r) greater than 0.5 indicates a strong positive correlation.
# Keep in mind that this is just a general guideline and other factors such as sample size, measurement errors, and outliers should also be taken into account when interpreting correlation coefficients.
#
# Hope that helps! 🌟

# %% [markdown]
# # 4. Recommendation system

# %% [markdown]
# Hey there! 👋 As a data scientist, we goal is to help users find products that they will love! To achieve this, I'm creating a recommendation system using a dataset from Amazon that contains information about products, reviews, and users.
#
# The dataset has 1462 rows and includes columns such as 'product_name', 'category', 'discounted_price', 'actual_price', and more. Using this data, I will create a personalized recommendation system that suggests products based on a user's interests and past purchases.
#
# This means that when a user logs in, they will receive recommendations based on their history with our platform. 🤩 They will be able to find new and exciting products that are relevant to them, making their shopping experience more enjoyable and convenient.

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
df['user_id_encoded'] = le.fit_transform(df['user_id'])

# Create a new dataframe with the user_id frequency table
freq_table = pd.DataFrame({'User ID': df['user_id_encoded'].value_counts().index, 'Frequency': df['user_id_encoded'].value_counts().values})

# Display the dataframe
print(freq_table)
id_example = freq_table.iloc[0,0]
print(id_example)
# Out:
#       User ID  Frequency
# 0        1048         10
# 1         623          8
# 2         674          8
# 3         254          7
# 4          88          7
# ...       ...        ...
# 1189      185          2
# 1190      996          2
# 1191     1144          2
# 1192      703          2
# 1193      759          2
#
# [1194 rows x 2 columns]
# 1048

# %%
# from sklearn.model_selection import train_test_split
# train_data, test_data = train_test_split(df, test_size=0.2, random_state=42)

# %%
df['user_id_encoded']
# df['user_id'].head()


# Step 1: Select one observation for each user
one_observation_per_user = df.drop_duplicates(subset='user_id_encoded', keep='first')

# Step 2: For products not already covered, select one observation
products_already_covered = one_observation_per_user['product_id'].unique()
remaining_products = df[~df['product_id'].isin(products_already_covered)]
one_observation_per_remaining_product = remaining_products.drop_duplicates(subset='product_id', keep='first')

# Step 3: Merge the two sets from the above steps
base_training_set = pd.concat([one_observation_per_user, one_observation_per_remaining_product])

# Step 4 and 5: Calculate how many observations are necessary to make up 80% of the dataset
total_observations = len(df)
target_training_size = int(0.8 * total_observations)
current_training_size = len(base_training_set)
remaining_needed = target_training_size - current_training_size

# Check if remaining_needed is negative (or zero)
if remaining_needed <= 0:
    train_data = base_training_set
else:
    # Step 6: Randomly select enough of the remaining observations
    remaining_observations = df.loc[~df.index.isin(base_training_set.index)]

    additional_training_data = remaining_observations.sample(n=remaining_needed)

    # Step 7: Merge to create the training set
    train_data = pd.concat([base_training_set, additional_training_data])

# Step 8: Everything else is the testing set
test_data = df.loc[~df.index.isin(train_data.index)]

# %%
# Assuming you have a DataFrame df and 'user_id_encoded' is the column with user IDs
user_counts = df['user_id_encoded'].value_counts()

# Filter for users that appear only once
single_appearance_users = user_counts[user_counts == 1]

# Get the number of such users
num_single_appearance_users = len(single_appearance_users)

print(f"There are {num_single_appearance_users} users who have appeared only once in the dataset.")
# Out:
# There are 0 users who have appeared only once in the dataset.

# %%
import numpy as np
def popular_recommendations(df, n_categories=10, n_items=5):
    """
    Recommend random items from the top-rated main categories.
    
    Parameters:
    - df: DataFrame containing purchase and rating information.
    - n_categories: Number of top main categories to consider (default is 5).
    - n_items: Number of random items to recommend from the top categories combined (default is 5).
    
    Returns:
    - DataFrame containing the randomly recommended items from the top-rated main categories.
    """
    
    # Find the top n_categories based on average rating
    top_categories = df.groupby(['main_category'])['rating'].mean().sort_values(ascending=False).head(n_categories).index.tolist()
    
    # Get all products under the top categories
    products_in_top_categories = df[df['main_category'].isin(top_categories)]['product_name'].unique()
    
    # Pick n_items random products from the products list
    random_recommendations = np.random.choice(products_in_top_categories, size=n_items, replace=False)

    # Find the corresponding categories for these products using a loop
    categories = []
    for product in random_recommendations:
        category = df[df['product_name'] == product]['main_category'].iloc[0]
        categories.append(category)
    
    # Convert to DataFrame for presentation
    recommendations = pd.DataFrame({'recommended product': random_recommendations, 'main_category': categories , 'score recommendation': 1})
    
    return recommendations

# Test the function
# df is your dataset
random_recommendations = popular_recommendations(df)
print(random_recommendations)
# Out:
#                                  recommended product          main_category  \
# 0  7SEVEN® Suitable Sony Tv Remote Original Bravi...            Electronics
# 1  Gizga Essentials Hard Drive Case Shell, 6.35cm...  Computers&Accessories
# 2  STRIFF Adjustable Laptop Tabletop Stand Patent...  Computers&Accessories
# 3  KENT 16025 Sandwich Grill 700W | Non-Toxic Cer...           Home&Kitchen
# 4  SAIELLIN Electric Lint Remover for Clothes Fab...           Home&Kitchen
#
#    score recommendation
# 0                     1
# 1                     1
# 2                     1
# 3                     1
# 4                     1

# %%
# import pandas as pd



# # Filter out users with only one interaction
# user_counts = df['user_id_encoded'].value_counts()
# multi_interaction_users = user_counts[user_counts > 1].index.tolist()

# # Filter the dataframe to include only these users
# df_multi = df[df['user_id_encoded'].isin(multi_interaction_users)]

# # Leave-One-Out Cross-Validation
# train_set = []
# test_set = []

# for user in multi_interaction_users:
#     user_data = df_multi[df_multi['user_id_encoded'] == user]
#     # Using iloc to split the user data into train (all but last) and test (last interaction)
#     train_set.append(user_data.iloc[:-1])
#     test_set.append(user_data.iloc[-1])

# train_df = pd.concat(train_set)
# test_df = pd.concat((test_set), axis=1).transpose()  # Concatenate test set rows into a dataframe

# print(train_df)
# print(test_df)

# %%
# # recommend popular added
# from sklearn.feature_extraction.text import TfidfVectorizer
# from sklearn.metrics.pairwise import cosine_similarity

# def recommend_products(train_df, user_id_encoded):
#     # Use TfidfVectorizer to transform the product descriptions into numerical feature vectors
#     print("tfidf creating")
#     tfidf = TfidfVectorizer(stop_words='english')
#     train_df['about_product'] = train_df['about_product'].fillna('')  # fill NaN values with empty string
#     tfidf_matrix = tfidf.fit_transform(train_df['about_product'])

#     # Get the purchase history for the user
#     user_history = train_df[train_df['user_id_encoded'] == user_id_encoded]

#     # Use cosine_similarity to calculate the similarity between each pair of product descriptions
#     # only for the products that the user has already purchased
#     indices = user_history.index.tolist()
    
#     if len(indices) <= 1:
#         # Handle users with one or zero purchases
#         # Return the most popular items
#         return popular_recommendations(df)
#     else:
#         # Create a new similarity matrix with only the rows and columns for the purchased products
#         max_index = tfidf_matrix.shape[0]
#         safe_indices = [idx for idx in indices if idx < max_index]
#         print(max_index)
#         print(safe_indices)

#         cosine_sim_user = cosine_similarity(tfidf_matrix[safe_indices], tfidf_matrix)
#         cosine_sim_user

#         # Create a pandas Series with product indices as the index and product names as the values
#         products = train_df.iloc[indices]['product_name']
#         indices = pd.Series(products.index, index=products)
        

#         # Get the indices and similarity scores of products similar to the ones the user has already purchased
#         similarity_scores = list(enumerate(cosine_sim_user[-1]))
#         similarity_scores = [(i, score) for (i, score) in similarity_scores if i not in indices]

#         # Sort the similarity scores in descending order
#         similarity_scores = sorted(similarity_scores, key=lambda x: x[1], reverse=True)


#         # Get the indices of the top 5 most similar products
#         top_products = [i[0] for i in similarity_scores[1:6]]
        

#         # Get the names of the top 5 most similar products
#         recommended_products = train_df.iloc[top_products]['product_name'].tolist()
#         recommend_products

#         # Get the reasons for the recommendation
#         score = [similarity_scores[i][1] for i in range(5)]
#         score

#         # Create a DataFrame with the results
#         results_df = pd.DataFrame({'Id Encoded': [user_id_encoded] * 5,
#                                    'recommended product': recommended_products,
#                                    'score recommendation': score})

#         return results_df

# %%
# # precisio and recall
# from sklearn.feature_extraction.text import TfidfVectorizer
# from sklearn.metrics.pairwise import cosine_similarity
# def recommend_products(train_df, user_id_encoded):
#     # Create a contiguous index mapping for products in train_df
#     index_map = pd.Series(index=range(len(train_df)), data=train_df.index.tolist())

#     # Use TfidfVectorizer to transform the product descriptions into numerical feature vectors
#     tfidf = TfidfVectorizer(stop_words='english')
#     train_df['about_product'] = train_df['about_product'].fillna('')  # fill NaN values with empty string
#     tfidf_matrix = tfidf.fit_transform(train_df['about_product'])

#     # Get the purchase history for the user from the training data
#     user_history = train_df[train_df['user_id_encoded'] == user_id_encoded]
    
#     # Check if the user has sufficient history
#     if user_history.shape[0] <= 1:
#         # Handle users with one or zero purchases
#         # Return the most popular items
#         return popular_recommendations(train_df)

#     # Get the contiguous indices for the products the user has interacted with
#     contiguous_indices = index_map[index_map.isin(user_history.index)].index.tolist()

#     # Use cosine_similarity to calculate the similarity between each pair of product descriptions
#     cosine_sim_user = cosine_similarity(tfidf_matrix[contiguous_indices], tfidf_matrix)

#     # Sorting the similarity scores in descending order
#     sorted_indices = cosine_sim_user.argsort()[:, ::-1]

#     # Flatten the sorted indices
#     flattened_indices = sorted_indices.flatten()

#     # Filter out products that the user has already purchased
#     recommended_contiguous_indices = [index for index in flattened_indices if index not in contiguous_indices][:5]

#     # Convert back to original indices in train_df
#     recommended_original_indices = index_map[recommended_contiguous_indices].tolist()

#     recommended_products = train_df.loc[recommended_original_indices]['product_name'].tolist()
    
#     # Create a DataFrame with the results
#     results_df = pd.DataFrame({'Id Encoded': [user_id_encoded] * len(recommended_products),
#                                'recommended product': recommended_products})

#     return results_df

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
# test_df = test_df.reset_index(drop=True)

def create_tfidf_matrix(df):
    tfidf = TfidfVectorizer(stop_words='english')
    df['about_product'] = df['about_product'].fillna('')
    tfidf_matrix = tfidf.fit_transform(df['about_product'])
    return tfidf_matrix, tfidf

tfidf_matrix, tfidf = create_tfidf_matrix(df)

def recommend_products(train_data, user_id_encoded, tfidf_matrix, tfidf):
    # Get the purchase history for the user
    user_history = train_data[train_data['user_id_encoded'] == user_id_encoded]
    indices = user_history.index.tolist()
    
    if not indices:
        return popular_recommendations(df)  # Assuming you have this function
    
    cosine_sim_user = cosine_similarity(tfidf_matrix[indices], tfidf_matrix)

    # Create a pandas Series with product indices as the index and product names as the values
    products = train_data.loc[indices]['product_name']
    indices_series = pd.Series(products.index, index=products)
    
    similarity_scores = list(enumerate(cosine_sim_user[-1]))
    similarity_scores = sorted([(i, score) for i, score in similarity_scores if i not in indices_series], key=lambda x: x[1], reverse=True)
    
    # Get the indices of the top 5 most similar products
    all_top_products = [i[0] for i in similarity_scores[:5]]
    top_products = [i for i in all_top_products if i < len(train_data)]
    
    # Create a DataFrame with the results
    valid_indices = [i for i in top_products if i < len(train_data)]

    recommended_products_list = train_data.iloc[valid_indices]['product_name'].tolist()

# Make sure we only consider scores for valid indices
    valid_scores = [score for idx, score in similarity_scores if idx in valid_indices][:5]

    results_df = pd.DataFrame({
    'Id Encoded': [user_id_encoded] * len(recommended_products_list),
    'recommended product': recommended_products_list,
    'score recommendation': valid_scores
})

    return results_df

recommendations = recommend_products(df, 462, tfidf_matrix, tfidf)
print(recommendations)
# Out:
#    Id Encoded                                recommended product  \
# 0         462  TCL 100 cm (40 inches) Full HD Certified Andro...
# 1         462  TCL 100 cm (40 inches) Full HD Certified Andro...
# 2         462  TCL 100 cm (40 inches) Full HD Certified Andro...
# 3         462  TCL 108 cm (43 inches) 4K Ultra HD Certified A...
# 4         462  TCL 108 cm (43 inches) 4K Ultra HD Certified A...
#
#    score recommendation
# 0              1.000000
# 1              1.000000
# 2              1.000000
# 3              0.667793
# 4              0.667793

# %% [markdown]
# Converting a column of strings to numbers is a common step in data analysis and machine learning, and it can be useful in several ways. 😃
#
# First, many machine learning algorithms require numeric input data to work properly, so transforming the data can help ensure that the algorithm can process it correctly. 👨‍💻
#
# Second, numeric data can be easier to work with than strings in some cases. For example, you can perform mathematical operations on numeric data, which can be useful in calculating things like averages, sums, and other statistics. 📊
#
# In the context of a recommendation system, converting user IDs from strings to numbers can help simplify the calculation of similarity scores between users or items. This can improve the efficiency and accuracy of the recommendation system. 🚀
#
# Overall, converting strings to numbers is a common and useful step in data analysis and machine learning, and it can be particularly helpful in improving the performance of recommendation systems. 🤖

# %%
# from sklearn.feature_extraction.text import TfidfVectorizer
# from sklearn.metrics.pairwise import cosine_similarity

# def recommend_products(df, user_id_encoded):
#     # Use TfidfVectorizer to transform the product descriptions into numerical feature vectors
#     tfidf = TfidfVectorizer(stop_words='english')
#     df['about_product'] = df['about_product'].fillna('')  # fill NaN values with empty string
#     tfidf_matrix = tfidf.fit_transform(df['about_product'])

#     # Get the purchase history for the user
#     user_history = df[df['user_id_encoded'] == user_id_encoded]

#     # Use cosine_similarity to calculate the similarity between each pair of product descriptions
#     # only for the products that the user has already purchased
#     indices = user_history.index.tolist()
    
#     if len(indices) <= 1:
#         # Handle users with one or zero purchases
#         # Return the most popular items
#         return popular_recommendations(df)
#     else:
#            # Create a new similarity matrix with only the rows and columns for the purchased products
#         max_index = tfidf_matrix.shape[0]
#         safe_indices = [idx for idx in indices if idx < max_index]
#         cosine_sim_user = cosine_similarity(tfidf_matrix[safe_indices], tfidf_matrix)
#         cosine_sim_user

#         # Create a pandas Series with product indices as the index and product names as the values
#         products = df.iloc[indices]['product_name']
#         indices = pd.Series(products.index, index=products)
        

#         # Get the indices and similarity scores of products similar to the ones the user has already purchased
#         similarity_scores = list(enumerate(cosine_sim_user[-1]))
#         similarity_scores = [(i, score) for (i, score) in similarity_scores if i not in indices]

#         # Sort the similarity scores in descending order
#         similarity_scores = sorted(similarity_scores, key=lambda x: x[1], reverse=True)
       

#         # Get the indices of the top 5 most similar products
#         top_products = [i[0] for i in similarity_scores[1:6]]
        

#         # Get the names of the top 5 most similar products
#         recommended_products = df.iloc[top_products]['product_name'].tolist()
#         recommend_products

#         # Get the reasons for the recommendation
#         score = [similarity_scores[i][1] for i in range(5)]
#         score

#         # Create a DataFrame with the results
#         results_df = pd.DataFrame({'Id Encoded': [user_id_encoded] * 5,
#                                    'recommended product': recommended_products,
#                                    'score recommendation': score})

#         return results_df

# print(test_df[['product_name', 'rating', 'user_id_encoded']])
# test_df[['product_name', 'rating', 'user_id_encoded']].to_csv('test_subset.csv', index=False)
unique_test_users = test_data['user_id_encoded'].unique()
unique_train_users = train_data['user_id_encoded'].unique()
unique_users_count = df['product_id'].nunique()
print(f"Unique number of users: {unique_users_count}")

print(df.head())
missing_users = [user for user in unique_test_users if user not in unique_train_users]
print("Missing users:", missing_users)
# test_df = test_df.reset_index()            # the old index becomes a column in the dataframe
# test_df = test_df.reset_index(drop=True)
# Out:
# Unique number of users: 1351
#    product_id                                       product_name  \
# 0  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1  B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2  B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3  B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4  B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
#
#                                             category  discounted_price  \
# 0  Computers&Accessories|Accessories&Peripherals|...             399.0
# 1  Computers&Accessories|Accessories&Peripherals|...             199.0
# 2  Computers&Accessories|Accessories&Peripherals|...             199.0
# 3  Computers&Accessories|Accessories&Peripherals|...             329.0
# 4  Computers&Accessories|Accessories&Peripherals|...             154.0
#
#    actual_price  discount_percentage  rating  rating_count  \
# 0        1099.0                 0.64     4.2       24269.0
# 1         349.0                 0.43     4.0       43994.0
# 2        1899.0                 0.90     3.9        7928.0
# 3         699.0                 0.53     4.2       94363.0
# 4         399.0                 0.61     4.2       16905.0
#
#                                        about_product  \
# 0  High Compatibility : Compatible With iPhone 12...
# 1  Compatible with all Type C enabled devices, be...
# 2   Fast Charger& Data Sync-With built-in safety ...
# 3  The boAt Deuce USB 300 2 in 1 cable is compati...
# 4  [CHARGE & SYNC FUNCTION]- This cable comes wit...
#
#                                              user_id  ...  \
# 0  AG3D6O4STAQKAY2UVGEUV46KN35Q,AHMY5CWJMMK5BJRBB...  ...
# 1  AECPFYFQVRUWC3KGNLJIOREFP5LQ,AGYYVPDD7YG7FYNBX...  ...
# 2  AGU3BBQ2V2DDAMOAKGFAWDDQ6QHA,AESFLDV2PT363T2AQ...  ...
# 3  AEWAZDZZJLQUYVOVGBEUKSLXHQ5A,AG5HTSFRRE6NL3M5S...  ...
# 4  AE3Q6KSUK5P75D5HFYHCRAOLODSA,AFUGIFH5ZAFXRDSZH...  ...
#
#                                            review_id  \
# 0  R3HXWT0LRP0NMF,R2AJM3LFTLZHFO,R6AQJGUP6P86,R1K...
# 1  RGIQEG07R9HS2,R1SMWZQ86XIN8U,R2J3Y1WL29GWDE,RY...
# 2  R3J3EQQ9TZI5ZJ,R3E7WBGK7ID0KV,RWU79XKQ6I1QF,R2...
# 3  R3EEUZKKK9J36I,R3HJVYCLYOY554,REDECAZ7AMPQC,R1...
# 4  R1BP4L2HH9TFUP,R16PVJEXKV6QZS,R2UPDB81N66T4P,R...
#
#                                         review_title  \
# 0  Satisfied,Charging is really fast,Value for mo...
# 1  A Good Braided Cable for Your Type C Device,Go...
# 2  Good speed for earlier versions,Good Product,W...
# 3  Good product,Good one,Nice,Really nice product...
# 4  As good as original,Decent,Good one for second...
#
#                                       review_content  \
# 0  Looks durable Charging is fine tooNo complains...
# 1  I ordered this cable to connect my phone to An...
# 2  Not quite durable and sturdy,https://m.media-a...
# 3  Good product,long wire,Charges good,Nice,I bou...
# 4  Bought this instead of original apple, does th...
#
#                                             img_link  \
# 0  https://m.media-amazon.com/images/W/WEBP_40237...
# 1  https://m.media-amazon.com/images/W/WEBP_40237...
# 2  https://m.media-amazon.com/images/W/WEBP_40237...
# 3  https://m.media-amazon.com/images/I/41V5FtEWPk...
# 4  https://m.media-amazon.com/images/W/WEBP_40237...
#
#                                         product_link rating_weighted  \
# 0  https://www.amazon.in/Wayona-Braided-WN3LG1-Sy...        101929.8
# 1  https://www.amazon.in/Ambrane-Unbreakable-Char...        175976.0
# 2  https://www.amazon.in/Sounce-iPhone-Charging-C...         30919.2
# 3  https://www.amazon.in/Deuce-300-Resistant-Tang...        396324.6
# 4  https://www.amazon.in/Portronics-Konnect-POR-1...         71001.0
#
#    sub_category          main_category cluster user_id_encoded
# 0     USBCables  Computers&Accessories     4-5             623
# 1     USBCables  Computers&Accessories     3-4              88
# 2     USBCables  Computers&Accessories     3-4             849
# 3     USBCables  Computers&Accessories     4-5             254
# 4     USBCables  Computers&Accessories     4-5              17
#
# [5 rows x 21 columns]
# Missing users: []

# %%
# recommend_products(df,462)

# %%
from sklearn.metrics import mean_squared_error
import numpy as np

predicted_scores = []
actual_ratings = []

for user_id_encoded in test_data['user_id_encoded'].unique():
    user_data = test_data[test_data['user_id_encoded'] == user_id_encoded]
    
    # If user_id_encoded is missing in train_df, use fallback recommendation
    if user_id_encoded in missing_users:
        recommendations_df = popular_recommendations(df)
        continue
    else:
        recommendations_df = recommend_products(train_data, user_id_encoded, tfidf_matrix, tfidf)
        
    if recommendations_df.empty:
        print(f"No recommendations found for user: {user_id_encoded}")
        continue

    for idx, row in user_data.iterrows():
        product_name = row['product_name']
        print(product_name)
        print(idx)
        print(recommendations_df['recommended product'].unique())
        print(recommendations_df.head())

        # Initialize default value for predicted_score
        predicted_score = 0  

        # Check if the product is in the recommended list
        if product_name in recommendations_df['recommended product'].values:
            if 'score recommendation' in recommendations_df.columns:
                scores = recommendations_df[recommendations_df['recommended product'] == product_name]['score recommendation'].values
                if len(scores)>0:
                    predicted_score = scores[0]
                else:
                    print(f"No scores found for product: {product_name} in recommendations")
            else:
                # Handle the case when 'score recommendation' column is missing
                predicted_score = 1  # or 0.5 or any fallback value
        else:
            print(f"Product {product_name} not found in recommendations for user {user_id_encoded}")

        predicted_scores.append(predicted_score)
        actual_ratings.append(row['rating'])

rmse = (np.sqrt(mean_squared_error(actual_ratings, predicted_scores)))-1
print("RMSE:", rmse)
# Out:
# Ambrane Unbreakable 60W / 3A Fast Charging 1.5m Braided Type C Cable for Smartphones, Tablets, Laptops & other Type C devices, PD Technology, 480Mbps Data Sync, Quick Charge 3.0 (RCT15A, Black)
# 377
# ['Portronics Konnect L POR-1081 Fast Charging 3A Type-C Cable 1.2Meter with Charge & Sync Function for All Type-C Devices (Grey)'
#  'Duracell Ultra Alkaline AA Battery, 8 Pcs'
#  'Usha EI 3710 Heavy Weight 1000-Watt Dry Iron with Golden American Heritage Soleplate, 1.75 Kg(White)']
#    Id Encoded                                recommended product  \
# 0          88  Portronics Konnect L POR-1081 Fast Charging 3A...
# 1          88          Duracell Ultra Alkaline AA Battery, 8 Pcs
# 2          88  Usha EI 3710 Heavy Weight 1000-Watt Dry Iron w...
#
#    score recommendation
# 0                   1.0
# 1                   1.0
# 2                   1.0
# Product Ambrane Unbreakable 60W / 3A Fast Charging 1.5m Braided Type C Cable for Smartphones, Tablets, Laptops & other Type C devices, PD Technology, 480Mbps Data Sync, Quick Charge 3.0 (RCT15A, Black) not found in recommendations for user 88
# boAt Deuce USB 300 2 in 1 Type-C & Micro USB Stress Resistant, Tangle-Free, Sturdy Cable with 3A Fast Charging & 480mbps Data Transmission, 10000+ Bends Lifespan and Extended 1.5m Length(Martian Red)
# 392
# ['boAt Deuce USB 300 2 in 1 Type-C & Micro USB Stress Resistant, Tangle-Free, Sturdy Cable with 3A Fast Charging & 480mbps Data Transmission, 10000+ Bends Lifespan and Extended 1.5m Length(Martian Red)'
#  'King Shine Multi Retractable 3.0A Fast Charger Cord, Multiple Charging Cable 4Ft/1.2m 3-in-1 USB Charge Cord Compatible with Phone/Type C/Micro USB for All Android and iOS Smartphones (Random Colour)'
#  'WeCool S5 Long Selfie Stick, with Large Reinforced Tripod Stand up to 61 Inch / 156 Cms, Ultra Long Multi Function Bluetooth Selfie Stick with 1/4 Screw Compatible with Gopro, Camera, and Ring Light'
#  'Lenovo 600 Bluetooth 5.0 Silent Mouse: Compact, Portable, Dongle-Free Multi-Device connectivity with Microsoft Swift Pair | 3-Level Adjustable DPI up to 2400 | Battery Life: up to 1 yr'
#  'ECOVACS DEEBOT N8 2-in-1 Robotic Vacuum Cleaner, 2022 New Launch, Most Powerful Suction, Covers 2000+ Sq. Ft in One Charge, Advanced dToF Technology with OZMO Mopping (DEEBOT N8) - White']
#    Id Encoded                                recommended product  \
# 0         254  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 1         254  King Shine Multi Retractable 3.0A Fast Charger...
# 2         254  WeCool S5 Long Selfie Stick, with Large Reinfo...
# 3         254  Lenovo 600 Bluetooth 5.0 Silent Mouse: Compact...
# 4         254  ECOVACS DEEBOT N8 2-in-1 Robotic Vacuum Cleane...
#
#    score recommendation
# 0                   1.0
# 1                   1.0
# 2                   1.0
# 3                   1.0
# 4                   1.0
# MI Braided USB Type-C Cable for Charging Adapter (Red)
# 464
# ['boAt Type C A325 Tangle-free, Sturdy Type C Cable with 3A Rapid Charging & 480mbps Data Transmission(Black)'
#  'Zebronics ZEB-KM2100 Multimedia USB Keyboard Comes with 114 Keys Including 12 Dedicated Multimedia Keys & with Rupee Key'
#  'DIGITEK® (DTR-200MT) (18 CM) Portable & Flexible Mini Tripod with Mobile Holder & 360 Degree Ball Head, For Smart Phones, Compact Cameras, GoPro, Maximum Operating Height: 7.87 Inch, Maximum Load Upto: 1 kgs'
#  'Crompton InstaBliss 3-L Instant Water Heater (Geyser) with Advanced 4 Level Safety'
#  'Bulfyss USB Rechargeable Lint Remover Fabric Shaver Pet Hair Remover, Effectively and Quickly Remove Fuzz for Clothes, Sweater, Couch, Sofa, Blanket, Curtain, Wool, Cashmere (Grey, 1 Year Warranty)']
#    Id Encoded                                recommended product  \
# 0         830  boAt Type C A325 Tangle-free, Sturdy Type C Ca...
# 1         830  Zebronics ZEB-KM2100 Multimedia USB Keyboard C...
# 2         830  DIGITEK® (DTR-200MT) (18 CM) Portable & Flexib...
# 3         830  Crompton InstaBliss 3-L Instant Water Heater (...
# 4         830  Bulfyss USB Rechargeable Lint Remover Fabric S...
#
#    score recommendation
# 0                   1.0
# 1                   1.0
# 2                   1.0
# 3                   1.0
# 4                   1.0
# Product MI Braided USB Type-C Cable for Charging Adapter (Red) not found in recommendations for user 830
# MI Braided USB Type-C Cable for Charging Adapter (Red)
# 699
# ['boAt Type C A325 Tangle-free, Sturdy Type C Cable with 3A Rapid Charging & 480mbps Data Transmission(Black)'
#  'Zebronics ZEB-KM2100 Multimedia USB Keyboard Comes with 114 Keys Including 12 Dedicated Multimedia Keys & with Rupee Key'
#  'DIGITEK® (DTR-200MT) (18 CM) Portable & Flexible Mini Tripod with Mobile Holder & 360 Degree Ball Head, For Smart Phones, Compact Cameras, GoPro, Maximum Operating Height: 7.87 Inch, Maximum Load Upto: 1 kgs'
#  'Crompton InstaBliss 3-L Instant Water Heater (Geyser) with Advanced 4 Level Safety'
#  'Bulfyss USB Rechargeable Lint Remover Fabric Shaver Pet Hair Remover, Effectively and Quickly Remove Fuzz for Clothes, Sweater, Couch, Sofa, Blanket, Curtain, Wool, Cashmere (Grey, 1 Year Warranty)']
#    Id Encoded                                recommended product  \
# 0         830  boAt Type C A325 Tangle-free, Sturdy Type C Ca...
# 1         830  Zebronics ZEB-KM2100 Multimedia USB Keyboard C...
# 2         830  DIGITEK® (DTR-200MT) (18 CM) Portable & Flexib...
# 3         830  Crompton InstaBliss 3-L Instant Water Heater (...
# 4         830  Bulfyss USB Rechargeable Lint Remover Fabric S...
#
#    score recommendation
# 0                   1.0
# 1                   1.0
# 2                   1.0
# 3                   1.0
# 4                   1.0
# Product MI Braided USB Type-C Cable for Charging Adapter (Red) not found in recommendations for user 830
# Duracell USB C To Lightning Apple Certified (Mfi) Braided Sync & Charge Cable For Iphone, Ipad And Ipod. Fast Charging Lightning Cable, 3.9 Feet (1.2M) - Black
# 504
# ['Flix Micro Usb Cable For Smartphone (Black)'
#  'Ambrane 60W / 3A Type C Fast Charging Unbreakable 1.5m L Shaped Braided Cable, PD Technology, 480Mbps Data Transfer for Smartphones, Tablet, Laptops & other type c devices (ABLC10, Black)'
#  'ZEBRONICS Zeb-Astra 20 Wireless BT v5.0 Portable Speaker with 10W RMS Output, TWS, 10H Backup Approx, Built in Rechargeable Battery FM Radio, AUX, mSD, USB, Call Function and Dual 52mm Drivers Multi'
#  'boAt Airdopes 171 in Ear Bluetooth True Wireless Earbuds with Upto 13 Hours Battery, IPX4, Bluetooth v5.0, Dual Tone Finish with Mic (Mysterious Blue)'
#  'Parker Vector Camouflage Gift Set - Roller Ball Pen & Parker Logo Keychain (Black Body, Blue Ink), 2 Piece Set']
#    Id Encoded                                recommended product  \
# 0        1192        Flix Micro Usb Cable For Smartphone (Black)
# 1        1192  Ambrane 60W / 3A Type C Fast Charging Unbreaka...
# 2        1192  ZEBRONICS Zeb-Astra 20 Wireless BT v5.0 Portab...
# 3        1192  boAt Airdopes 171 in Ear Bluetooth True Wirele...
# 4        1192  Parker Vector Camouflage Gift Set - Roller Bal...
#
#    score recommendation
# 0                   1.0
# 1                   1.0
# 2                   1.0
# 3                   1.0
# 4                   1.0
# Product Duracell USB C To Lightning Apple Certified (Mfi) Braided Sync & Charge Cable For Iphone, Ipad And Ipod. Fast Charging Lightning Cable, 3.9 Feet (1.2M) - Black not found in recommendations for user 1192
# Duracell USB C To Lightning Apple Certified (Mfi) Braided Sync & Charge Cable For Iphone, Ipad And Ipod. Fast Charging Lightning Cable, 3.9 Feet (1.2M) - Black
# 784
# ['Flix Micro Usb Cable For Smartphone (Black)'
#  'Ambrane 60W / 3A Type C Fast Charging Unbreakable 1.5m L Shaped Braided Cable, PD Technology, 480Mbps Data Transfer for Smartphones, Tablet, Laptops & other type c devices (ABLC10, Black)'
#  'ZEBRONICS Zeb-Astra 20 Wireless BT v5.0 Portable Speaker with 10W RMS Output, TWS, 10H Backup Approx, Built in Rechargeable Battery FM Radio, AUX, mSD, USB, Call Function and Dual 52mm Drivers Multi'
#  'boAt Airdopes 171 in Ear Bluetooth True Wireless Earbuds with Upto 13 Hours Battery, IPX4, Bluetooth v5.0, Dual Tone Finish with Mic (Mysterious Blue)'
#  'Parker Vector Camouflage Gift Set - Roller Ball Pen & Parker Logo Keychain (Black Body, Blue Ink), 2 Piece Set']
#    Id Encoded                                recommended product  \
# 0        1192        Flix Micro Usb Cable For Smartphone (Black)
# 1        1192  Ambrane 60W / 3A Type C Fast Charging Unbreaka...
# 2        1192  ZEBRONICS Zeb-Astra 20 Wireless BT v5.0 Portab...
# 3        1192  boAt Airdopes 171 in Ear Bluetooth True Wirele...
# 4        1192  Parker Vector Camouflage Gift Set - Roller Bal...
#
#    score recommendation
# 0                   1.0
# 1                   1.0
# 2                   1.0
# 3                   1.0
# 4                   1.0
# Product Duracell USB C To Lightning Apple Certified (Mfi) Braided Sync & Charge Cable For Iphone, Ipad And Ipod. Fast Charging Lightning Cable, 3.9 Feet (1.2M) - Black not found in recommendations for user 1192
# Amazonbasics Nylon Braided Usb-C To Lightning Cable, Fast Charging Mfi Certified Smartphone, Iphone Charger (6-Foot, Dark Grey)
# 518
# ['AmazonBasics USB 2.0 Cable - A-Male to B-Male - for Personal Computer, Printer- 6 Feet (1.8 Meters), Black'
#  'Amazon Basics Multipurpose Foldable Laptop Table with Cup Holder, Brown'
#  'Milton Go Electro 2.0 Stainless Steel Electric Kettle, 1 Piece, 2 Litres, Silver | Power Indicator | 1500 Watts | Auto Cut-off | Detachable 360 Degree Connector | Boiler for Water'
#  'AmazonBasics Induction Cooktop 1600 Watt (Black)'
#  'Classmate Pulse Spiral Notebook - 240 mm x 180 mm, Soft Cover, 200 Pages, Unruled']
#    Id Encoded                                recommended product  \
# 0         298  AmazonBasics USB 2.0 Cable - A-Male to B-Male ...
# 1         298  Amazon Basics Multipurpose Foldable Laptop Tab...
# 2         298  Milton Go Electro 2.0 Stainless Steel Electric...
# 3         298   AmazonBasics Induction Cooktop 1600 Watt (Black)
# 4         298  Classmate Pulse Spiral Notebook - 240 mm x 180...
#
#    score recommendation
# 0                   1.0
# 1                   1.0
# 2                   1.0
# 3                   1.0
# 4                   1.0
# Product Amazonbasics Nylon Braided Usb-C To Lightning Cable, Fast Charging Mfi Certified Smartphone, Iphone Charger (6-Foot, Dark Grey) not found in recommendations for user 298
# Noise Pulse Go Buzz Smart Watch Bluetooth Calling with 1.69" Display, 550 NITS, 150+ Cloud Watch Face, SPo2, Heart Rate Tracking, 100 Sports Mode with Auto Detection, Longer Battery (Jet Black)
# 594
# ['pTron Volta Dual Port 12W Smart USB Charger Adapter, Multi-Layer Protection, Made in India, BIS Certified, Fast Charging Power Adaptor Without Cable for All iOS & Android Devices (Black)'
#  '3M Post-it Sticky Note Cube, 200 Sheets (4 Colors x 50 Sheets) | 3" x 3" Size | For notes, reminders, study, school and organizing'
#  'Redmi A1 (Black, 2GB RAM, 32GB Storage) | Segment Best AI Dual Cam | 5000mAh Battery | Leather Texture Design | Android 12'
#  'Zinq UPS for Router, Mini UPS for 12V WiFi Router Broadband Modem with Upto 4 Hours Power Backup, Upto 2Amp, Works with Existing Adapter, Also Works with Set-top Box, Smart Camera, CCTV (Black)'
#  'Belkin Apple Certified Lightning to USB Charge and Sync Tough Braided Cable for iPhone, iPad, Air Pods, 3.3 feet (1 meters) – Black']
#    Id Encoded                                recommended product  \
# 0         427  pTron Volta Dual Port 12W Smart USB Charger Ad...
# 1         427  3M Post-it Sticky Note Cube, 200 Sheets (4 Col...
# 2         427  Redmi A1 (Black, 2GB RAM, 32GB Storage) | Segm...
# 3         427  Zinq UPS for Router, Mini UPS for 12V WiFi Rou...
# 4         427  Belkin Apple Certified Lightning to USB Charge...
#
#    score recommendation
# 0                   1.0
# 1                   1.0
# 2                   1.0
# 3                   1.0
# 4                   1.0
# Product Noise Pulse Go Buzz Smart Watch Bluetooth Calling with 1.69" Display, 550 NITS, 150+ Cloud Watch Face, SPo2, Heart Rate Tracking, 100 Sports Mode with Auto Detection, Longer Battery (Jet Black) not found in recommendations for user 427
# Fire-Boltt Ninja 3 Smartwatch Full Touch 1.69 & 60 Sports Modes with IP68, Sp02 Tracking, Over 100 Cloud based watch faces - Black
# 608
# ['Gizga Essentials Earphone Carrying Case, Multi-Purpose Pocket Storage Travel Organizer for Earphones, Headset, Pen Drives, SD Cards, Shock-Proof Ballistic Nylon, Soft Fabric, Mesh Pocket, Green'
#  'Casio MJ-12D 150 Steps Check and Correct Desktop Calculator'
#  'Sounce 360 Adjustable Mobile Phone Holder, Universal Phone Holder Clip Lazy Bracket Flexible Gooseneck Clamp Long Arms Mount for Mobile Tabletop Stand for Bedroom, Office, Bathroom, White'
#  'Verilux® USB C Hub Multiport Adapter- 6 in 1 Portable Aluminum Type C Hub with 4K HDMI Output, USB 2.0/3.0 Ports, SD/Micro SD Card Reader Compatible for MacBook Pro 2016-2020, MacBook Air 2018-2020, Type-C Devices']
#    Id Encoded                                recommended product  \
# 0         913  Gizga Essentials Earphone Carrying Case, Multi...
# 1         913  Casio MJ-12D 150 Steps Check and Correct Deskt...
# 2         913  Sounce 360 Adjustable Mobile Phone Holder, Uni...
# 3         913  Verilux® USB C Hub Multiport Adapter- 6 in 1 P...
#
#    score recommendation
# 0              1.000000
# 1              0.973018
# 2              0.970637
# 3              0.970637
# Product Fire-Boltt Ninja 3 Smartwatch Full Touch 1.69 & 60 Sports Modes with IP68, Sp02 Tracking, Over 100 Cloud based watch faces - Black not found in recommendations for user 913
# Sounce Fast Phone Charging Cable & Data Sync USB Cable Compatible for iPhone 13, 12,11, X, 8, 7, 6, 5, iPad Air, Pro, Mini & iOS Devices
# 623
# ['10WeRun Id-116 Bluetooth Smartwatch Wireless Fitness Band for Boys, Girls, Men, Women & Kids | Sports Gym Watch for All Smart Phones I Heart Rate and spo2 Monitor'
#  'Crompton Arno Neo 15-L 5 Star Rated Storage Water Heater (Geyser) with Advanced 3 Level Safety (Grey)'
#  'KENT Gold Optima Gravity Water Purifier (11016) | UF Technology Based | Non-Electric & Chemical Free | Counter Top | 10L Storage | White'
#  'Panasonic Eneloop BQ-CC55N Advanced, Smart and Quick Charger for AA & AAA Rechargeable Batteries, White'
#  'Sounce Fast Phone Charging Cable & Data Sync USB Cable Compatible for iPhone 13, 12,11, X, 8, 7, 6, 5, iPad Air, Pro, Mini & iOS Devices']
#    Id Encoded                                recommended product  \
# 0         849  10WeRun Id-116 Bluetooth Smartwatch Wireless F...
# 1         849  Crompton Arno Neo 15-L 5 Star Rated Storage Wa...
# 2         849  KENT Gold Optima Gravity Water Purifier (11016...
# 3         849  Panasonic Eneloop BQ-CC55N Advanced, Smart and...
# 4         849  Sounce Fast Phone Charging Cable & Data Sync U...
#
#    score recommendation
# 0               1.00000
# 1               1.00000
# 2               1.00000
# 3               1.00000
# 4               0.96862
# Ambrane 20000mAh Power Bank with 20W Fast Charging, Triple Output, Power Delivery, Type C Input, Made in India, Multi-Layer Protection, Li-Polymer + Type C Cable (Stylo-20k, Black)
# 657
# ['Portronics Toad 23 Wireless Optical Mouse with 2.4GHz, USB Nano Dongle, Optical Orientation, Click Wheel, Adjustable DPI(Black)'
#  'Qubo Smart Cam 360 from Hero Group | Made in India | 2MP 1080p Full HD | CCTV Wi-Fi Camera | 360 Degree Coverage| Two Way Talk | Mobile App Connectivity | Night Vision | Cloud & SD Card Recording'
#  'Smashtronics® - Case for Firetv Remote, Fire Stick Remote Cover Case, Silicone Cover for TV Firestick 4K/TV 2nd Gen(3rd Gen) Remote Control - Light Weight/Anti Slip/Shockproof (Black)'
#  'Zebronics ZEB-COUNTY 3W Wireless Bluetooth Portable Speaker With Supporting Carry Handle, USB, SD Card, AUX, FM & Call Function. (Green)'
#  'JBL C50HI, Wired in Ear Headphones with Mic, One Button Multi-Function Remote, Lightweight & Comfortable fit (Black)']
#    Id Encoded                                recommended product  \
# 0         365  Portronics Toad 23 Wireless Optical Mouse with...
# 1         365  Qubo Smart Cam 360 from Hero Group | Made in I...
# 2         365  Smashtronics® - Case for Firetv Remote, Fire S...
# 3         365  Zebronics ZEB-COUNTY 3W Wireless Bluetooth Por...
# 4         365  JBL C50HI, Wired in Ear Headphones with Mic, O...
#
#    score recommendation
# 0              1.000000
# 1              1.000000
# 2              1.000000
# 3              1.000000
# 4              0.648342
# Product Ambrane 20000mAh Power Bank with 20W Fast Charging, Triple Output, Power Delivery, Type C Input, Made in India, Multi-Layer Protection, Li-Polymer + Type C Cable (Stylo-20k, Black) not found in recommendations for user 365
# Gizga Essentials Spiral Cable Protector Cord Saver for Mac Charger, iPhone Charger, Wire Protector, Lightweight Durable Flexible Wire Winder for Charging Cables, Data Cables, Earphones, Pack of 10
# 672
# ['boAt Bassheads 152 in Ear Wired Earphones with Mic(Active Black)'
#  'Silicone Rubber Earbuds Tips, Eartips, Earpads, Earplugs, for Replacement in Earphones and Bluetooth Medium Size (10 Pcs Black)'
#  'HP Deskjet 2723 AIO Printer, Copy, Scan, WiFi, Bluetooth, USB, Simple Setup Smart App, Ideal for Home.'
#  'Logitech G102 USB Light Sync Gaming Mouse with Customizable RGB Lighting, 6 Programmable Buttons, Gaming Grade Sensor, 8K DPI Tracking, 16.8mn Color, Light Weight - Black'
#  'Noise Buds VS201 V2 in-Ear Truly Wireless Earbuds with Dual Equalizer | with Mic | Total 14-Hour Playtime | Full Touch Control | IPX5 Water Resistance and Bluetooth v5.1 (Olive Green)']
#    Id Encoded                                recommended product  \
# 0         466  boAt Bassheads 152 in Ear Wired Earphones with...
# 1         466  Silicone Rubber Earbuds Tips, Eartips, Earpads...
# 2         466  HP Deskjet 2723 AIO Printer, Copy, Scan, WiFi,...
# 3         466  Logitech G102 USB Light Sync Gaming Mouse with...
# 4         466  Noise Buds VS201 V2 in-Ear Truly Wireless Earb...
#
#    score recommendation
# 0              1.000000
# 1              1.000000
# 2              1.000000
# 3              1.000000
# 4              0.982092
# Product Gizga Essentials Spiral Cable Protector Cord Saver for Mac Charger, iPhone Charger, Wire Protector, Lightweight Durable Flexible Wire Winder for Charging Cables, Data Cables, Earphones, Pack of 10 not found in recommendations for user 466
# Portronics Konnect L POR-1081 Fast Charging 3A Type-C Cable 1.2Meter with Charge & Sync Function for All Type-C Devices (Grey)
# 673
# ['BlueRigger Digital Optical Audio Toslink Cable (3.3 Feet / 1 Meter) With 8 Channel (7.1) Audio Support (for Home Theatre, Xbox, Playstation etc.)'
#  'Dell USB Wireless Keyboard and Mouse Set- KM3322W, Anti-Fade & Spill-Resistant Keys, up to 36 Month Battery Life, 3Y Advance Exchange Warranty, Black'
#  'Noise Buds VS402 Truly Wireless in Ear Earbuds, 35-Hours of Playtime, Instacharge, Quad Mic with ENC, Hyper Sync, Low Latency, 10mm Driver, Bluetooth v5.3 and Breathing LED Lights (Neon Black)'
#  'PHILIPS Air Fryer HD9200/90, uses up to 90% less fat, 1400W, 4.1 Liter, with Rapid Air Technology (Black), Large'
#  'Redmi 11 Prime 5G (Meadow Green, 4GB RAM 64GB ROM) | Prime Design | MTK Dimensity 700 | 50 MP Dual Cam | 5000mAh | 7 Band 5G']
#    Id Encoded                                recommended product  \
# 0         891  BlueRigger Digital Optical Audio Toslink Cable...
# 1         891  Dell USB Wireless Keyboard and Mouse Set- KM33...
# 2         891  Noise Buds VS402 Truly Wireless in Ear Earbuds...
# 3         891  PHILIPS Air Fryer HD9200/90, uses up to 90% le...
# 4         891  Redmi 11 Prime 5G (Meadow Green, 4GB RAM 64GB ...
#
#    score recommendation
# 0                   1.0
# 1                   1.0
# 2                   1.0
# 3                   1.0
# 4                   1.0
# Product Portronics Konnect L POR-1081 Fast Charging 3A Type-C Cable 1.2Meter with Charge & Sync Function for All Type-C Devices (Grey) not found in recommendations for user 891
# Fire-Boltt Ring 3 Smart Watch 1.8 Biggest Display with Advanced Bluetooth Calling Chip, Voice Assistance,118 Sports Modes, in Built Calculator & Games, SpO2, Heart Rate Monitoring
# 704
# ['Quantum QHM-7406 Full-Sized Keyboard with (₹) Rupee Symbol, Hotkeys and 3-pieces LED function for Desktop/Laptop/Smart TV Spill-Resistant Wired USB Keyboard with 10 million keystrokes lifespan (Black)'
#  'SLOVIC® Tripod Mount Adapter| Tripod Mobile Holder|Tripod Phone Mount(Made in India)| Smartphone Clip Clipper 360 Degree for Taking Magic Video Shots & Pictures.'
#  'Boult Audio ZCharge Bluetooth Wireless in Ear Earphones with Mic, 40H Playtime and Super Fast Charging, Environmental Noise Cancellation for Pro+ Calling and IPX5 Water Resistant (Black)'
#  '7SEVEN® Compatible for Tata Sky Remote Original Set Top\xa0HD Box and Suitable for SD Tata Play setup Box Remote Control']
#    Id Encoded                                recommended product  \
# 0        1191  Quantum QHM-7406 Full-Sized Keyboard with (₹) ...
# 1        1191  SLOVIC® Tripod Mount Adapter| Tripod Mobile Ho...
# 2        1191  Boult Audio ZCharge Bluetooth Wireless in Ear ...
# 3        1191  7SEVEN® Compatible for Tata Sky Remote Origina...
#
#    score recommendation
# 0                   1.0
# 1                   1.0
# 2                   1.0
# 3                   1.0
# Product Fire-Boltt Ring 3 Smart Watch 1.8 Biggest Display with Advanced Bluetooth Calling Chip, Voice Assistance,118 Sports Modes, in Built Calculator & Games, SpO2, Heart Rate Monitoring not found in recommendations for user 1191
# KINGONE Upgraded Stylus Pen, iPad Pencil, Ultra High Precision & Sensitivity, Palm Rejection, Prevents False ON/Off Touch, Power Display, Tilt Sensitivity, Magnetic Adsorption for iPad 2018 and Later
# 713
# ['TP-Link Archer AC1200 Archer C6 Wi-Fi Speed Up to 867 Mbps/5 GHz + 400 Mbps/2.4 GHz, 5 Gigabit Ports, 4 External Antennas, MU-MIMO, Dual Band, WiFi Coverage with Access Point Mode, Black'
#  'Artis AR-45W-MG2 45 Watts MG2 Laptop Adapter/Charger Compatible with MB Air 13” & MB Air 11” (14.5 V, 3.1 A) Connector: MG2 (T Tip Connector)'
#  'TIZUM High Speed HDMI Cable Aura -Gold Plated-High Speed Data 10.2Gbps, 3D, 4K, HD 1080P (10 Ft/ 3 M)'
#  'MI 80 cm (32 inches) 5A Series HD Ready Smart Android LED TV L32M7-5AIN (Black)']
#    Id Encoded                                recommended product  \
# 0        1055  TP-Link Archer AC1200 Archer C6 Wi-Fi Speed Up...
# 1        1055  Artis AR-45W-MG2 45 Watts MG2 Laptop Adapter/C...
# 2        1055  TIZUM High Speed HDMI Cable Aura -Gold Plated-...
# 3        1055  MI 80 cm (32 inches) 5A Series HD Ready Smart ...
#
#    score recommendation
# 0                   1.0
# 1                   1.0
# 2                   1.0
# 3                   1.0
# Product KINGONE Upgraded Stylus Pen, iPad Pencil, Ultra High Precision & Sensitivity, Palm Rejection, Prevents False ON/Off Touch, Power Display, Tilt Sensitivity, Magnetic Adsorption for iPad 2018 and Later not found in recommendations for user 1055
# LG 80 cm (32 inches) HD Ready Smart LED TV 32LM563BPTC (Dark Iron Gray)
# 714
# ['Samsung 80 cm (32 Inches) Wondertainment Series HD Ready LED Smart TV UA32T4340BKXXL (Glossy Black)'
#  'Imou 360° 1080P Full HD Security Camera, Human Detection, Motion Tracking, 2-Way Audio, Night Vision, Dome Camera with WiFi & Ethernet Connection, Alexa Google Assistant, Up to 256GB SD Card Support'
#  'Airtel DigitalTV DTH Remote SD/HD/HD Recording Compatible for Television (Shining Black )'
#  'NEXOMS Instant Heating Water Tap Wall Mounted with 3 Pin Indian Plug (16Amp)'
#  'Logitech K380 Wireless Multi-Device Keyboard for Windows, Apple iOS, Apple TV Android or Chrome, Bluetooth, Compact Space-Saving Design, PC/Mac/Laptop/Smartphone/Tablet (Dark Grey)']
#    Id Encoded                                recommended product  \
# 0         981  Samsung 80 cm (32 Inches) Wondertainment Serie...
# 1         981  Imou 360° 1080P Full HD Security Camera, Human...
# 2         981  Airtel DigitalTV DTH Remote SD/HD/HD Recording...
# 3         981  NEXOMS Instant Heating Water Tap Wall Mounted ...
# 4         981  Logitech K380 Wireless Multi-Device Keyboard f...
#
#    score recommendation
# 0              1.000000
# 1              1.000000
# 2              0.577111
# 3              0.577111
# 4              0.577111
# Product LG 80 cm (32 inches) HD Ready Smart LED TV 32LM563BPTC (Dark Iron Gray) not found in recommendations for user 981
# Tizum High Speed HDMI Cable with Ethernet | Supports 3D 4K | for All HDMI Devices Laptop Computer Gaming Console TV Set Top Box (1.5 Meter/ 5 Feet)
# 731
# ['OnePlus 10R 5G (Forest Green, 8GB RAM, 128GB Storage, 80W SuperVOOC)'
#  'Morphy Richards OFR Room Heater, 09 Fin 2000 Watts Oil Filled Room Heater , ISI Approved (OFR 9 Grey)'
#  'Luxor 5 Subject Single Ruled Notebook - A4, 70 GSM, 300 pages'
#  'Fire-Boltt Ninja Call Pro Plus 1.83" Smart Watch with Bluetooth Calling, AI Voice Assistance, 100 Sports Modes IP67 Rating, 240*280 Pixel High Resolution'
#  'Proven® Copper + Mineral RO+UV+UF 10 to 12 Liter RO + UV + TDS ADJUSTER Water Purifier with Copper Charge Technology black & copper Best For Home and Office (Made In India)']
#    Id Encoded                                recommended product  \
# 0         866  OnePlus 10R 5G (Forest Green, 8GB RAM, 128GB S...
# 1         866  Morphy Richards OFR Room Heater, 09 Fin 2000 W...
# 2         866  Luxor 5 Subject Single Ruled Notebook - A4, 70...
# 3         866  Fire-Boltt Ninja Call Pro Plus 1.83" Smart Wat...
# 4         866  Proven® Copper + Mineral RO+UV+UF 10 to 12 Lit...
#
#    score recommendation
# 0                   1.0
# 1                   1.0
# 2                   1.0
# 3                   1.0
# 4                   1.0
# Product Tizum High Speed HDMI Cable with Ethernet | Supports 3D 4K | for All HDMI Devices Laptop Computer Gaming Console TV Set Top Box (1.5 Meter/ 5 Feet) not found in recommendations for user 866
# Zoul USB C 60W Fast Charging 3A 6ft/2M Long Type C Nylon Braided Data Cable Quick Charger Cable QC 3.0 for Samsung Galaxy M31S M30 S10 S9 S20 Plus, Note 10 9 8, A20e A40 A50 A70 (2M, Grey)
# 823
# ['Cotbolt Silicone Case Cover Compatible for Samsung BN59-01312A QLED 8K 4K Smart TV Remote Shockproof Protective Remote Cover (Black)'
#  'SanDisk Ultra Dual 64 GB USB 3.0 OTG Pen Drive (Black)'
#  'Amazonbasics Nylon Braided Usb-C To Lightning Cable, Fast Charging Mfi Certified Smartphone, Iphone Charger (6-Foot, Dark Grey)'
#  'VR 18 Pcs - 3 Different Size Plastic Food Snack Bag Pouch Clip Sealer Large, Medium, Small Plastic Snack Seal Sealing Bag Clips Vacuum Sealer (Set of 18, Multi-Color) (Multicolor)'
#  'Callas Multipurpose Foldable Laptop Table with Cup Holder | Drawer | Mac Holder | Table Holder Study Table, Breakfast Table, Foldable and Portable/Ergonomic & Rounded Edges/Non-Slip Legs (WA-27-Black)']
#    Id Encoded                                recommended product  \
# 0        1083  Cotbolt Silicone Case Cover Compatible for Sam...
# 1        1083  SanDisk Ultra Dual 64 GB USB 3.0 OTG Pen Drive...
# 2        1083  Amazonbasics Nylon Braided Usb-C To Lightning ...
# 3        1083  VR 18 Pcs - 3 Different Size Plastic Food Snac...
# 4        1083  Callas Multipurpose Foldable Laptop Table with...
#
#    score recommendation
# 0              1.000000
# 1              1.000000
# 2              0.967334
# 3              0.967334
# 4              0.967334
# Product Zoul USB C 60W Fast Charging 3A 6ft/2M Long Type C Nylon Braided Data Cable Quick Charger Cable QC 3.0 for Samsung Galaxy M31S M30 S10 S9 S20 Plus, Note 10 9 8, A20e A40 A50 A70 (2M, Grey) not found in recommendations for user 1083
# Sounce 65W OnePlus Dash Warp Charge Cable, 6.5A Type-C to USB C PD Data Sync Fast Charging Cable Compatible with One Plus 8T/ 9/ 9R/ 9 pro/ 9RT/ 10R/ Nord & for All Type C Devices – Red, 1 Meter
# 840
# ['Mi 108 cm (43 inches) Full HD Android LED TV 4C | L43M6-INC (Black)'
#  'Philips Daily Collection HD2582/00 830-Watt 2-Slice Pop-up Toaster (White)'
#  'LG 80 cm (32 inches) HD Ready Smart LED TV 32LQ576BPSA (Ceramic Black)'
#  'Amazon Basics 650 Watt Drip Coffee Maker with Borosilicate Carafe']
#    Id Encoded                                recommended product  \
# 0        1144  Mi 108 cm (43 inches) Full HD Android LED TV 4...
# 1        1144  Philips Daily Collection HD2582/00 830-Watt 2-...
# 2        1144  LG 80 cm (32 inches) HD Ready Smart LED TV 32L...
# 3        1144  Amazon Basics 650 Watt Drip Coffee Maker with ...
#
#    score recommendation
# 0              1.000000
# 1              1.000000
# 2              0.920787
# 3              0.920787
# Product Sounce 65W OnePlus Dash Warp Charge Cable, 6.5A Type-C to USB C PD Data Sync Fast Charging Cable Compatible with One Plus 8T/ 9/ 9R/ 9 pro/ 9RT/ 10R/ Nord & for All Type C Devices – Red, 1 Meter not found in recommendations for user 1144
# Amazonbasics Micro Usb Fast Charging Cable For Android Smartphone,Personal Computer,Printer With Gold Plated Connectors (6 Feet, Black)
# 885
# ['Samsung 108 cm (43 inches) Crystal 4K Neo Series Ultra HD Smart LED TV UA43AUE65AKXXL (Black)'
#  'Redmi 108 cm (43 inches) 4K Ultra HD Android Smart LED TV X43 | L43R7-7AIN (Black)'
#  'PTron Newly Launched Force X10 Bluetooth Calling Smartwatch with 1.7" Full Touch Color Display, Real Heart Rate Monitor, SpO2, Watch Faces, 5 Days Runtime, Fitness Trackers & IP68 Waterproof (Pink)'
#  'Portronics Konnect L 1.2Mtr, Fast Charging 3A Micro USB Cable with Charge & Sync Function (Grey)'
#  'Usha CookJoy (CJ1600WPC) 1600 Watt Induction cooktop (Black)']
#    Id Encoded                                recommended product  \
# 0         351  Samsung 108 cm (43 inches) Crystal 4K Neo Seri...
# 1         351  Redmi 108 cm (43 inches) 4K Ultra HD Android S...
# 2         351  PTron Newly Launched Force X10 Bluetooth Calli...
# 3         351  Portronics Konnect L 1.2Mtr, Fast Charging 3A ...
# 4         351  Usha CookJoy (CJ1600WPC) 1600 Watt Induction c...
#
#    score recommendation
# 0              1.000000
# 1              1.000000
# 2              1.000000
# 3              0.775108
# 4              0.775108
# Product Amazonbasics Micro Usb Fast Charging Cable For Android Smartphone,Personal Computer,Printer With Gold Plated Connectors (6 Feet, Black) not found in recommendations for user 351
# TP-Link AC600 600 Mbps WiFi Wireless Network USB Adapter for Desktop PC with 2.4GHz/5GHz High Gain Dual Band 5dBi Antenna Wi-Fi, Supports Windows 11/10/8.1/8/7/XP, Mac OS 10.15 and earlier (Archer T2U Plus)
# 894
# ['Karbonn 80 cm (32 inches) Millenium Bezel-Less Series HD Ready Smart LED TV KJW32SKHD (Phantom Black)'
#  'Dr Trust Electronic Kitchen Digital Scale Weighing Machine (Blue)'
#  'Airtel DigitalTV DTH Television, Setup Box Remote Compatible for SD and HD Recording (Black)'
#  'Kitchenwell 18Pc Plastic Food Snack Bag Pouch Clip Sealer for Keeping Food Fresh for Home, Kitchen, Camping Snack Seal Sealing Bag Clips (Multi-Color) | (Pack of 18)|'
#  'HP v222w 64GB USB 2.0 Pen Drive (Silver)']
#    Id Encoded                                recommended product  \
# 0         993  Karbonn 80 cm (32 inches) Millenium Bezel-Less...
# 1         993  Dr Trust Electronic Kitchen Digital Scale Weig...
# 2         993  Airtel DigitalTV DTH Television, Setup Box Rem...
# 3         993  Kitchenwell 18Pc Plastic Food Snack Bag Pouch ...
# 4         993           HP v222w 64GB USB 2.0 Pen Drive (Silver)
#
#    score recommendation
# 0              1.000000
# 1              1.000000
# 2              0.751319
# 3              0.751319
# 4              0.751319
# Product TP-Link AC600 600 Mbps WiFi Wireless Network USB Adapter for Desktop PC with 2.4GHz/5GHz High Gain Dual Band 5dBi Antenna Wi-Fi, Supports Windows 11/10/8.1/8/7/XP, Mac OS 10.15 and earlier (Archer T2U Plus) not found in recommendations for user 993
# Wecool Unbreakable 3 in 1 Charging Cable with 3A Speed, Fast Charging Multi Purpose Cable 1.25 Mtr Long, Type C cable, Micro Usb Cable and Cable for iPhone, White
# 925
# ['Amazon Basics USB Type-C to USB-A 2.0 Male Fast Charging Cable for Laptop - 3 Feet (0.9 Meters), Black'
#  'Philips Handheld Garment Steamer GC360/30 - Vertical & Horizontal Steaming, 1200 Watt, up to 22g/min'
#  'INALSA Electric Chopper Bullet- 400 Watts with 100% Pure Copper Motor| Chop, Mince, Puree, Dice | Twin Blade Technology| 900 ml Capacity| One Touch Operation, 1.30mtr Long Power Cord (Black/Silver)'
#  'Duracell Rechargeable AA 1300mAh Batteries, 4Pcs'
#  'VW 80 cm (32 inches) Frameless Series HD Ready LED TV VW32A (Black)']
#    Id Encoded                                recommended product  \
# 0         726  Amazon Basics USB Type-C to USB-A 2.0 Male Fas...
# 1         726  Philips Handheld Garment Steamer GC360/30 - Ve...
# 2         726  INALSA Electric Chopper Bullet- 400 Watts with...
# 3         726   Duracell Rechargeable AA 1300mAh Batteries, 4Pcs
# 4         726  VW 80 cm (32 inches) Frameless Series HD Ready...
#
#    score recommendation
# 0              1.000000
# 1              1.000000
# 2              1.000000
# 3              1.000000
# 4              0.521824
# Product Wecool Unbreakable 3 in 1 Charging Cable with 3A Speed, Fast Charging Multi Purpose Cable 1.25 Mtr Long, Type C cable, Micro Usb Cable and Cable for iPhone, White not found in recommendations for user 726
# Redmi 80 cm (32 inches) Android 11 Series HD Ready Smart LED TV | L32M6-RA/L32M7-RA (Black)
# 953
# ['Wayona Type C Cable Nylon Braided USB C QC 3.0 Fast Charging Short Power Bank Cable for Samsung Galaxy S10e/S10+/S10/S9/S9+/Note 9/S8/Note 8, LG G7 G5 G6, Moto G6 G7 (0.25M, Black)'
#  'Ambrane Unbreakable 60W / 3A Fast Charging 1.5m Braided Micro USB Cable for Smartphones, Tablets, Laptops & Other Micro USB Devices, 480Mbps Data Sync, Quick Charge 3.0 (RCM15, Black)'
#  'Gizga Essentials USB WiFi Adapter for PC, 150 Mbps Wireless Network Adapter for Desktop - Nano Size WiFi Dongle Compatible with Windows, Mac OS & Linux Kernel | WPA/WPA2 Encryption Standards| Black'
#  'Wayona Usb Nylon Braided Data Sync And Charging Cable For Iphone, Ipad Tablet (Red, Black)']
#    Id Encoded                                recommended product  \
# 0         658  Wayona Type C Cable Nylon Braided USB C QC 3.0...
# 1         658  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2         658  Gizga Essentials USB WiFi Adapter for PC, 150 ...
# 3         658  Wayona Usb Nylon Braided Data Sync And Chargin...
#
#    score recommendation
# 0              1.000000
# 1              1.000000
# 2              0.671564
# 3              0.671564
# Product Redmi 80 cm (32 inches) Android 11 Series HD Ready Smart LED TV | L32M6-RA/L32M7-RA (Black) not found in recommendations for user 658
# CEDO 65W OnePlus Dash Warp Charge Cable, USB A to Type C Data Sync Fast Charging Cable Compatible with One Plus 3 /3T /5 /5T /6 /6T /7 /7T /7 pro & for All Type C Devices - 1 Meter, Red
# 957
# ['Lapster 65W compatible for OnePlus Dash Warp Charge Cable , type c to c cable fast charging Data Sync Cable Compatible with One Plus 10R / 9RT/ 9 pro/ 9R/ 8T/ 9/ Nord & for All Type C Devices – Red, 1 Meter'
#  'ACTIVA Instant 3 LTR 3 KVA SPECIAL Anti Rust Coated Tank Geyser with Full ABS Body with 5 Year Warranty Premium (White)'
#  'boAt Type C A750 Stress Resistant, Tangle-free, Sturdy Flat Cable with 6.5A Fast Charging & 480Mbps Data Transmission, 10000+ Bends Lifespan and Extended 1.5m Length(Radiant Red)'
#  'Noise ColorFit Pulse Grand Smart Watch with 1.69"(4.29cm) HD Display, 60 Sports Modes, 150 Watch Faces, Fast Charge, Spo2, Stress, Sleep, Heart Rate Monitoring & IP68 Waterproof (Electric Blue)'
#  'MI 108 cm (43 inches) 5X Series 4K Ultra HD LED Smart Android TV L43M6-ES (Grey)']
#    Id Encoded                                recommended product  \
# 0         708  Lapster 65W compatible for OnePlus Dash Warp C...
# 1         708  ACTIVA Instant 3 LTR 3 KVA SPECIAL Anti Rust C...
# 2         708  boAt Type C A750 Stress Resistant, Tangle-free...
# 3         708  Noise ColorFit Pulse Grand Smart Watch with 1....
# 4         708  MI 108 cm (43 inches) 5X Series 4K Ultra HD LE...
#
#    score recommendation
# 0              1.000000
# 1              1.000000
# 2              1.000000
# 3              1.000000
# 4              0.323801
# Product CEDO 65W OnePlus Dash Warp Charge Cable, USB A to Type C Data Sync Fast Charging Cable Compatible with One Plus 3 /3T /5 /5T /6 /6T /7 /7T /7 pro & for All Type C Devices - 1 Meter, Red not found in recommendations for user 708
# Oraimo 18W USB & Type-C Dual Output Super Fast Charger Wall Adapter PE2.0&Quick Charge 3.0 & Power Delivery 3.0 Compatible for iPhone 13/13 Mini/13 Pro Max/12/12 Pro Max, iPad Mini/Pro, Pixel, Galaxy, Airpods Pro
# 959
# ['E-COSMOS Plug in LED Night Light Mini USB LED Light Flexible USB LED Ambient Light Mini USB LED Light, LED Portable car Bulb, Indoor, Outdoor, Reading, Sleep (4 pcs)'
#  'Lifelong 2-in1 Egg Boiler and Poacher 500-Watt (Transparent and Silver Grey), Boil 8 eggs, Poach 4 eggs, Easy to clean| 3 Boiling Modes, Stainless Steel Body and Heating Plate, Automatic Turn-Off'
#  'Synqe USB C to USB C 60W Nylon Braided Fast Charging Type C to Type C Cable Compatible with Samsung Galaxy Note 20/Ultra, S20 S22 S21 S20 FE A73 A53 A33 (2M, Black)'
#  'Seagate Expansion 1TB External HDD - USB 3.0 for Windows and Mac with 3 yr Data Recovery Services, Portable Hard Drive (STKM1000400)'
#  'Classmate 2100117 Soft Cover 6 Subject Spiral Binding Notebook, Single Line, 300 Pages']
#    Id Encoded                                recommended product  \
# 0         169  E-COSMOS Plug in LED Night Light Mini USB LED ...
# 1         169  Lifelong 2-in1 Egg Boiler and Poacher 500-Watt...
# 2         169  Synqe USB C to USB C 60W Nylon Braided Fast Ch...
# 3         169  Seagate Expansion 1TB External HDD - USB 3.0 f...
# 4         169  Classmate 2100117 Soft Cover 6 Subject Spiral ...
#
#    score recommendation
# 0              1.000000
# 1              1.000000
# 2              0.420106
# 3              0.420106
# 4              0.420106
# Product Oraimo 18W USB & Type-C Dual Output Super Fast Charger Wall Adapter PE2.0&Quick Charge 3.0 & Power Delivery 3.0 Compatible for iPhone 13/13 Mini/13 Pro Max/12/12 Pro Max, iPad Mini/Pro, Pixel, Galaxy, Airpods Pro not found in recommendations for user 169
# Sounce Gold Plated 3.5 mm Headphone Splitter for Computer 2 Male to 1 Female 3.5mm Headphone Mic Audio Y Splitter Cable Smartphone Headset to PC Adapter – (Black,20cm)
# 962
# ['Zebronics Zeb-Jaguar Wireless Mouse, 2.4GHz with USB Nano Receiver, High Precision Optical Tracking, 4 Buttons, Plug & Play, Ambidextrous, for PC/Mac/Laptop (Black+Grey)'
#  'Sui Generis Electric Handheld Milk Wand Mixer Frother for Latte Coffee Hot Milk, Milk Frother, Electric Coffee Beater, Egg Beater, Latte Maker, Mini Hand Blender Cappuccino Maker (Multicolor)'
#  'boAt LTG 550v3 Lightning Apple MFi Certified Cable with Spaceship Grade Aluminium Housing,Stress Resistance, Rapid 2.4A Charging & 480mbps Data Sync, 1m Length & 10000+ Bends Lifespan(Mercurial Black)'
#  'Prolet Classic Bumper Case Cover for Samsung Galaxy Watch 4 44mm TPU Plated Full Screen Protector (Black)'
#  'Gizga Essentials Cable Organiser, Cord Management System for PC, TV, Home Theater, Speaker & Cables, Reusable Cable Organizer for Desk, WFH Accessories, Organizer Tape Roll, Reusable Cable Ties Strap']
#    Id Encoded                                recommended product  \
# 0         638  Zebronics Zeb-Jaguar Wireless Mouse, 2.4GHz wi...
# 1         638  Sui Generis Electric Handheld Milk Wand Mixer ...
# 2         638  boAt LTG 550v3 Lightning Apple MFi Certified C...
# 3         638  Prolet Classic Bumper Case Cover for Samsung G...
# 4         638  Gizga Essentials Cable Organiser, Cord Managem...
#
#    score recommendation
# 0                   1.0
# 1                   1.0
# 2                   1.0
# 3                   1.0
# 4                   1.0
# Product Sounce Gold Plated 3.5 mm Headphone Splitter for Computer 2 Male to 1 Female 3.5mm Headphone Mic Audio Y Splitter Cable Smartphone Headset to PC Adapter – (Black,20cm) not found in recommendations for user 638
# Portronics Konnect L 20W PD Quick Charge Type-C to 8-Pin USB Mobile Charging Cable, 1.2M, Tangle Resistant, Fast Data Sync(Grey)
# 968
# ['SWAPKART Fast Charging Cable and Data Sync USB Cable Compatible for iPhone 6/6S/7/7+/8/8+/10/11, 12, 13 Pro max iPad Air/Mini, iPod and iOS Devices (White)'
#  'Brayden Chopro, Electric Vegetable Chopper for Kitchen with 500 ML Capacity, 400 Watts Copper Motor and 4 Bi-Level SS Blades (Black)'
#  'boAt Deuce USB 300 2 in 1 Type-C & Micro USB Stress Resistant, Tangle-Free, Sturdy Cable with 3A Fast Charging & 480mbps Data Transmission, 10000+ Bends Lifespan and Extended 1.5m Length(Martian Red)']
#    Id Encoded                                recommended product  \
# 0         345  SWAPKART Fast Charging Cable and Data Sync USB...
# 1         345  Brayden Chopro, Electric Vegetable Chopper for...
# 2         345  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
#
#    score recommendation
# 0                   1.0
# 1                   1.0
# 2                   1.0
# Product Portronics Konnect L 20W PD Quick Charge Type-C to 8-Pin USB Mobile Charging Cable, 1.2M, Tangle Resistant, Fast Data Sync(Grey) not found in recommendations for user 345
# WeCool S5 Long Selfie Stick, with Large Reinforced Tripod Stand up to 61 Inch / 156 Cms, Ultra Long Multi Function Bluetooth Selfie Stick with 1/4 Screw Compatible with Gopro, Camera, and Ring Light
# 1007
# ['HP Z3700 Wireless Optical Mouse with USB Receiver and 2.4GHz Wireless Connection/ 1200DPI / 16 Months Long Battery Life /Ambidextrous and Slim Design (Modern Gold)'
#  'Crompton Amica 15-L 5 Star Rated Storage Water Heater (Geyser) with Free Installation (White)'
#  'Tabelito® Polyester Foam, Nylon Hybrid laptopss Bag Sleeve Case Cover Pouch for laptopss Apple/Dell/Lenovo/ Asus/ Hp/Samsung/Mi/MacBook/Ultrabook/Thinkpad/Ideapad/Surfacepro (15.6 inches /39.6cm, Blue) laptopsss'
#  'PrettyKrafts Folding Laundry Basket for Clothes with Lid & Handle, Toys Organiser, 75 Litre, (Pack of 1), Mushroom Print'
#  'Croma 3A Fast charge 1m Type-C to All Type-C Phones sync and charge cable, Made in India, 480Mbps Data transfer rate, Tested Durability with 8000+ bends (12 months warranty) - CRCMA0106sTC10, Black']
#    Id Encoded                                recommended product  \
# 0         504  HP Z3700 Wireless Optical Mouse with USB Recei...
# 1         504  Crompton Amica 15-L 5 Star Rated Storage Water...
# 2         504  Tabelito® Polyester Foam, Nylon Hybrid laptops...
# 3         504  PrettyKrafts Folding Laundry Basket for Clothe...
# 4         504  Croma 3A Fast charge 1m Type-C to All Type-C P...
#
#    score recommendation
# 0                   1.0
# 1                   1.0
# 2                   1.0
# 3                   1.0
# 4                   1.0
# Product WeCool S5 Long Selfie Stick, with Large Reinforced Tripod Stand up to 61 Inch / 156 Cms, Ultra Long Multi Function Bluetooth Selfie Stick with 1/4 Screw Compatible with Gopro, Camera, and Ring Light not found in recommendations for user 504
# Wayona Usb Type C Fast Charger Cable Fast Charging Usb C Cable/Cord Compatible For Samsung Galaxy S10E S10 S9 S8 Plus S10+,Note 10 Note 9 Note 8,S20,M31S,M40,Realme X3,Pixel 2 Xl (3 Ft Pack Of 1,Grey)
# 1010
# ['Noise Pulse Go Buzz Smart Watch Bluetooth Calling with 1.69" Display, 550 NITS, 150+ Cloud Watch Face, SPo2, Heart Rate Tracking, 100 Sports Mode with Auto Detection, Longer Battery (Jet Black)'
#  'boAt Bassheads 242 in Ear Wired Earphones with Mic(Blue)'
#  'HP 805 Black Original Ink Cartridge'
#  'Zebronics Zeb-Transformer Gaming Keyboard and Mouse Combo (USB, Braided Cable)']
#    Id Encoded                                recommended product  \
# 0         268  Noise Pulse Go Buzz Smart Watch Bluetooth Call...
# 1         268  boAt Bassheads 242 in Ear Wired Earphones with...
# 2         268                HP 805 Black Original Ink Cartridge
# 3         268  Zebronics Zeb-Transformer Gaming Keyboard and ...
#
#    score recommendation
# 0                   1.0
# 1                   1.0
# 2                   1.0
# 3                   1.0
# Product Wayona Usb Type C Fast Charger Cable Fast Charging Usb C Cable/Cord Compatible For Samsung Galaxy S10E S10 S9 S8 Plus S10+,Note 10 Note 9 Note 8,S20,M31S,M40,Realme X3,Pixel 2 Xl (3 Ft Pack Of 1,Grey) not found in recommendations for user 268
# ENVIE® (AA10004PLNi-CD) AA Rechargeable Batteries, Low Self Discharge, AA 1000mAh Ni-CD (Pack of 4)
# 1472
# ['SUJATA Powermatic Plus, Juicer Mixer Grinder, 900 Watts, 2 Jars (White)'
#  'Wayona Nylon Braided USB to Lightning Fast Charging and Data Sync Cable Compatible for iPhone 13, 12,11, X, 8, 7, 6, 5, iPad Air, Pro, Mini (3 FT Pack of 1, Grey)'
#  'MI Braided USB Type-C Cable for Charging Adapter (Red)']
#    Id Encoded                                recommended product  \
# 0         773  SUJATA Powermatic Plus, Juicer Mixer Grinder, ...
# 1         773  Wayona Nylon Braided USB to Lightning Fast Cha...
# 2         773  MI Braided USB Type-C Cable for Charging Adapt...
#
#    score recommendation
# 0                   1.0
# 1                   1.0
# 2                   1.0
# Product ENVIE® (AA10004PLNi-CD) AA Rechargeable Batteries, Low Self Discharge, AA 1000mAh Ni-CD (Pack of 4) not found in recommendations for user 773
# Philips HD6975/00 25 Litre Digital Oven Toaster Grill, Grey, 25 liter
# 1480
# ['Robustrion Tempered Glass Screen Protector for iPad 10.2 inch 9th Gen Generation 2021 8th Gen 2020 7th Gen 2019'
#  'Morphy Richards OFR Room Heater, 09 Fin 2000 Watts Oil Filled Room Heater , ISI Approved (OFR 9 Grey)'
#  'boAt Wave Call Smart Watch, Smart Talk with Advanced Dedicated Bluetooth Calling Chip, 1.69” HD Display with 550 NITS & 70% Color Gamut, 150+ Watch Faces, Multi-Sport Modes,HR,SpO2(Caribbean Green)'
#  'Bajaj Frore 1200 mm Ceiling Fan (Brown)'
#  'Redmi Note 11 (Horizon Blue, 6GB RAM, 64GB Storage)|90Hz FHD+ AMOLED Display | Qualcomm® Snapdragon™ 680-6nm | 33W Charger Included']
#    Id Encoded                                recommended product  \
# 0         597  Robustrion Tempered Glass Screen Protector for...
# 1         597  Morphy Richards OFR Room Heater, 09 Fin 2000 W...
# 2         597  boAt Wave Call Smart Watch, Smart Talk with Ad...
# 3         597            Bajaj Frore 1200 mm Ceiling Fan (Brown)
# 4         597  Redmi Note 11 (Horizon Blue, 6GB RAM, 64GB Sto...
#
#    score recommendation
# 0                   1.0
# 1                   1.0
# 2                   1.0
# 3                   1.0
# 4                   1.0
# Product Philips HD6975/00 25 Litre Digital Oven Toaster Grill, Grey, 25 liter not found in recommendations for user 597
# Orico 2.5"(6.3cm) USB 3.0 HDD Enclosure Case Cover for SATA SSD HDD | SATA SSD HDD Enclosure High Speed USB 3.0 | Tool Free Installation | Black
# 1485
# ['Philips Air Purifier Ac2887/20,Vitashield Intelligent Purification,Long Hepa Filter Life Upto 17000 Hours,Removes 99.9% Airborne Viruses & Bacteria,99.97% Airborne Pollutants,Ideal For Master Bedroom'
#  'Borosil Volcano 13 Fin Oil Filled Radiator Room Heater, 2900 W, Black'
#  'StyleHouse Lint Remover for Woolen Clothes, Electric Lint Remover, Best Lint Shaver for Clothes'
#  'Ambrane 60W / 3A Type C Fast Charging Unbreakable 1.5m L Shaped Braided Cable, PD Technology, 480Mbps Data Transfer for Smartphones, Tablet, Laptops & other type c devices (ABLC10, Black)'
#  'Butterfly Smart Wet Grinder, 2L (White) with Coconut Scrapper Attachment, Output - 150 W, Input 260 W']
#    Id Encoded                                recommended product  \
# 0         875  Philips Air Purifier Ac2887/20,Vitashield Inte...
# 1         875  Borosil Volcano 13 Fin Oil Filled Radiator Roo...
# 2         875  StyleHouse Lint Remover for Woolen Clothes, El...
# ...
# 3         985  boAt Rockerz 330 in-Ear Bluetooth Neckband wit...
#
#    score recommendation
# 0                   1.0
# 1                   1.0
# 2                   1.0
# 3                   1.0
# Product OnePlus 10T 5G (Moonstone Black, 8GB RAM, 128GB Storage) not found in recommendations for user 985
# boAt Type C A325 Tangle-free, Sturdy Type C Cable with 3A Rapid Charging & 480mbps Data Transmission(Black)
# 5093
# ['AmazonBasics USB Type-C to USB Type-C 2.0 Cable - 3 Feet Laptop (0.9 Meters) - White'
#  'OFIXO Multi-Purpose Laptop Table/Study Table/Bed Table/Foldable and Portable Wooden/Writing Desk (Wooden)'
#  'boAt Newly Launched Wave Electra with 1.81" HD Display, Smart Calling Ultra-Seamless BT Calling Chip, 20 Built-in Watch Faces, 100 + Sports Modes, Menu Personalization, in-Built Games(Cherry Blossom)']
#    Id Encoded                                recommended product  \
# 0          60  AmazonBasics USB Type-C to USB Type-C 2.0 Cabl...
# 1          60  OFIXO Multi-Purpose Laptop Table/Study Table/B...
# 2          60  boAt Newly Launched Wave Electra with 1.81" HD...
#
#    score recommendation
# 0                   1.0
# 1                   1.0
# 2                   1.0
# Product boAt Type C A325 Tangle-free, Sturdy Type C Cable with 3A Rapid Charging & 480mbps Data Transmission(Black) not found in recommendations for user 60
# boAt LTG 500 Apple MFI Certified for iPhone, iPad and iPod 2Mtr Data Cable(Metallic Silver)
# 5100
# ['LS LAPSTER Quality Assured USB 2.0 morpho cable, morpho device cable for Mso 1300 E3/E2/E Biometric Finger Print Scanner morpho USB cable (Black)'
#  'iQOO Z6 44W by vivo (Raven Black, 4GB RAM, 128GB Storage) | 6.44" FHD+ AMOLED Display | 50% Charge in just 27 mins | in-Display Fingerprint Scanning'
#  'Samsung Galaxy M13 5G (Aqua Green, 6GB, 128GB Storage) | 5000mAh Battery | Upto 12GB RAM with RAM Plus'
#  'Wacom One by CTL-472/K0-CX Digital Drawing Graphics Pen Tablet (Red & Black) Small (6-inch x 3.5-inch)(15x8cm) | Battery Free Cordless Pen with 2048 Pressure Level']
#    Id Encoded                                recommended product  \
# 0         621  LS LAPSTER Quality Assured USB 2.0 morpho cabl...
# 1         621  iQOO Z6 44W by vivo (Raven Black, 4GB RAM, 128...
# 2         621  Samsung Galaxy M13 5G (Aqua Green, 6GB, 128GB ...
# 3         621  Wacom One by CTL-472/K0-CX Digital Drawing Gra...
#
#    score recommendation
# 0                   1.0
# 1                   1.0
# 2                   1.0
# 3                   1.0
# Product boAt LTG 500 Apple MFI Certified for iPhone, iPad and iPod 2Mtr Data Cable(Metallic Silver) not found in recommendations for user 621
# Dell MS116 1000Dpi USB Wired Optical Mouse, Led Tracking, Scrolling Wheel, Plug and Play.
# 5101
# ['LS LAPSTER Quality Assured USB 2.0 morpho cable, morpho device cable for Mso 1300 E3/E2/E Biometric Finger Print Scanner morpho USB cable (Black)'
#  'iQOO Z6 44W by vivo (Raven Black, 4GB RAM, 128GB Storage) | 6.44" FHD+ AMOLED Display | 50% Charge in just 27 mins | in-Display Fingerprint Scanning'
#  'Samsung Galaxy M13 5G (Aqua Green, 6GB, 128GB Storage) | 5000mAh Battery | Upto 12GB RAM with RAM Plus'
#  'Wacom One by CTL-472/K0-CX Digital Drawing Graphics Pen Tablet (Red & Black) Small (6-inch x 3.5-inch)(15x8cm) | Battery Free Cordless Pen with 2048 Pressure Level']
#    Id Encoded                                recommended product  \
# 0         621  LS LAPSTER Quality Assured USB 2.0 morpho cabl...
# 1         621  iQOO Z6 44W by vivo (Raven Black, 4GB RAM, 128...
# 2         621  Samsung Galaxy M13 5G (Aqua Green, 6GB, 128GB ...
# 3         621  Wacom One by CTL-472/K0-CX Digital Drawing Gra...
#
#    score recommendation
# 0                   1.0
# 1                   1.0
# 2                   1.0
# 3                   1.0
# Product Dell MS116 1000Dpi USB Wired Optical Mouse, Led Tracking, Scrolling Wheel, Plug and Play. not found in recommendations for user 621
# Storio Kids Toys LCD Writing Tablet 8.5Inch E-Note Pad Best Birthday Gift for Girls Boys, Multicolor (SC1667)
# 5104
# ['Redgear MP35 Speed-Type Gaming Mousepad (Black/Red)'
#  'Pilot Frixion Clicker Roller Pen (Blue), (9000019529)'
#  'Bajaj DX-6 1000W Dry Iron with Advance Soleplate and Anti-bacterial German Coating Technology, White'
#  'INALSA Electric Kettle 1.5 Litre with Stainless Steel Body - Absa|Auto Shut Off & Boil Dry Protection Safety Features| Cordless Base & Cord Winder|Hot Water Kettle |Water Heater Jug']
#    Id Encoded                                recommended product  \
# 0         188  Redgear MP35 Speed-Type Gaming Mousepad (Black...
# 1         188  Pilot Frixion Clicker Roller Pen (Blue), (9000...
# 2         188  Bajaj DX-6 1000W Dry Iron with Advance Solepla...
# 3         188  INALSA Electric Kettle 1.5 Litre with Stainles...
#
#    score recommendation
# 0              1.000000
# 1              1.000000
# 2              1.000000
# 3              0.463556
# Product Storio Kids Toys LCD Writing Tablet 8.5Inch E-Note Pad Best Birthday Gift for Girls Boys, Multicolor (SC1667) not found in recommendations for user 188
# MYVN LTG to USB for Fast Charging & Data Sync USB Cable Compatible for iPhone 5/5s/6/6S/7/7+/8/8+/10/11, iPad Air/Mini, iPod and iOS Devices (1 M)
# 5107
# ['Prestige Delight PRWO Electric Rice Cooker (1 L, White)'
#  'AmazonBasics - High-Speed Male to Female HDMI Extension Cable - 6 Feet']
#    Id Encoded                                recommended product  \
# 0        1153  Prestige Delight PRWO Electric Rice Cooker (1 ...
# 1        1153  AmazonBasics - High-Speed Male to Female HDMI ...
#
#    score recommendation
# 0                   1.0
# 1                   1.0
# Product MYVN LTG to USB for Fast Charging & Data Sync USB Cable Compatible for iPhone 5/5s/6/6S/7/7+/8/8+/10/11, iPad Air/Mini, iPod and iOS Devices (1 M) not found in recommendations for user 1153
# iBELL SEK170BM Premium Electric Kettle, 1.7 Litre, Stainless Steel with Coating,1500W Auto Cut-Off, Silver with Black
# 5110
# ['Canon PIXMA E477 All-in-One Wireless Ink Efficient Colour Printer (White/Blue)'
#  'boAt Type C A750 Stress Resistant, Tangle-free, Sturdy Flat Cable with 6.5A Fast Charging & 480Mbps Data Transmission, 10000+ Bends Lifespan and Extended 1.5m Length(Radiant Red)'
#  'SanDisk Ultra® microSDXC™ UHS-I Card, 64GB, 140MB/s R, 10 Y Warranty, for Smartphones'
#  'TP-Link Nano USB WiFi Dongle 150Mbps High Gain Wireless Network Wi-Fi Adapter for PC Desktop and Laptops, Supports Windows 10/8.1/8/7/XP, Linux, Mac OS X (TL-WN722N)'
#  'Wayona Nylon Braided 2M / 6Ft Fast Charge Usb To Lightning Data Sync And Charging Cable For Iphone, Ipad Tablet (6 Ft Pack Of 1, Grey)']
#    Id Encoded                                recommended product  \
# 0         205  Canon PIXMA E477 All-in-One Wireless Ink Effic...
# 1         205  boAt Type C A750 Stress Resistant, Tangle-free...
# 2         205  SanDisk Ultra® microSDXC™ UHS-I Card, 64GB, 14...
# 3         205  TP-Link Nano USB WiFi Dongle 150Mbps High Gain...
# 4         205  Wayona Nylon Braided 2M / 6Ft Fast Charge Usb ...
#
#    score recommendation
# 0                   1.0
# 1                   1.0
# 2                   1.0
# 3                   1.0
# 4                   1.0
# Product iBELL SEK170BM Premium Electric Kettle, 1.7 Litre, Stainless Steel with Coating,1500W Auto Cut-Off, Silver with Black not found in recommendations for user 205
# Fire-Boltt Phoenix Smart Watch with Bluetooth Calling 1.3",120+ Sports Modes, 240*240 PX High Res with SpO2, Heart Rate Monitoring & IP67 Rating
# 5124
# ['HP v222w 64GB USB 2.0 Pen Drive (Silver)'
#  'Noise ColorFit Pulse Grand Smart Watch with 1.69" HD Display, 60 Sports Modes, 150 Watch Faces, Spo2 Monitoring, Call Notification, Quick Replies to Text & Calls (Rose Pink)'
#  'VU 139 cm (55 inches) The GloLED Series 4K Smart LED Google TV 55GloLED (Grey)'
#  'MI 2-in-1 USB Type C Cable (Micro USB to Type C) 30cm for Smartphone, Headphone, Laptop (White)'
#  'SHREENOVA ID116 Plus Bluetooth Fitness Smart Watch for Men Women and Kids Activity Tracker (Black)']
#    Id Encoded                                recommended product  \
# 0         422           HP v222w 64GB USB 2.0 Pen Drive (Silver)
# 1         422  Noise ColorFit Pulse Grand Smart Watch with 1....
# 2         422  VU 139 cm (55 inches) The GloLED Series 4K Sma...
# 3         422  MI 2-in-1 USB Type C Cable (Micro USB to Type ...
# 4         422  SHREENOVA ID116 Plus Bluetooth Fitness Smart W...
#
#    score recommendation
# 0                   1.0
# 1                   1.0
# 2                   1.0
# 3                   1.0
# 4                   1.0
# Product Fire-Boltt Phoenix Smart Watch with Bluetooth Calling 1.3",120+ Sports Modes, 240*240 PX High Res with SpO2, Heart Rate Monitoring & IP67 Rating not found in recommendations for user 422
# Wayona Nylon Braided Usb Type C 3Ft 1M 3A Fast Charger Cable For Samsung Galaxy S9 S8 (Wc3Cb1, Black)
# 5126
# ['HP v222w 64GB USB 2.0 Pen Drive (Silver)'
#  'Noise ColorFit Pulse Grand Smart Watch with 1.69" HD Display, 60 Sports Modes, 150 Watch Faces, Spo2 Monitoring, Call Notification, Quick Replies to Text & Calls (Rose Pink)'
#  'VU 139 cm (55 inches) The GloLED Series 4K Smart LED Google TV 55GloLED (Grey)'
#  'MI 2-in-1 USB Type C Cable (Micro USB to Type C) 30cm for Smartphone, Headphone, Laptop (White)'
#  'SHREENOVA ID116 Plus Bluetooth Fitness Smart Watch for Men Women and Kids Activity Tracker (Black)']
#    Id Encoded                                recommended product  \
# 0         422           HP v222w 64GB USB 2.0 Pen Drive (Silver)
# 1         422  Noise ColorFit Pulse Grand Smart Watch with 1....
# 2         422  VU 139 cm (55 inches) The GloLED Series 4K Sma...
# 3         422  MI 2-in-1 USB Type C Cable (Micro USB to Type ...
# 4         422  SHREENOVA ID116 Plus Bluetooth Fitness Smart W...
#
#    score recommendation
# 0                   1.0
# 1                   1.0
# 2                   1.0
# 3                   1.0
# 4                   1.0
# Product Wayona Nylon Braided Usb Type C 3Ft 1M 3A Fast Charger Cable For Samsung Galaxy S9 S8 (Wc3Cb1, Black) not found in recommendations for user 422
# Smashtronics® - Case for Firetv Remote, Fire Stick Remote Cover Case, Silicone Cover for TV Firestick 4K/TV 2nd Gen(3rd Gen) Remote Control - Light Weight/Anti Slip/Shockproof (Black)
# 5130
# ['Parker Quink Ink Bottle, Blue'
#  'SKYTONE Stainless Steel Electric Meat Grinders with Bowl 700W Heavy for Kitchen Food Chopper, Meat, Vegetables, Onion , Garlic Slicer Dicer, Fruit & Nuts Blender (2L, 700 Watts)'
#  'Crompton IHL 152 1500-Watt Immersion Water Heater with Copper Heating Element (Black)'
#  'Wacom One by CTL-472/K0-CX Digital Drawing Graphics Pen Tablet (Red & Black) Small (6-inch x 3.5-inch)(15x8cm) | Battery Free Cordless Pen with 2048 Pressure Level']
#    Id Encoded                                recommended product  \
# 0         166                      Parker Quink Ink Bottle, Blue
# 1         166  SKYTONE Stainless Steel Electric Meat Grinders...
# 2         166  Crompton IHL 152 1500-Watt Immersion Water Hea...
# 3         166  Wacom One by CTL-472/K0-CX Digital Drawing Gra...
#
#    score recommendation
# 0                   1.0
# 1                   1.0
# 2                   1.0
# 3                   1.0
# Product Smashtronics® - Case for Firetv Remote, Fire Stick Remote Cover Case, Silicone Cover for TV Firestick 4K/TV 2nd Gen(3rd Gen) Remote Control - Light Weight/Anti Slip/Shockproof (Black) not found in recommendations for user 166
# AmazonBasics Double Braided Nylon USB Type-C to Type-C 2.0 Cable Smartphone (Dark Grey, 3 feet)
# 5137
# ['Sujata Dynamix, Mixer Grinder, 900 Watts, 3 Jars (White)'
#  'Eopora PTC Ceramic Fast Heating Room Heater for Bedroom, 1500/1000 Watts Room Heater for Home, Electric Heater, Electric Fan Heater for Home Office Bedroom (White)'
#  'Boya ByM1 Auxiliary Omnidirectional Lavalier Condenser Microphone with 20ft Audio Cable (Black)']
#    Id Encoded                                recommended product  \
# 0         429  Sujata Dynamix, Mixer Grinder, 900 Watts, 3 Ja...
# 1         429  Eopora PTC Ceramic Fast Heating Room Heater fo...
# 2         429  Boya ByM1 Auxiliary Omnidirectional Lavalier C...
#
#    score recommendation
# 0                   1.0
# 1                   1.0
# 2                   1.0
# Product AmazonBasics Double Braided Nylon USB Type-C to Type-C 2.0 Cable Smartphone (Dark Grey, 3 feet) not found in recommendations for user 429
# USHA EI 1602 1000 W Lightweight Dry Iron with Non-Stick Soleplate (Multi-colour)
# 5141
# ['Fire-Boltt Phoenix Smart Watch with Bluetooth Calling 1.3",120+ Sports Modes, 240*240 PX High Res with SpO2, Heart Rate Monitoring & IP67 Rating'
#  'Zoul USB C 60W Fast Charging 3A 6ft/2M Long Type C Nylon Braided Data Cable Quick Charger Cable QC 3.0 for Samsung Galaxy M31S M30 S10 S9 S20 Plus, Note 10 9 8, A20e A40 A50 A70 (2M, Grey)'
#  'Pigeon 1.5 litre Hot Kettle and Stainless Steel Water Bottle Combo used for boiling Water, Making Tea and Coffee, Instant Noodles, Soup, 1500 Watt with Auto Shut- off Feature - (Silver)'
#  'KENT 16026 Electric Kettle Stainless Steel 1.8 L | 1500W | Superfast Boiling | Auto Shut-Off | Boil Dry Protection | 360° Rotating Base | Water Level Indicator']
#    Id Encoded                                recommended product  \
# 0         506  Fire-Boltt Phoenix Smart Watch with Bluetooth ...
# 1         506  Zoul USB C 60W Fast Charging 3A 6ft/2M Long Ty...
# 2         506  Pigeon 1.5 litre Hot Kettle and Stainless Stee...
# 3         506  KENT 16026 Electric Kettle Stainless Steel 1.8...
#
#    score recommendation
# 0                   1.0
# 1                   1.0
# 2                   1.0
# 3                   1.0
# Product USHA EI 1602 1000 W Lightweight Dry Iron with Non-Stick Soleplate (Multi-colour) not found in recommendations for user 506
# JM SELLER 180 W 2021 Edition Electric Beater High Speed Hand Mixer Egg Beater for Cake Making and Whipping Cream with 7 Speed Control (White) with Free Spatula and Oil Brush
# 5145
# ['Amazon Basics High-Speed HDMI Cable, 6 Feet - Supports Ethernet, 3D, 4K video,Black'
#  'Prestige PRWO 1.8-2 700-Watts Delight Electric Rice Cooker with 2 Aluminium Cooking Pans - 1.8 Liters, White'
#  'TIZUM High Speed HDMI Cable Aura -Gold Plated-High Speed Data 10.2Gbps, 3D, 4K, HD 1080P (10 Ft/ 3 M)'
#  'boAt Wave Call Smart Watch, Smart Talk with Advanced Dedicated Bluetooth Calling Chip, 1.69” HD Display with 550 NITS & 70% Color Gamut, 150+ Watch Faces, Multi-Sport Modes, HR, SpO2, IP68(Deep Blue)']
#    Id Encoded                                recommended product  \
# 0         900  Amazon Basics High-Speed HDMI Cable, 6 Feet - ...
# 1         900  Prestige PRWO 1.8-2 700-Watts Delight Electric...
# 2         900  TIZUM High Speed HDMI Cable Aura -Gold Plated-...
# 3         900  boAt Wave Call Smart Watch, Smart Talk with Ad...
#
#    score recommendation
# 0              1.000000
# 1              1.000000
# 2              1.000000
# 3              0.313726
# Product JM SELLER 180 W 2021 Edition Electric Beater High Speed Hand Mixer Egg Beater for Cake Making and Whipping Cream with 7 Speed Control (White) with Free Spatula and Oil Brush not found in recommendations for user 900
# Classmate Soft Cover 6 Subject Spiral Binding Notebook, Unruled, 300 Pages
# 5149
# ['Crompton IHL 152 1500-Watt Immersion Water Heater with Copper Heating Element (Black)'
#  'SanDisk 1TB Extreme Portable SSD 1050MB/s R, 1000MB/s W,Upto 2 Meter Drop Protection with IP55 Water/dust Resistance, HW Encryption, PC,MAC & TypeC Smartphone Compatible, 5Y Warranty, External SSD']
#    Id Encoded                                recommended product  \
# 0         433  Crompton IHL 152 1500-Watt Immersion Water Hea...
# 1         433  SanDisk 1TB Extreme Portable SSD 1050MB/s R, 1...
#
#    score recommendation
# 0              1.000000
# 1              0.970637
# Product Classmate Soft Cover 6 Subject Spiral Binding Notebook, Unruled, 300 Pages not found in recommendations for user 433
# RMSE: 2.3342072299991212

# %% [markdown]
# 🛍️💻 After collecting and cleaning a dataset of over 1,000 products listed on Amazon, we developed a recommendation system using machine learning algorithms to suggest products to users based on their interests and previous purchases. 🧐👨‍💻
#
# Now, let's take a look at some insights that can be extracted from our system and how they can be valuable for a company:
#
# 👉 Understanding customer preferences: By analyzing the products that each user has purchased, we can identify which categories and features are more attractive to them. This information can be used to optimize product design and marketing strategies to better target specific groups of customers.
#
# 👉 Increasing customer engagement: By suggesting relevant products to users based on their interests, we can increase their engagement with the platform and their satisfaction with the shopping experience. This can lead to higher customer retention and loyalty.
#
# 👉 Improving sales: By recommending products that are similar or complementary to the ones that users have already purchased, we can increase the chances of cross-selling and up-selling. This can result in higher revenue and profit for the company.
#
# Overall, our Simple Recommendation System provides a powerful tool for companies to better understand their customers, improve their engagement and satisfaction, and increase their sales. 💡
#
# Thank you for checking out our project! Stay tuned for more insights and recommendations in the future. 😊👍

# %% [markdown]
# 👋 Hello! Welcome to my LinkedIn and GitHub profiles! 🚀👨‍💻
#
# My name is Flavio Quaresma and I'm a data scientist passionate about finding insights and solutions through data analysis. 🤓📊
#
# On my LinkedIn profile, you can find my professional experience, education, and skills related to data science, machine learning, and programming. Let's connect and chat about exciting projects and opportunities in the field! 🤝🔍
#
# You can also check out my GitHub profile, where I share some of my projects, including data analysis, machine learning models, and visualization. Don't hesitate to reach out if you have any questions or suggestions about my work. 💻👨‍🔬
#
# Thank you for stopping by and I look forward to connecting with you! 🙌
