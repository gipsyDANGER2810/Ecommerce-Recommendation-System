# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import LabelEncoder
from sqlalchemy import create_engine

# %%
# df = pd.read_csv(r"C:/Users/swapn/Desktop/for evaluation/merged_data.csv")

# %%
engine = create_engine('mysql+pymysql://root:sunny106133@localhost/project')

# Fetch data into Pandas DataFrames
products_df = pd.read_sql("SELECT * FROM products", con=engine)
users_df = pd.read_sql("SELECT * FROM users", con=engine)
reviews_df = pd.read_sql("SELECT * FROM product_reviews", con=engine)

missing_users = set(reviews_df['user_id'].unique()) - set(users_df['user_id'].unique())
missing_products = set(reviews_df['product_id'].unique()) - set(products_df['product_id'].unique())

merged_1 = pd.merge(reviews_df, products_df, how='outer', on='product_id')


merged_2 = pd.merge(merged_1, users_df, how='outer', on='user_id')
merged_df = merged_2

# %%
merged_df.fillna(value=np.nan, inplace=True)


# Now merged_df contains your merged data
df = merged_df
mask_all_nan_except_credentials = df.drop(columns=['user_id', 'user_name', 'password']).isna().all(axis=1)

# Create a mask for rows where rating and rating_count are NOT NaN.
mask_valid_ratings = ~(df['rating'].isna() | df['rating_count'].isna())

# Combine both conditions using OR (|)
final_mask = mask_all_nan_except_credentials | mask_valid_ratings

# Filter the dataframe using the combined mask
df = df[final_mask]

# %%
df['discounted_price'] = df['discounted_price'].astype(str).str.replace('₹', '').str.replace(',', '').astype(float)
df['actual_price'] = df['actual_price'].astype(str).str.replace('₹', '').str.replace(',', '').astype(float)
df['discount_percentage'] = df['discount_percentage'].astype(str).str.replace('%','').astype(float)/100
df['rating'] = df['rating'].astype(str)
count = df['rating'].str.contains('\|').sum()

df = df[df['rating'].apply(lambda x: '|' not in str(x))]
count = df['rating'].str.contains('\|').sum()


df['rating'] = df['rating'].astype(str).str.replace(',', '').astype(float)
df['rating_count'] = df['rating_count'].astype(str).str.replace(',', '').astype(float)

# %%
le = LabelEncoder()
df['user_id_encoded'] = le.fit_transform(df['user_id'])

def userIdEncoder(userID):
    uuid = userID
    encoded_value = le.transform([uuid])[0]
    return encoded_value

# %%
# Calculate the mean rating across all products
C = df['rating'].mean()

# Calculate the 90th percentile of the number of ratings
m = df['rating_count'].quantile(0.9)

# Filter out movies that have a rating count less than m
qualified_products = df[df['rating_count'] >= m]

# Compute the weighted rating for each qualified product
def weighted_rating(x, m=m, C=C):
    v = x['rating_count']
    R = x['rating']
    return (v / (v + m) * R) + (m / (v + m) * C)

# Apply the function to the DataFrame
qualified_products['weighted_rating'] = qualified_products.apply(weighted_rating, axis=1)

# Sort products based on score
qualified_products = qualified_products.sort_values('weighted_rating', ascending=False)
# Out:
# C:\Users\swapn\AppData\Local\Temp\ipykernel_18724\837953868.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   qualified_products['weighted_rating'] = qualified_products.apply(weighted_rating, axis=1)

# %%
def get_popular_products(N=5):
    # Get top N products from the sorted qualified_products DataFrame
    popular_recommendations = []
    for _, row in qualified_products.head(N).iterrows():
        model_response = {}
        model_response['product_id'] = row['product_id']
        model_response['product_name'] = row['product_name']
        model_response['img_link'] = row['img_link']
        model_response['actual_price'] = row['actual_price']
        model_response['discounted_price'] = row['discounted_price']
        model_response['discount_percentage'] = row['discount_percentage']
        popular_recommendations.append(model_response)
        
    return pd.DataFrame({'Product': popular_recommendations, 'Score': [row['weighted_rating'] for _, row in qualified_products.head(N).iterrows()]})

# %%
from sklearn.model_selection import LeavePOut

def leave_p_out_cv(df, p, user_column, item_column):
    lpo = LeavePOut(p)
    train_sets = []
    test_sets = []

    for user in df[user_column].unique():
        user_data = df[df[user_column] == user]
        
        # Ensure that the user has more than 'p' interactions
        if len(user_data) > p:
            for train_index, test_index in lpo.split(user_data):
                train = user_data.iloc[train_index]
                test = user_data.iloc[test_index]
                train_sets.append(train)
                test_sets.append(test)

    # Concatenate all the different train and test dataframes
    train_data = pd.concat(train_sets, ignore_index=True)
    test_data = pd.concat(test_sets, ignore_index=True)

    return train_data, test_data

# Example usage
p = 1
train, test = leave_p_out_cv(df, p, 'user_id', 'product_id')

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import pandas as pd
import numpy as np

def content_based_filtering(train):
    train['combined_text'] = train['about_product'].fillna('') + ' ' + train['review_title'].fillna('') + ' ' + train['review_content'].fillna('')
    index_mapping = {index: i for i, index in enumerate(train.index)}
    tfidf = TfidfVectorizer(stop_words='english')
    tfidf_matrix = tfidf.fit_transform(train['combined_text'])
    user_profiles = {}


    for user_id_encoded in train['user_id_encoded'].unique():
        user_data = train[train['user_id_encoded'] == user_id_encoded]
        tfidf_indices = [index_mapping[idx] for idx in user_data.index.tolist()]

        # Get the corresponding tf-idf vectors and ratings for the user
        user_tfidf_vectors = tfidf_matrix[tfidf_indices]
        user_ratings = user_data['rating'].values

        # Compute the weighted sum of the tf-idf vectors
        weighted_user_vector = np.sum(user_tfidf_vectors.multiply(user_ratings[:, np.newaxis]), axis=0)
        weighted_user_vector = np.asarray(weighted_user_vector).reshape(1, -1)

        if np.linalg.norm(weighted_user_vector) != 0:
            weighted_user_vector_norm = weighted_user_vector / np.linalg.norm(weighted_user_vector)
            user_profiles[user_id_encoded] = weighted_user_vector_norm
        else:
            print(f"Zero norm detected for user_id_encoded: {user_id_encoded}")
    

    def recommend_products_with_profiles(user_id_encoded):
        user_vector = user_profiles.get(user_id_encoded, None)
        if user_vector is None:
            return qualified_products

        cosine_sim_user = cosine_similarity(user_vector, tfidf_matrix)
    
        # Getting products already interacted with by the user
        interacted_products = train.loc[train['user_id_encoded'] == user_id_encoded]['product_id'].tolist()

        # Sorting the similarity scores
        similarity_scores = sorted(list(enumerate(cosine_sim_user[0])), key=lambda x: x[1], reverse=True)

        all_top_products = []
        for idx, score in similarity_scores:
            if len(all_top_products) == 5:  # break if we already have 5 recommendations
                break
            product_id = train.iloc[idx]['product_id']
            if product_id not in interacted_products and product_id not in [prod['product_id'] for prod in all_top_products]:
                all_top_products.append(train.iloc[idx])

        recommendation_response = []
        for product in all_top_products:
            model_response = {}
            model_response['product_id'] = product['product_id']
            model_response['product_name'] = product['product_name']
            model_response['img_link'] = product['img_link']
            model_response['actual_price'] = product['actual_price']
            model_response['discounted_price'] = product['discounted_price']
            model_response['discount_percentage'] = product['discount_percentage']
            recommendation_response.append(model_response)

        valid_scores = [score for idx, score in similarity_scores if train.iloc[idx]['product_id'] in [prod['product_id'] for prod in all_top_products]][:5]

        results_df = pd.DataFrame({
            'Id_Encoded': [user_id_encoded] * len(recommendation_response),
            'recommended_product': recommendation_response,
            'score_recommendation': valid_scores
        })
        
        return results_df
    return recommend_products_with_profiles, tfidf_matrix

recommender_function, tfidf_matrix_out = content_based_filtering(train)

# %%
def prerequisites_collaborative():
    # Filter users who've rated at least 1 product
    x = train.groupby('user_id_encoded').count()['rating'] > 1
    users_rated = x[x].index
    filtered_df = train[train['user_id_encoded'].isin(users_rated)]

    # Consider all products that have been rated at least once
    y = filtered_df.groupby('product_id').count()['rating'] > 1
    high_rated_products = y[y].index
    final_rating = filtered_df[filtered_df['product_id'].isin(high_rated_products)]

    # Create a user-item matrix
    pt = final_rating.pivot_table(index='user_id_encoded', columns='product_id', values='rating')

    pt.fillna(0, inplace=True)
    return pt


pt = prerequisites_collaborative()


# OGG
from sklearn.metrics.pairwise import cosine_similarity
similarity_score = cosine_similarity(pt)



def get_recommendations(user_id_encoded):
    """Return a list of recommended products for a given user."""
    if user_id_encoded not in pt.index:
        print(f"Error: user_id_encoded {user_id_encoded} not found in index.")
        return qualified_products[['product_name', 'rating', 'rating_count', 'weighted_rating']]

    # Find similar users
    index = pt.index.get_loc(user_id_encoded)
    similar_users = sorted(list(enumerate(similarity_score[index])), key=lambda x: x[1], reverse=True)[1:6]

    # Get the items that these users have interacted with
    recommended_products = {}
    for i in similar_users:
        user_id = pt.index[i[0]]
        rated_products = pt.columns[(pt.loc[user_id] > 0)].tolist()
        for product in rated_products:
            if product not in recommended_products:
                recommended_products[product] = i[1]
            else:
                recommended_products[product] += i[1]

    # Filter out products with a score of 0 and format the top products
    top_products = sorted([(product, score) for product, score in recommended_products.items() if score > 0], key=lambda x: x[1], reverse=True)[:5]

    # Extracting product details
    recommendation_response = []
    scores = []  # New list to keep track of the scores for products that weren't skipped
    for product_id, score in top_products:
        product_data = train[train['product_id'] == product_id]
        if product_data.empty:
            print(f"Warning: No data found for product_id: {product_id}")
            continue
        
        product = product_data.iloc[0]
        model_response = {}
        model_response['product_id'] = product['product_id']
        model_response['product_name'] = product['product_name']
        model_response['img_link'] = product['img_link']
        model_response['actual_price'] = product['actual_price']
        model_response['discounted_price'] = product['discounted_price']
        model_response['discount_percentage'] = product['discount_percentage']
        recommendation_response.append(model_response)
        scores.append(score)  # Add the score for this product

    # Now use the adjusted lists to construct the DataFrame
    results_df = pd.DataFrame({
        'Id_Encoded': [user_id_encoded] * len(recommendation_response),
        'recommended_product': recommendation_response,
        'score_recommendation': scores
    })
    return results_df

# %%
from sklearn.metrics import mean_squared_error
predicted_scores = []
actual_ratings = []

for user_id_encoded in test['user_id_encoded'].unique():
    user_data = test[test['user_id_encoded'] == user_id_encoded]
    recommendations_df = get_recommendations(user_id_encoded)
    
    if user_id_encoded not in pt.index or 'recommended_product' not in recommendations_df.columns:
        continue

    for idx, row in user_data.iterrows():
        product_name = row['product_name']
        predicted_score = recommendations_df[recommendations_df['recommended_product'].apply(lambda x: x['product_name']) == product_name]['score_recommendation'].values
        predicted_scores.append(predicted_score[0] if len(predicted_score) > 0 else 0)
        actual_ratings.append(row['rating'])

rmse = np.sqrt(mean_squared_error(actual_ratings, predicted_scores))
print("RMSE:", rmse)
# Out:
# Error: user_id_encoded 5301 not found in index.
# Error: user_id_encoded 1835 not found in index.
# Error: user_id_encoded 8340 not found in index.
# Error: user_id_encoded 8855 not found in index.
# Error: user_id_encoded 332 not found in index.
# Error: user_id_encoded 1654 not found in index.
# Error: user_id_encoded 4786 not found in index.
# Error: user_id_encoded 8273 not found in index.
# Error: user_id_encoded 4857 not found in index.
# Error: user_id_encoded 1847 not found in index.
# Error: user_id_encoded 5722 not found in index.
# Error: user_id_encoded 5423 not found in index.
# Error: user_id_encoded 3109 not found in index.
# Error: user_id_encoded 4216 not found in index.
# Error: user_id_encoded 4278 not found in index.
# Error: user_id_encoded 4888 not found in index.
# Error: user_id_encoded 7984 not found in index.
# Error: user_id_encoded 1759 not found in index.
# Error: user_id_encoded 4434 not found in index.
# Error: user_id_encoded 628 not found in index.
# Error: user_id_encoded 5847 not found in index.
# Error: user_id_encoded 975 not found in index.
# Error: user_id_encoded 2898 not found in index.
# Error: user_id_encoded 3013 not found in index.
# Error: user_id_encoded 7535 not found in index.
# Error: user_id_encoded 2391 not found in index.
# Error: user_id_encoded 2112 not found in index.
# Error: user_id_encoded 4318 not found in index.
# Error: user_id_encoded 117 not found in index.
# Error: user_id_encoded 4107 not found in index.
# Error: user_id_encoded 3429 not found in index.
# Error: user_id_encoded 6563 not found in index.
# Error: user_id_encoded 7218 not found in index.
# Error: user_id_encoded 6588 not found in index.
# Error: user_id_encoded 7377 not found in index.
# Error: user_id_encoded 7341 not found in index.
# Error: user_id_encoded 2587 not found in index.
# Error: user_id_encoded 66 not found in index.
# Error: user_id_encoded 7203 not found in index.
# Error: user_id_encoded 2464 not found in index.
# Error: user_id_encoded 9030 not found in index.
# Error: user_id_encoded 8861 not found in index.
# Error: user_id_encoded 5462 not found in index.
# Error: user_id_encoded 833 not found in index.
# Error: user_id_encoded 8677 not found in index.
# Error: user_id_encoded 5771 not found in index.
# Error: user_id_encoded 3547 not found in index.
# Error: user_id_encoded 4274 not found in index.
# Error: user_id_encoded 8333 not found in index.
# Error: user_id_encoded 4483 not found in index.
# Error: user_id_encoded 7038 not found in index.
# Error: user_id_encoded 8830 not found in index.
# Error: user_id_encoded 109 not found in index.
# Error: user_id_encoded 1380 not found in index.
# Error: user_id_encoded 2828 not found in index.
# Error: user_id_encoded 4905 not found in index.
# Error: user_id_encoded 1786 not found in index.
# Error: user_id_encoded 3050 not found in index.
# Error: user_id_encoded 7666 not found in index.
# Error: user_id_encoded 8310 not found in index.
# Error: user_id_encoded 3735 not found in index.
# Error: user_id_encoded 8090 not found in index.
# Error: user_id_encoded 3514 not found in index.
# Error: user_id_encoded 5891 not found in index.
# Error: user_id_encoded 5186 not found in index.
# Error: user_id_encoded 2138 not found in index.
# Error: user_id_encoded 4949 not found in index.
# Error: user_id_encoded 7588 not found in index.
# Error: user_id_encoded 3515 not found in index.
# Error: user_id_encoded 5768 not found in index.
# Error: user_id_encoded 3827 not found in index.
# Error: user_id_encoded 3627 not found in index.
# Error: user_id_encoded 6687 not found in index.
# Error: user_id_encoded 4546 not found in index.
# Error: user_id_encoded 8960 not found in index.
# Error: user_id_encoded 2585 not found in index.
# Error: user_id_encoded 447 not found in index.
# Error: user_id_encoded 1027 not found in index.
# Error: user_id_encoded 6537 not found in index.
# Error: user_id_encoded 3938 not found in index.
# Error: user_id_encoded 2034 not found in index.
# Error: user_id_encoded 5418 not found in index.
# Error: user_id_encoded 6088 not found in index.
# RMSE: 3.7128257378706486

# %%
true_positives = 0
false_positives = 0
false_negatives = 0

for user_id_encoded in test['user_id_encoded'].unique():
    user_data = test[test['user_id_encoded'] == user_id_encoded]
    actual_products = set(user_data['product_name'])
    
    recommendations_df = get_recommendations(user_id_encoded)
    
    # Check if the user was found and if 'recommended_product' exists in the DataFrame
    if user_id_encoded not in pt.index or 'recommended_product' not in recommendations_df.columns:
        continue
    
    recommended_products = set([item['product_name'] for item in recommendations_df['recommended_product']])

    true_positives += len(recommended_products.intersection(actual_products))
    false_positives += len(recommended_products - actual_products)
    false_negatives += len(actual_products - recommended_products)

precision = true_positives / (true_positives + false_positives) if (true_positives + false_positives) != 0 else 0
recall = true_positives / (true_positives + false_negatives) if (true_positives + false_negatives) != 0 else 0

print("Precision:", precision)
print("Recall:", recall)
# Out:
# Error: user_id_encoded 5301 not found in index.
# Error: user_id_encoded 1835 not found in index.
# Error: user_id_encoded 8340 not found in index.
# Error: user_id_encoded 8855 not found in index.
# Error: user_id_encoded 332 not found in index.
# Error: user_id_encoded 1654 not found in index.
# Error: user_id_encoded 4786 not found in index.
# Error: user_id_encoded 8273 not found in index.
# Error: user_id_encoded 4857 not found in index.
# Error: user_id_encoded 1847 not found in index.
# Error: user_id_encoded 5722 not found in index.
# Error: user_id_encoded 5423 not found in index.
# Error: user_id_encoded 3109 not found in index.
# Error: user_id_encoded 4216 not found in index.
# Error: user_id_encoded 4278 not found in index.
# Error: user_id_encoded 4888 not found in index.
# Error: user_id_encoded 7984 not found in index.
# Error: user_id_encoded 1759 not found in index.
# Error: user_id_encoded 4434 not found in index.
# Error: user_id_encoded 628 not found in index.
# Error: user_id_encoded 5847 not found in index.
# Error: user_id_encoded 975 not found in index.
# Error: user_id_encoded 2898 not found in index.
# Error: user_id_encoded 3013 not found in index.
# Error: user_id_encoded 7535 not found in index.
# Error: user_id_encoded 2391 not found in index.
# Error: user_id_encoded 2112 not found in index.
# Error: user_id_encoded 4318 not found in index.
# Error: user_id_encoded 117 not found in index.
# Error: user_id_encoded 4107 not found in index.
# Error: user_id_encoded 3429 not found in index.
# Error: user_id_encoded 6563 not found in index.
# Error: user_id_encoded 7218 not found in index.
# Error: user_id_encoded 6588 not found in index.
# Error: user_id_encoded 7377 not found in index.
# Error: user_id_encoded 7341 not found in index.
# Error: user_id_encoded 2587 not found in index.
# Error: user_id_encoded 66 not found in index.
# Error: user_id_encoded 7203 not found in index.
# Error: user_id_encoded 2464 not found in index.
# Error: user_id_encoded 9030 not found in index.
# Error: user_id_encoded 8861 not found in index.
# Error: user_id_encoded 5462 not found in index.
# Error: user_id_encoded 833 not found in index.
# Error: user_id_encoded 8677 not found in index.
# Error: user_id_encoded 5771 not found in index.
# Error: user_id_encoded 3547 not found in index.
# Error: user_id_encoded 4274 not found in index.
# Error: user_id_encoded 8333 not found in index.
# Error: user_id_encoded 4483 not found in index.
# Error: user_id_encoded 7038 not found in index.
# Error: user_id_encoded 8830 not found in index.
# Error: user_id_encoded 109 not found in index.
# Error: user_id_encoded 1380 not found in index.
# Error: user_id_encoded 2828 not found in index.
# Error: user_id_encoded 4905 not found in index.
# Error: user_id_encoded 1786 not found in index.
# Error: user_id_encoded 3050 not found in index.
# Error: user_id_encoded 7666 not found in index.
# Error: user_id_encoded 8310 not found in index.
# Error: user_id_encoded 3735 not found in index.
# Error: user_id_encoded 8090 not found in index.
# Error: user_id_encoded 3514 not found in index.
# Error: user_id_encoded 5891 not found in index.
# Error: user_id_encoded 5186 not found in index.
# Error: user_id_encoded 2138 not found in index.
# Error: user_id_encoded 4949 not found in index.
# Error: user_id_encoded 7588 not found in index.
# Error: user_id_encoded 3515 not found in index.
# Error: user_id_encoded 5768 not found in index.
# Error: user_id_encoded 3827 not found in index.
# Error: user_id_encoded 3627 not found in index.
# Error: user_id_encoded 6687 not found in index.
# Error: user_id_encoded 4546 not found in index.
# Error: user_id_encoded 8960 not found in index.
# Error: user_id_encoded 2585 not found in index.
# Error: user_id_encoded 447 not found in index.
# Error: user_id_encoded 1027 not found in index.
# Error: user_id_encoded 6537 not found in index.
# Error: user_id_encoded 3938 not found in index.
# Error: user_id_encoded 2034 not found in index.
# Error: user_id_encoded 5418 not found in index.
# Error: user_id_encoded 6088 not found in index.
# Precision: 0.5082508250825083
# Recall: 0.5703703703703704

# %%
def hybrid_recommendation_v2(user_id_encoded, alpha=0.5, N=50):
    # Get top N recommendations from both systems
    content_based_recommendations = recommender_function(user_id_encoded)[:N]
    collaborative_recommendations = get_recommendations(user_id_encoded)[:N]
    
    # Normalize scores for collaborative recommendations using Min-Max scaling
    max_collab_score = collaborative_recommendations['score_recommendation'].max()
    collaborative_recommendations['normalized_score'] = collaborative_recommendations['score_recommendation'] / max_collab_score

    # Create a dictionary for both content and collab recommendations for O(1) access
    content_dict = {row['recommended_product']['product_id']: row['score_recommendation'] for _, row in content_based_recommendations.iterrows()}
    collab_dict = {row['recommended_product']['product_id']: row['normalized_score'] for _, row in collaborative_recommendations.iterrows()}

    # Combine both recommendation lists
    combined_recommendations = list(set(content_dict.keys()) | set(collab_dict.keys()))

    # Compute combined score for each product in combined_recommendations
    combined_scores = {}
    for product_id in combined_recommendations:
        content_score = content_dict.get(product_id, 0)
        collab_score = collab_dict.get(product_id, 0)
        combined_scores[product_id] = alpha * content_score + (1 - alpha) * collab_score

    # Sort products based on combined scores
    sorted_recommendations = sorted(combined_scores.items(), key=lambda x: x[1], reverse=True)[:5]

    # Extract product details for the top 5 sorted recommendations
    final_recommendations = []
    final_scores = []
    for product_id, score in sorted_recommendations:
        product_data = train[train['product_id'] == product_id].iloc[0]
        model_response = {}
        model_response['product_id'] = product_data['product_id']
        model_response['product_name'] = product_data['product_name']
        model_response['img_link'] = product_data['img_link']
        model_response['actual_price'] = product_data['actual_price']
        model_response['discounted_price'] = product_data['discounted_price']
        model_response['discount_percentage'] = product_data['discount_percentage']
        final_recommendations.append(model_response)
        final_scores.append(score)

    return pd.DataFrame({'Product': final_recommendations, 'Score': final_scores})

# %%
true_positives = 0
false_positives = 0
false_negatives = 0
actual_scores = []  # to store the actual scores (ratings)
predicted_scores = []  # to store the predicted scores

for user_id_encoded in test['user_id_encoded'].unique():
    
    # Check if user_id_encoded exists in the matrix
    if user_id_encoded not in pt.index:
        continue

    user_data = test[test['user_id_encoded'] == user_id_encoded]
    
    actual_products = set(user_data['product_name'])
    
    if len(user_data) > 0:
        print(f"User {user_id_encoded} has {len(user_data)} interactions in the test_data.")
    else:
        print(f"User {user_id_encoded} has no interactions in the test_data.")
    # Get hybrid recommendations
    recommendations_df = hybrid_recommendation_v2(user_id_encoded)
    print(recommendations_df.head())

    


    recommended_products = set([item['product_name'] for item in recommendations_df['Product']])
    
    true_positives += len(recommended_products.intersection(actual_products))
    false_positives += len(recommended_products - actual_products)
    false_negatives += len(actual_products - recommended_products)
    
    # Assuming you have a column that denotes the actual rating/score given by the user
    for _, interaction in user_data.iterrows():
        actual_product_name = interaction['product_name']

        recommended_product_ids = [item['product_id'] for item in recommendations_df['Product']]
        
        # Check if the actual product id is in the recommended product ids
        if actual_product_name not in [item['product_name'] for item in recommendations_df['Product']]:
            print(f"Product name {actual_product_name} not found in recommendations.")
            continue

        predicted_score = recommendations_df[recommendations_df['Product'].apply(lambda x: x['product_name'] == actual_product_name)]['Score'].values[0]

        # Assuming 'score_interaction' column exists in test_data
        actual_score = interaction['rating']

        actual_scores.append(actual_score)
        predicted_scores.append(predicted_score)

print(f"Length of actual scores: {len(actual_scores)}")
print(f"Length of predicted scores: {len(predicted_scores)}")


precision = true_positives / (true_positives + false_positives) if (true_positives + false_positives) != 0 else 0
recall = true_positives / (true_positives + false_negatives) if (true_positives + false_negatives) != 0 else 0

rmse = np.sqrt(mean_squared_error(actual_scores, predicted_scores))

print("Precision for Hybrid System:", precision)
print("Recall for Hybrid System:", recall)
print("RMSE for Hybrid System:", rmse)
# Out:
# User 5 has 10 interactions in the test_data.
#                                              Product     Score
# 0  {'product_id': 'B0765B3TH7', 'product_name': '...  0.500000
# 1  {'product_id': 'B077T3BG5L', 'product_name': '...  0.234315
# 2  {'product_id': 'B08ZJDWTJ1', 'product_name': '...  0.207107
# 3  {'product_id': 'B014SZO90Y', 'product_name': '...  0.125997
# 4  {'product_id': 'B08CS3BT4L', 'product_name': '...  0.124734
# Product name Kodak 80 cm (32 Inches) HD Ready LED TV Kodak 32HDX900S (Black) not found in recommendations.
# Product name Tata Sky Universal Remote not found in recommendations.
# Product name iQOO Z6 Pro 5G by vivo (Legion Sky, 6GB RAM, 128GB Storage) | Snapdragon 778G 5G | 66W FlashCharge | 1300 nits Peak Brightness | HDR10+ not found in recommendations.
# Product name Faber-Castell Connector Pen Set - Pack of 25 (Assorted) not found in recommendations.
# Product name Dr Trust Electronic Kitchen Digital Scale Weighing Machine (Blue) not found in recommendations.
# Product name Duracell Ultra Alkaline D Battery, 2 Pcs not found in recommendations.
# Product name JBL C100SI Wired In Ear Headphones with Mic, JBL Pure Bass Sound, One Button Multi-function Remote, Premium Metallic Finish, Angled Buds for Comfort fit (Red) not found in recommendations.
# User 7952 has 2 interactions in the test_data.
#                                              Product  Score
# 0  {'product_id': 'B01N90RZ4M', 'product_name': '...    0.5
# 1  {'product_id': 'B01DF26V7A', 'product_name': '...    0.5
# 2  {'product_id': 'B00DJ5N9VK', 'product_name': '...    0.5
# 3  {'product_id': 'B014SZPBM4', 'product_name': '...    0.5
# 4  {'product_id': 'B06XGWRKYT', 'product_name': '...    0.5
# Product name Zebronics ZEB-KM2100 Multimedia USB Keyboard Comes with 114 Keys Including 12 Dedicated Multimedia Keys & with Rupee Key not found in recommendations.
# Product name Bajaj DX-6 1000W Dry Iron with Advance Soleplate and Anti-bacterial German Coating Technology, White not found in recommendations.
# User 3 has 7 interactions in the test_data.
#                                              Product     Score
# 0  {'product_id': 'B09V2Q4QVQ', 'product_name': '...  0.500000
# 1  {'product_id': 'B073BRXPZX', 'product_name': '...  0.275000
# 2  {'product_id': 'B01DEWVZ2C', 'product_name': '...  0.256250
# 3  {'product_id': 'B09XB8GFBQ', 'product_name': '...  0.143035
# 4  {'product_id': 'B0BBFJ9M3X', 'product_name': '...  0.143035
# Product name Redgear Pro Wireless Gamepad with 2.4GHz Wireless Technology, Integrated Dual Intensity Motor, Illuminated Keys for PC(Compatible with Windows 7/8/8.1/10 only) not found in recommendations.
# Product name Redmi 9 Activ (Carbon Black, 4GB RAM, 64GB Storage) | Octa-core Helio G35 | 5000 mAh Battery not found in recommendations.
# Product name JBL Go 2, Wireless Portable Bluetooth Speaker with Mic, JBL Signature Sound, Vibrant Color Options with IPX7 Waterproof & AUX (Blue) not found in recommendations.
# Product name Noise ColorFit Pulse Smartwatch with 3.56 cm (1.4") Full Touch HD Display, SpO2, Heart Rate, Sleep Monitors & 10-Day Battery - Jet Black not found in recommendations.
# User 2562 has 2 interactions in the test_data.
#                                              Product  Score
# 0  {'product_id': 'B01DEWVZ2C', 'product_name': '...    0.5
# 1  {'product_id': 'B0756CLQWL', 'product_name': '...    0.5
# 2  {'product_id': 'B073BRXPZX', 'product_name': '...    0.5
# 3  {'product_id': 'B097R25DP7', 'product_name': '...    0.5
# 4  {'product_id': 'B07B88KQZ8', 'product_name': '...    0.5
# Product name boAt Bassheads 225 in Ear Wired Earphones with Mic(Blue) not found in recommendations.
# User 9001 has 2 interactions in the test_data.
#                                              Product     Score
# 0  {'product_id': 'B09V2Q4QVQ', 'product_name': '...  0.500000
# 1  {'product_id': 'B09F9YQQ7B', 'product_name': '...  0.165951
# 2  {'product_id': 'B09JPC82QC', 'product_name': '...  0.165951
# 3  {'product_id': 'B0B3XY5YT4', 'product_name': '...  0.160196
# 4  {'product_id': 'B09WN3SRC7', 'product_name': '...  0.139965
# Product name OnePlus 126 cm (50 inches) Y Series 4K Ultra HD Smart Android LED TV 50Y1S Pro (Black) not found in recommendations.
# User 5905 has 2 interactions in the test_data.
#                                              Product     Score
# 0  {'product_id': 'B09V2Q4QVQ', 'product_name': '...  0.500000
# 1  {'product_id': 'B01DEWVZ2C', 'product_name': '...  0.133289
# 2  {'product_id': 'B0756CLQWL', 'product_name': '...  0.133289
# 3  {'product_id': 'B073BRXPZX', 'product_name': '...  0.133289
# 4  {'product_id': 'B07B88KQZ8', 'product_name': '...  0.133289
# Product name Ionix Jewellery Scale | Weight Scale | Digital Weight Machine | weight machine for gold | Electronic weighing machines for Jewellery 0.01G to 200G Small Weight Machine for Shop - Silver not found in recommendations.
# User 1111 has 2 interactions in the test_data.
#                                              Product     Score
# 0  {'product_id': 'B08ZJDWTJ1', 'product_name': '...  0.516774
# 1  {'product_id': 'B0765B3TH7', 'product_name': '...  0.500000
# 2  {'product_id': 'B01DF26V7A', 'product_name': '...  0.170786
# 3  {'product_id': 'B00DJ5N9VK', 'product_name': '...  0.170786
# 4  {'product_id': 'B014SZPBM4', 'product_name': '...  0.170786
# Product name Seagate One Touch 2TB External HDD with Password Protection – Black, for Windows and Mac, with 3 yr Data Recovery Services, and 4 Months Adobe CC Photography (STKY2000400) not found in recommendations.
# User 1383 has 2 interactions in the test_data.
#                                              Product     Score
# 0  {'product_id': 'B0765B3TH7', 'product_name': '...  0.500000
# 1  {'product_id': 'B0B9RZ4G4W', 'product_name': '...  0.273411
# 2  {'product_id': 'B08ZJDWTJ1', 'product_name': '...  0.273411
# 3  {'product_id': 'B094QZLJQ6', 'product_name': '...  0.180713
# 4  {'product_id': 'B00DJ5N9VK', 'product_name': '...  0.134189
# User 4268 has 2 interactions in the test_data.
#                                              Product  Score
# 0  {'product_id': 'B01DEWVZ2C', 'product_name': '...    0.5
# 1  {'product_id': 'B0756CLQWL', 'product_name': '...    0.5
# 2  {'product_id': 'B073BRXPZX', 'product_name': '...    0.5
# 3  {'product_id': 'B097R25DP7', 'product_name': '...    0.5
# 4  {'product_id': 'B07B88KQZ8', 'product_name': '...    0.5
# Product name Usha IH2415 1500-Watt Immersion Heater (Silver) not found in recommendations.
# User 4910 has 2 interactions in the test_data.
#                                              Product     Score
# 0  {'product_id': 'B098K3H92Z', 'product_name': '...  0.500000
# 1  {'product_id': 'B07L9FW9GF', 'product_name': '...  0.455664
# 2  {'product_id': 'B07G3YNLJB', 'product_name': '...  0.182929
# 3  {'product_id': 'B01LONQBDG', 'product_name': '...  0.182929
# 4  {'product_id': 'B086Q3QMFS', 'product_name': '...  0.160714
# User 5484 has 2 interactions in the test_data.
#                                              Product     Score
# 0  {'product_id': 'B098K3H92Z', 'product_name': '...  0.500000
# 1  {'product_id': 'B07L9FW9GF', 'product_name': '...  0.279648
# 2  {'product_id': 'B07G3YNLJB', 'product_name': '...  0.220352
# 3  {'product_id': 'B01LONQBDG', 'product_name': '...  0.220352
# 4  {'product_id': 'B01J0XWYKQ', 'product_name': '...  0.168548
# Product name Logitech M221 Wireless Mouse, Silent Buttons, 2.4 GHz with USB Mini Receiver, 1000 DPI Optical Tracking, 18-Month Battery Life, Ambidextrous PC / Mac / Laptop - Charcoal Grey not found in recommendations.
# User 6972 has 3 interactions in the test_data.
#                                              Product     Score
# 0  {'product_id': 'B098K3H92Z', 'product_name': '...  0.500000
# 1  {'product_id': 'B07G3YNLJB', 'product_name': '...  0.225776
# 2  {'product_id': 'B09NVPSCQT', 'product_name': '...  0.225776
# 3  {'product_id': 'B01GGKZ0V6', 'product_name': '...  0.212412
# 4  {'product_id': 'B07L9FW9GF', 'product_name': '...  0.211348
# Product name AmazonBasics USB Type-C to Micro-B 2.0 Cable - 6 Inches (15.2 Centimeters) - White not found in recommendations.
# User 2137 has 3 interactions in the test_data.
#                                              Product     Score
# 0  {'product_id': 'B0B3X2BY3M', 'product_name': '...  0.500000
# 1  {'product_id': 'B07VZH6ZBB', 'product_name': '...  0.500000
# 2  {'product_id': 'B08YRMBK9R', 'product_name': '...  0.161450
# 3  {'product_id': 'B097MKZHNV', 'product_name': '...  0.152725
# 4  {'product_id': 'B00HZIOGXW', 'product_name': '...  0.143829
# Product name iBELL Castor CTEK15L Premium 1.5 Litre Stainless Steel Electric Kettle,1500W Auto Cut-Off Feature,Silver not found in recommendations.
# User 6125 has 2 interactions in the test_data.
#                                              Product     Score
# 0  {'product_id': 'B0B3X2BY3M', 'product_name': '...  0.648263
# 1  {'product_id': 'B08C7TYHPB', 'product_name': '...  0.500000
# 2  {'product_id': 'B07VZH6ZBB', 'product_name': '...  0.500000
# 3  {'product_id': 'B00HZIOGXW', 'product_name': '...  0.148263
# 4  {'product_id': 'B097MKZHNV', 'product_name': '...  0.146081
# Product name INDIAS®™ Electro-Instant Water Geyser A.B.S. Body Shock Proof Can be Used in Bathroom, Kitchen, wash Area, Hotels, Hospital etc. not found in recommendations.
# User 3907 has 2 interactions in the test_data.
#                                              Product     Score
# 0  {'product_id': 'B01486F4G6', 'product_name': '...  0.500000
# 1  {'product_id': 'B0BBWJFK5C', 'product_name': '...  0.186464
# 2  {'product_id': 'B097MKZHNV', 'product_name': '...  0.062254
# 3  {'product_id': 'B0B5RP43VN', 'product_name': '...  0.060514
# 4  {'product_id': 'B07S851WX5', 'product_name': '...  0.057592
# Product name AGARO Supreme High Pressure Washer, 1800 Watts, 120 Bars, 6.5L/Min Flow Rate, 8 Meters Outlet Hose, Portable, for Car,Bike and Home Cleaning Purpose, Black and Orange not found in recommendations.
# User 3196 has 2 interactions in the test_data.
#                                              Product     Score
# 0  {'product_id': 'B01486F4G6', 'product_name': '...  0.500000
# 1  {'product_id': 'B0B61DSF17', 'product_name': '...  0.176481
# 2  {'product_id': 'B0B694PXQJ', 'product_name': '...  0.161789
# 3  {'product_id': 'B07Q4NJQC5', 'product_name': '...  0.154032
# 4  {'product_id': 'B07VQGVL68', 'product_name': '...  0.154032
# Product name Themisto TH-WS20 Digital Kitchen Weighing Scale Stainless Steel (5Kg) not found in recommendations.
# User 7353 has 2 interactions in the test_data.
#                                              Product     Score
# 0  {'product_id': 'B07YL54NVJ', 'product_name': '...  0.500000
# 1  {'product_id': 'B09VKWGZD7', 'product_name': '...  0.179532
# 2  {'product_id': 'B097C564GC', 'product_name': '...  0.111645
# 3  {'product_id': 'B081FG1QYX', 'product_name': '...  0.110938
# 4  {'product_id': 'B07GVGTSLN', 'product_name': '...  0.100027
# Product name Shakti Technology S3 High Pressure Car Washer Machine 1800 Watts and Pressure 120 Bar for Cleaning Car, Bike & Home not found in recommendations.
# User 4277 has 2 interactions in the test_data.
#                                              Product     Score
# 0  {'product_id': 'B07232M876', 'product_name': '...  0.500000
# 1  {'product_id': 'B00NH11PEY', 'product_name': '...  0.293497
# 2  {'product_id': 'B08D9NDZ1Y', 'product_name': '...  0.293497
# 3  {'product_id': 'B00NH11KIK', 'product_name': '...  0.265711
# 4  {'product_id': 'B09YLXYP7Y', 'product_name': '...  0.185000
# User 6620 has 2 interactions in the test_data.
#                                              Product     Score
# 0  {'product_id': 'B08D9NDZ1Y', 'product_name': '...  0.500000
# 1  {'product_id': 'B07232M876', 'product_name': '...  0.469964
# 2  {'product_id': 'B00NH11PEY', 'product_name': '...  0.469964
# 3  {'product_id': 'B00NH11KIK', 'product_name': '...  0.230662
# 4  {'product_id': 'B01EJ5MM5M', 'product_name': '...  0.126385
# User 7863 has 2 interactions in the test_data.
#                                              Product     Score
# 0  {'product_id': 'B098NS6PVG', 'product_name': '...  0.500000
# 1  {'product_id': 'B07TCN5VR9', 'product_name': '...  0.500000
# 2  {'product_id': 'B07PFJ5VQD', 'product_name': '...  0.500000
# 3  {'product_id': 'B0B4DT8MKT', 'product_name': '...  0.133654
# 4  {'product_id': 'B09YLXYP7Y', 'product_name': '...  0.128722
# Product name STRIFF Laptop Stand Adjustable Laptop Computer Stand Multi-Angle Stand Phone Stand Portable Foldable Laptop Riser Notebook Holder Stand Compatible for 9 to 15.6” Laptops Black(Black) not found in recommendations.
# User 4335 has 2 interactions in the test_data.
#                                              Product     Score
# 0  {'product_id': 'B08GYG6T12', 'product_name': '...  0.500000
# 1  {'product_id': 'B07JF9B592', 'product_name': '...  0.131413
# 2  {'product_id': 'B00RFWNJMC', 'product_name': '...  0.111858
# 3  {'product_id': 'B09X7DY7Q4', 'product_name': '...  0.106820
# 4  {'product_id': 'B07YFWVRCM', 'product_name': '...  0.076514
# Product name HUMBLE Dynamic Lapel Collar Mic Voice Recording Filter Microphone for Singing Youtube SmartPhones, Black not found in recommendations.
# User 8002 has 2 interactions in the test_data.
#                                              Product     Score
# 0  {'product_id': 'B09RF2QXGX', 'product_name': '...  0.500000
# 1  {'product_id': 'B0B2DJ5RVQ', 'product_name': '...  0.068501
# 2  {'product_id': 'B09JPC82QC', 'product_name': '...  0.065048
# 3  {'product_id': 'B0BCVJ3PVP', 'product_name': '...  0.065048
# 4  {'product_id': 'B09CYTJV3N', 'product_name': '...  0.064789
# Product name Caprigo Heavy Duty TV Wall Mount Stand for 12 to 27 inches LED/LCD/Monitor Screen's, Full Motion Rotatable Universal TV & Monitor Wall Mount Bracket with Swivel & Tilt Adjustments (Single Arm - M416) not found in recommendations.
# User 1335 has 2 interactions in the test_data.
#                                              Product     Score
# 0  {'product_id': 'B09RF2QXGX', 'product_name': '...  0.500000
# 1  {'product_id': 'B08FTFXNNB', 'product_name': '...  0.106907
# 2  {'product_id': 'B07YFWVRCM', 'product_name': '...  0.078625
# 3  {'product_id': 'B00MUTWLW4', 'product_name': '...  0.075409
# 4  {'product_id': 'B08HD7JQHX', 'product_name': '...  0.061080
# Product name Logitech C270 Digital HD Webcam with Widescreen HD Video Calling, HD Light Correction, Noise-Reducing Mic, for Skype, FaceTime, Hangouts, WebEx, PC/Mac/Laptop/MacBook/Tablet - (Black, HD 720p/30fps) not found in recommendations.
# User 8625 has 2 interactions in the test_data.
#                                              Product     Score
# 0  {'product_id': 'B08WJ86PV2', 'product_name': '...  0.500000
# 1  {'product_id': 'B0BCVJ3PVP', 'product_name': '...  0.238697
# 2  {'product_id': 'B0819HZPXL', 'product_name': '...  0.208456
# 3  {'product_id': 'B09MZ6WZ6V', 'product_name': '...  0.190665
# 4  {'product_id': 'B0926V9CTV', 'product_name': '...  0.165936
# Product name Dyazo 6 Angles Adjustable Aluminum Ergonomic Foldable Portable Tabletop Laptop/Desktop Riser Stand Holder Compatible for MacBook, HP, Dell, Lenovo & All Other Notebook (Silver) not found in recommendations.
# User 433 has 2 interactions in the test_data.
#                                              Product     Score
# 0  {'product_id': 'B0148NPH9I', 'product_name': '...  0.500000
# 1  {'product_id': 'B07R99NBVB', 'product_name': '...  0.500000
# 2  {'product_id': 'B00MUTWLW4', 'product_name': '...  0.229640
# 3  {'product_id': 'B087FXHB6J', 'product_name': '...  0.141152
# 4  {'product_id': 'B00CEQEGPI', 'product_name': '...  0.136430
# Product name Logitech Pebble M350 Wireless Mouse with Bluetooth or USB - Silent, Slim Computer Mouse with Quiet Click for Laptop, Notebook, PC and Mac - Graphite not found in recommendations.
# User 3703 has 2 interactions in the test_data.
#                                              Product     Score
# 0  {'product_id': 'B01M4GGIVU', 'product_name': '...  0.500000
# 1  {'product_id': 'B09HCH3JZG', 'product_name': '...  0.372071
# 2  {'product_id': 'B00LZLQ624', 'product_name': '...  0.248514
# 3  {'product_id': 'B06XR9PR5X', 'product_name': '...  0.232589
# 4  {'product_id': 'B07RZZ1QSW', 'product_name': '...  0.152127
# Product name WeCool B1 Mobile Holder for Bikes or Bike Mobile Holder for Maps and GPS Navigation, one Click Locking, Firm Gripping, Anti Shake and Stable Cradle Clamp with 360° Rotation Bicycle Phone Mount not found in recommendations.
# User 6612 has 3 interactions in the test_data.
#                                              Product     Score
# 0  {'product_id': 'B0B4DT8MKT', 'product_name': '...  0.500000
# 1  {'product_id': 'B0993BB11X', 'product_name': '...  0.500000
# 2  {'product_id': 'B094JNXNPV', 'product_name': '...  0.137178
# 3  {'product_id': 'B098NS6PVG', 'product_name': '...  0.131303
# 4  {'product_id': 'B085DTN6R2', 'product_name': '...  0.131303
# Product name CARDEX Digital Kitchen Weighing Machine Multipurpose Electronic Weight Scale With Back Lite LCD Display for Measuring Food, Cake, Vegetable, Fruit (KITCHEN SCALE) not found in recommendations.
# Product name AirCase Rugged Hard Drive Case for 2.5-inch Western Digital, Seagate, Toshiba, Portable Storage Shell for Gadget Hard Disk USB Cable Power Bank Mobile Charger Earphone, Waterproof (Black) not found in recommendations.
# User 5469 has 2 interactions in the test_data.
#                                              Product     Score
# 0  {'product_id': 'B0993BB11X', 'product_name': '...  0.500000
# 1  {'product_id': 'B07RD611Z8', 'product_name': '...  0.289001
# 2  {'product_id': 'B085DTN6R2', 'product_name': '...  0.289001
# 3  {'product_id': 'B098NS6PVG', 'product_name': '...  0.283333
# 4  {'product_id': 'B09CMP1SC8', 'product_name': '...  0.215507
# Product name Wecool Unbreakable 3 in 1 Charging Cable with 3A Speed, Fast Charging Multi Purpose Cable 1.25 Mtr Long, Type C cable, Micro Usb Cable and Cable for iPhone, White not found in recommendations.
# User 6350 has 2 interactions in the test_data.
#                                              Product     Score
# 0  {'product_id': 'B078W65FJ7', 'product_name': '...  0.500000
# 1  {'product_id': 'B08MTLLSL8', 'product_name': '...  0.500000
# 2  {'product_id': 'B07KY3FNQP', 'product_name': '...  0.104700
# 3  {'product_id': 'B07CD2BN46', 'product_name': '...  0.103841
# 4  {'product_id': 'B07S9S86BF', 'product_name': '...  0.103255
# User 3107 has 2 interactions in the test_data.
#                                              Product     Score
# 0  {'product_id': 'B078W65FJ7', 'product_name': '...  0.500000
# 1  {'product_id': 'B08MTLLSL8', 'product_name': '...  0.500000
# 2  {'product_id': 'B00Y4ORQ46', 'product_name': '...  0.110894
# 3  {'product_id': 'B07CD2BN46', 'product_name': '...  0.105310
# 4  {'product_id': 'B07TCN5VR9', 'product_name': '...  0.105310
# Product name HP w100 480P 30 FPS Digital Webcam with Built-in Mic, Plug and Play Setup, Wide-Angle View for Video Calling on Skype, Zoom, Microsoft Teams and Other Apps (Black) not found in recommendations.
# User 8527 has 2 interactions in the test_data.
#                                              Product     Score
# 0  {'product_id': 'B00LUGTJGO', 'product_name': '...  0.500000
# 1  {'product_id': 'B009P2LK08', 'product_name': '...  0.209861
# 2  {'product_id': 'B00P0R95EA', 'product_name': '...  0.135526
# 3  {'product_id': 'B097R4D42G', 'product_name': '...  0.127666
# 4  {'product_id': 'B07LG96SDB', 'product_name': '...  0.119294
# Product name Bajaj Splendora 3 Litre 3KW IWH Instant Water Heater (Geyser), White not found in recommendations.
# User 5625 has 2 interactions in the test_data.
#                                              Product     Score
# 0  {'product_id': 'B09SGGRKV8', 'product_name': '...  0.500000
# 1  {'product_id': 'B00H47GVGY', 'product_name': '...  0.115413
# 2  {'product_id': 'B07CD2BN46', 'product_name': '...  0.101716
# 3  {'product_id': 'B07TXCY3YK', 'product_name': '...  0.101716
# 4  {'product_id': 'B0B9F9PT8R', 'product_name': '...  0.098655
# Product name Lifelong LLFH921 Regalia 2000 W Fan Heater, 3 Air Settings, Room Heater with Overheating Protection, 1 Year Warranty ( White, (ISI Certified, Ideal for small to medium room/area) not found in recommendations.
# User 4457 has 2 interactions in the test_data.
#                                              Product     Score
# 0  {'product_id': 'B09SGGRKV8', 'product_name': '...  0.500000
# 1  {'product_id': 'B07CD2BN46', 'product_name': '...  0.145576
# 2  {'product_id': 'B078W65FJ7', 'product_name': '...  0.143753
# 3  {'product_id': 'B07TCN5VR9', 'product_name': '...  0.115002
# 4  {'product_id': 'B00Y4ORQ46', 'product_name': '...  0.113640
# Product name boAt Bassheads 152 in Ear Wired Earphones with Mic(Active Black) not found in recommendations.
# User 3379 has 2 interactions in the test_data.
#                                              Product     Score
# 0  {'product_id': 'B097C564GC', 'product_name': '...  0.500000
# 1  {'product_id': 'B01LONQBDG', 'product_name': '...  0.207714
# 2  {'product_id': 'B01GGKZ0V6', 'product_name': '...  0.207714
# 3  {'product_id': 'B07924P3C5', 'product_name': '...  0.200469
# 4  {'product_id': 'B08Y1TFSP6', 'product_name': '...  0.164068
# Product name Portronics MPORT 31C 4-in-1 USB Hub (Type C to 4 USB-A Ports) with Fast Data Transfer not found in recommendations.
# User 2849 has 2 interactions in the test_data.
#                                              Product     Score
# 0  {'product_id': 'B097C564GC', 'product_name': '...  0.500000
# 1  {'product_id': 'B07DC4RZPY', 'product_name': '...  0.196376
# 2  {'product_id': 'B07GVGTSLN', 'product_name': '...  0.186937
# 3  {'product_id': 'B081FG1QYX', 'product_name': '...  0.146354
# 4  {'product_id': 'B09NHVCHS9', 'product_name': '...  0.144791
# Product name Wayona Nylon Braided USB to Lightning Fast Charging and Data Sync Cable Compatible for iPhone 13, 12,11, X, 8, 7, 6, 5, iPad Air, Pro, Mini (3 FT Pack of 1, Grey) not found in recommendations.
# User 4276 has 3 interactions in the test_data.
#                                              Product     Score
# 0  {'product_id': 'B00LZLQ624', 'product_name': '...  0.289976
# 1  {'product_id': 'B00P93X0VO', 'product_name': '...  0.280686
# 2  {'product_id': 'B00LZLPYHW', 'product_name': '...  0.264112
# 3  {'product_id': 'B086Q3QMFS', 'product_name': '...  0.262898
# 4  {'product_id': 'B08MTCKDYN', 'product_name': '...  0.196625
# Product name 3M Post-it Sticky Note Cube, 200 Sheets (4 Colors x 50 Sheets) | 3" x 3" Size | For notes, reminders, study, school and organizing not found in recommendations.
# Product name Classmate Soft Cover 6 Subject Spiral Binding Notebook, Unruled, 300 Pages not found in recommendations.
# Product name STRIFF 12 Pieces Highly Flexible Silicone Micro USB Protector, Mouse Cable Protector, Suit for All Cell Phones, Computers and Chargers (White) not found in recommendations.
# User 2277 has 2 interactions in the test_data.
#                                              Product     Score
# 0  {'product_id': 'B09YLXYP7Y', 'product_name': '...  0.500000
# 1  {'product_id': 'B0949SBKMP', 'product_name': '...  0.231212
# 2  {'product_id': 'B07CD2BN46', 'product_name': '...  0.231212
# 3  {'product_id': 'B07GLNJC25', 'product_name': '...  0.184858
# 4  {'product_id': 'B09ZPL5VYM', 'product_name': '...  0.184858
# User 8393 has 2 interactions in the test_data.
#                                              Product     Score
# 0  {'product_id': 'B0949SBKMP', 'product_name': '...  0.500000
# 1  {'product_id': 'B09YLXYP7Y', 'product_name': '...  0.366838
# 2  {'product_id': 'B07CD2BN46', 'product_name': '...  0.366838
# 3  {'product_id': 'B097R25DP7', 'product_name': '...  0.127395
# 4  {'product_id': 'B0B5LVS732', 'product_name': '...  0.127395
# User 6934 has 2 interactions in the test_data.
#                                              Product     Score
# 0  {'product_id': 'B08WJ86PV2', 'product_name': '...  0.500000
# 1  {'product_id': 'B0819HZPXL', 'product_name': '...  0.244444
# 2  {'product_id': 'B09MZ6WZ6V', 'product_name': '...  0.221841
# 3  {'product_id': 'B087FXHB6J', 'product_name': '...  0.178823
# 4  {'product_id': 'B073BRXPZX', 'product_name': '...  0.163696
# User 8211 has 2 interactions in the test_data.
#                                              Product     Score
# 0  {'product_id': 'B08WJ86PV2', 'product_name': '...  0.500000
# 1  {'product_id': 'B09MZ6WZ6V', 'product_name': '...  0.232124
# 2  {'product_id': 'B0819HZPXL', 'product_name': '...  0.208456
# 3  {'product_id': 'B01J1CFO5I', 'product_name': '...  0.116455
# 4  {'product_id': 'B087FXHB6J', 'product_name': '...  0.114191
# Product name Lapster Gel Mouse pad with Wrist Rest , Gaming Mouse Pad with Lycra Cloth Nonslip for Laptop , Computer, , Home & Office (Black) not found in recommendations.
# User 1690 has 2 interactions in the test_data.
#                                              Product     Score
# 0  {'product_id': 'B01M4GGIVU', 'product_name': '...  0.634433
# 1  {'product_id': 'B09HCH3JZG', 'product_name': '...  0.500000
# 2  {'product_id': 'B07VSG5SXZ', 'product_name': '...  0.157815
# 3  {'product_id': 'B06XR9PR5X', 'product_name': '...  0.142243
# 4  {'product_id': 'B08TGG316Z', 'product_name': '...  0.138430
# Product name Cablet 2.5 Inch SATA USB 3.0 HDD/SSD Portable External Enclosure for 7mm and 9.5mm, Tool-Free Design, Supports UASP Max 6TB not found in recommendations.
# User 5867 has 2 interactions in the test_data.
#                                              Product     Score
# 0  {'product_id': 'B08GYG6T12', 'product_name': '...  0.500000
# 1  {'product_id': 'B09HCH3JZG', 'product_name': '...  0.138924
# 2  {'product_id': 'B07VSG5SXZ', 'product_name': '...  0.138257
# 3  {'product_id': 'B01M4GGIVU', 'product_name': '...  0.132056
# 4  {'product_id': 'B09X7DY7Q4', 'product_name': '...  0.118177
# Product name 10k 8k 4k HDMI Cable, Certified 48Gbps 1ms Ultra High Speed HDMI 2.1 Cable 4k 120Hz 144Hz 2k 165Hz 8k 60Hz Dynamic HDR ARC eARC DTS:X Compatible for Mac Gaming PC Soundbar TV Monitor Laptop PS5 4 Xbox not found in recommendations.
# User 7383 has 2 interactions in the test_data.
#                                              Product     Score
# 0  {'product_id': 'B075DB1F13', 'product_name': '...  0.500000
# 1  {'product_id': 'B07DC4RZPY', 'product_name': '...  0.500000
# 2  {'product_id': 'B00N3XLDW0', 'product_name': '...  0.134938
# 3  {'product_id': 'B0993BB11X', 'product_name': '...  0.088070
# 4  {'product_id': 'B00BN5SNF0', 'product_name': '...  0.077446
# User 5864 has 2 interactions in the test_data.
#                                              Product     Score
# 0  {'product_id': 'B075DB1F13', 'product_name': '...  0.500000
# 1  {'product_id': 'B086394NY5', 'product_name': '...  0.321512
# 2  {'product_id': 'B07DC4RZPY', 'product_name': '...  0.321512
# 3  {'product_id': 'B07JW9H4J1', 'product_name': '...  0.150524
# 4  {'product_id': 'B08CF3B7N1', 'product_name': '...  0.127299
# User 4641 has 2 interactions in the test_data.
#                                              Product     Score
# 0  {'product_id': 'B086394NY5', 'product_name': '...  0.500000
# 1  {'product_id': 'B017PDR9N0', 'product_name': '...  0.467434
# 2  {'product_id': 'B0926V9CTV', 'product_name': '...  0.285744
# 3  {'product_id': 'B07DC4RZPY', 'product_name': '...  0.209933
# 4  {'product_id': 'B09ZPL5VYM', 'product_name': '...  0.097371
# User 3117 has 2 interactions in the test_data.
#                                              Product     Score
# 0  {'product_id': 'B086394NY5', 'product_name': '...  0.500000
# 1  {'product_id': 'B017PDR9N0', 'product_name': '...  0.250000
# 2  {'product_id': 'B07DC4RZPY', 'product_name': '...  0.250000
# 3  {'product_id': 'B0B61DSF17', 'product_name': '...  0.198410
# 4  {'product_id': 'B09W9V2PXG', 'product_name': '...  0.108174
# Product name Glun Multipurpose Portable Electronic Digital Weighing Scale Weight Machine (10 Kg - with Back Light) not found in recommendations.
# User 4918 has 2 interactions in the test_data.
#                                              Product     Score
# 0  {'product_id': 'B086394NY5', 'product_name': '...  0.500000
# 1  {'product_id': 'B017PDR9N0', 'product_name': '...  0.209933
# 2  {'product_id': 'B075DB1F13', 'product_name': '...  0.188549
# 3  {'product_id': 'B07DC4RZPY', 'product_name': '...  0.188549
# 4  {'product_id': 'B07JW9H4J1', 'product_name': '...  0.134921
# User 7128 has 2 interactions in the test_data.
#                                              Product     Score
# 0  {'product_id': 'B00NH11PEY', 'product_name': '...  0.500000
# 1  {'product_id': 'B08D9NDZ1Y', 'product_name': '...  0.500000
# 2  {'product_id': 'B0148NPH9I', 'product_name': '...  0.232206
# 3  {'product_id': 'B01EJ5MM5M', 'product_name': '...  0.217360
# 4  {'product_id': 'B00CEQEGPI', 'product_name': '...  0.140785
# Product name Logitech K480 Wireless Multi-Device Keyboard for Windows, macOS, iPadOS, Android or Chrome OS, Bluetooth, Compact, Compatible with PC, Mac, Laptop, Smartphone, Tablet - Black not found in recommendations.
# User 2222 has 2 interactions in the test_data.
#                                              Product     Score
# 0  {'product_id': 'B01HJI0FS2', 'product_name': '...  0.500000
# 1  {'product_id': 'B00GZLB57U', 'product_name': '...  0.500000
# 2  {'product_id': 'B014SZO90Y', 'product_name': '...  0.500000
# 3  {'product_id': 'B00N3XLDW0', 'product_name': '...  0.269919
# 4  {'product_id': 'B003B00484', 'product_name': '...  0.269919
# Product name Duracell Ultra Alkaline AAA Battery, 8 Pcs not found in recommendations.
# User 5829 has 3 interactions in the test_data.
#                                              Product     Score
# 0  {'product_id': 'B01HJI0FS2', 'product_name': '...  0.500000
# 1  {'product_id': 'B01DJJVFPC', 'product_name': '...  0.253168
# 2  {'product_id': 'B014SZO90Y', 'product_name': '...  0.250000
# 3  {'product_id': 'B08YDFX7Y1', 'product_name': '...  0.191302
# 4  {'product_id': 'B00GZLB57U', 'product_name': '...  0.191302
# User 2674 has 5 interactions in the test_data.
#                                              Product     Score
# 0  {'product_id': 'B07232M876', 'product_name': '...  0.500000
# 1  {'product_id': 'B07VTFN6HM', 'product_name': '...  0.311362
# 2  {'product_id': 'B008YW8M0G', 'product_name': '...  0.217678
# 3  {'product_id': 'B01N6LU1VF', 'product_name': '...  0.217678
# 4  {'product_id': 'B00NH11PEY', 'product_name': '...  0.202791
# Product name Philips GC1905 1440-Watt Steam Iron with Spray (Blue) not found in recommendations.
# Product name Sennheiser CX 80S in-Ear Wired Headphones with in-line One-Button Smart Remote with Microphone Black not found in recommendations.
# User 5073 has 3 interactions in the test_data.
#                                              Product    Score
# 0  {'product_id': 'B07RD611Z8', 'product_name': '...  0.50000
# 1  {'product_id': 'B08TDJNM3G', 'product_name': '...  0.50000
# 2  {'product_id': 'B008QTK47Q', 'product_name': '...  0.32266
# 3  {'product_id': 'B07232M876', 'product_name': '...  0.32266
# 4  {'product_id': 'B01N6LU1VF', 'product_name': '...  0.32266
# Product name Philips PowerPro FC9352/01 Compact Bagless Vacuum Cleaner (Blue) not found in recommendations.
# User 7007 has 2 interactions in the test_data.
#                                              Product     Score
# 0  {'product_id': 'B0B21C4BMX', 'product_name': '...  0.500000
# 1  {'product_id': 'B085DTN6R2', 'product_name': '...  0.269020
# 2  {'product_id': 'B08CF3B7N1', 'product_name': '...  0.223664
# 3  {'product_id': 'B098NS6PVG', 'product_name': '...  0.176236
# 4  {'product_id': 'B0B4DT8MKT', 'product_name': '...  0.176236
# Product name Portronics Konnect L POR-1403 Fast Charging 3A Type-C Cable 1.2 Meter with Charge & Sync Function for All Type-C Devices (White) not found in recommendations.
# User 6478 has 2 interactions in the test_data.
#                                              Product     Score
# 0  {'product_id': 'B0B21C4BMX', 'product_name': '...  0.500000
# 1  {'product_id': 'B0B2DJ5RVQ', 'product_name': '...  0.112898
# 2  {'product_id': 'B07RZZ1QSW', 'product_name': '...  0.075608
# 3  {'product_id': 'B0B9BXKBC7', 'product_name': '...  0.074841
# 4  {'product_id': 'B0926V9CTV', 'product_name': '...  0.061360
# Product name Portronics CLAMP X Car-Vent Mobile Holder 360 Degree Rotational(Black) not found in recommendations.
# User 4768 has 2 interactions in the test_data.
#                                              Product     Score
# 0  {'product_id': 'B07L1N3TJX', 'product_name': '...  0.500000
# 1  {'product_id': 'B00F159RIK', 'product_name': '...  0.058324
# 2  {'product_id': 'B0B8XNPQPN', 'product_name': '...  0.054538
# 3  {'product_id': 'B0BCVJ3PVP', 'product_name': '...  0.054450
# 4  {'product_id': 'B09NL4DCXK', 'product_name': '...  0.052473
# Product name Panasonic SR-WA22H (E) Automatic Rice Cooker, Apple Green, 2.2 Liters not found in recommendations.
# User 7230 has 2 interactions in the test_data.
#                                              Product     Score
# 0  {'product_id': 'B07L1N3TJX', 'product_name': '...  0.500000
# 1  {'product_id': 'B00GGGOYEK', 'product_name': '...  0.081979
# 2  {'product_id': 'B097C564GC', 'product_name': '...  0.064791
# 3  {'product_id': 'B07DC4RZPY', 'product_name': '...  0.064647
# 4  {'product_id': 'B07LFWP97N', 'product_name': '...  0.063857
# Product name Zebronics ZEB-90HB USB Hub, 4 Ports, Pocket Sized, Plug & Play, for Laptop & Computers not found in recommendations.
# User 2962 has 3 interactions in the test_data.
#                                              Product     Score
# 0  {'product_id': 'B01M0505SJ', 'product_name': '...  0.130960
# 1  {'product_id': 'B09GYBZPHF', 'product_name': '...  0.128755
# 2  {'product_id': 'B095PWLLY6', 'product_name': '...  0.124075
# 3  {'product_id': 'B08KDBLMQP', 'product_name': '...  0.118363
# 4  {'product_id': 'B08CFJBZRK', 'product_name': '...  0.107254
# Product name Butterfly Hero Mixer Grinder, 500W, 3 Jars (Grey) not found in recommendations.
# Product name Havells Ambrose 1200mm Ceiling Fan (Gold Mist Wood) not found in recommendations.
# Product name Havells Ventil Air DSP 230mm Exhaust Fan (Pista Green) not found in recommendations.
# User 4842 has 2 interactions in the test_data.
#                                              Product     Score
# 0  {'product_id': 'B01M4GGIVU', 'product_name': '...  0.500000
# 1  {'product_id': 'B09HCH3JZG', 'product_name': '...  0.311362
# 2  {'product_id': 'B06XR9PR5X', 'product_name': '...  0.288901
# 3  {'product_id': 'B00GG59HU2', 'product_name': '...  0.206643
# 4  {'product_id': 'B07VSG5SXZ', 'product_name': '...  0.204404
# User 919 has 2 interactions in the test_data.
#                                              Product     Score
# 0  {'product_id': 'B09YLXYP7Y', 'product_name': '...  0.500000
# 1  {'product_id': 'B09ZPL5VYM', 'product_name': '...  0.500000
# 2  {'product_id': 'B07GLNJC25', 'product_name': '...  0.500000
# 3  {'product_id': 'B07N8RQ6W7', 'product_name': '...  0.261719
# 4  {'product_id': 'B098NS6PVG', 'product_name': '...  0.261719
# Product name Ambrane Unbreakable 3A Fast Charging Braided Type C Cable    1.5 Meter (RCT15, Blue) Supports QC 2.0/3.0 Charging not found in recommendations.
# User 2853 has 2 interactions in the test_data.
#                                              Product     Score
# 0  {'product_id': 'B07Z53L5QL', 'product_name': '...  0.500000
# 1  {'product_id': 'B08MTCKDYN', 'product_name': '...  0.344472
# 2  {'product_id': 'B09Z6WH2N1', 'product_name': '...  0.197833
# 3  {'product_id': 'B08CF3B7N1', 'product_name': '...  0.197833
# 4  {'product_id': 'B08KRMK9LZ', 'product_name': '...  0.117551
# Product name LAPSTER 12pcs Spiral Cable Protectors for Charger, Wires, Data Charger Cable Protector for Computers, Cell Phones etc.(Grey) not found in recommendations.
# User 823 has 2 interactions in the test_data.
#                                              Product     Score
# 0  {'product_id': 'B083T5G5PM', 'product_name': '...  0.500000
# 1  {'product_id': 'B09JPC82QC', 'product_name': '...  0.500000
# 2  {'product_id': 'B076B8G5D8', 'product_name': '...  0.500000
# 3  {'product_id': 'B09F9YQQ7B', 'product_name': '...  0.319895
# 4  {'product_id': 'B06XGWRKYT', 'product_name': '...  0.272607
# Product name Croma 80 cm (32 Inches) HD Ready LED TV (CREL7369, Black) (2021 Model) not found in recommendations.
# User 4639 has 3 interactions in the test_data.
#                                              Product     Score
# 0  {'product_id': 'B09YLXYP7Y', 'product_name': '...  0.500000
# 1  {'product_id': 'B09ZPL5VYM', 'product_name': '...  0.301768
# 2  {'product_id': 'B07CD2BN46', 'product_name': '...  0.205592
# 3  {'product_id': 'B08Y1TFSP6', 'product_name': '...  0.138868
# 4  {'product_id': 'B098NS6PVG', 'product_name': '...  0.133199
# Product name ZEBRONICS Zeb-100HB 4 Ports USB Hub for Laptop, PC Computers, Plug & Play, Backward Compatible - Black not found in recommendations.
# User 1495 has 2 interactions in the test_data.
#                                              Product     Score
# 0  {'product_id': 'B08YDFX7Y1', 'product_name': '...  0.500000
# 1  {'product_id': 'B01HJI0FS2', 'product_name': '...  0.357469
# 2  {'product_id': 'B00GZLB57U', 'product_name': '...  0.357469
# 3  {'product_id': 'B014SZO90Y', 'product_name': '...  0.357469
# 4  {'product_id': 'B087FXHB6J', 'product_name': '...  0.159448
# User 1315 has 2 interactions in the test_data.
#                                              Product     Score
# 0  {'product_id': 'B0993BB11X', 'product_name': '...  0.752283
# 1  {'product_id': 'B08TDJNM3G', 'product_name': '...  0.500000
# 2  {'product_id': 'B07RD611Z8', 'product_name': '...  0.434368
# 3  {'product_id': 'B072J83V9W', 'product_name': '...  0.434368
# 4  {'product_id': 'B008QTK47Q', 'product_name': '...  0.434368
# User 8923 has 2 interactions in the test_data.
#                                              Product     Score
# 0  {'product_id': 'B0993BB11X', 'product_name': '...  0.500000
# 1  {'product_id': 'B07RD611Z8', 'product_name': '...  0.422038
# 2  {'product_id': 'B085DTN6R2', 'product_name': '...  0.230941
# 3  {'product_id': 'B09TP5KBN7', 'product_name': '...  0.221428
# 4  {'product_id': 'B0B4DT8MKT', 'product_name': '...  0.204082
# Product name E-COSMOS 5V 1.2W Portable Flexible USB LED Light (Colors May Vary, Small) - Set of 2 Pieces not found in recommendations.
# User 2262 has 2 interactions in the test_data.
#                                              Product     Score
# 0  {'product_id': 'B07232M876', 'product_name': '...  0.500000
# 1  {'product_id': 'B00NH11PEY', 'product_name': '...  0.303764
# 2  {'product_id': 'B00GE55L22', 'product_name': '...  0.224009
# 3  {'product_id': 'B008QTK47Q', 'product_name': '...  0.196236
# 4  {'product_id': 'B07VTFN6HM', 'product_name': '...  0.196236
# Product name Storite High Speed Micro USB 3.0 Cable A to Micro B for External & Desktop Hard Drives 45cm not found in recommendations.
# User 7803 has 2 interactions in the test_data.
#                                              Product     Score
# 0  {'product_id': 'B017PDR9N0', 'product_name': '...  0.500000
# 1  {'product_id': 'B0926V9CTV', 'product_name': '...  0.310276
# 2  {'product_id': 'B08LHTJTBB', 'product_name': '...  0.205879
# 3  {'product_id': 'B086394NY5', 'product_name': '...  0.204155
# 4  {'product_id': 'B0BCVJ3PVP', 'product_name': '...  0.140988
# User 6739 has 2 interactions in the test_data.
#                                              Product     Score
# 0  {'product_id': 'B017PDR9N0', 'product_name': '...  0.500000
# 1  {'product_id': 'B0926V9CTV', 'product_name': '...  0.325635
# 2  {'product_id': 'B086394NY5', 'product_name': '...  0.250000
# 3  {'product_id': 'B08LHTJTBB', 'product_name': '...  0.103621
# 4  {'product_id': 'B07Q4QV1DL', 'product_name': '...  0.090506
# Product name Robustrion Anti-Scratch & Smudge Proof Tempered Glass Screen Protector for Xiaomi Mi Pad 5 11 inch not found in recommendations.
# User 8055 has 3 interactions in the test_data.
#                                              Product     Score
# 0  {'product_id': 'B0811VCGL5', 'product_name': '...  0.500000
# 1  {'product_id': 'B09KRHXTLN', 'product_name': '...  0.074656
# 2  {'product_id': 'B09NFSHCWN', 'product_name': '...  0.070970
# 3  {'product_id': 'B097MKZHNV', 'product_name': '...  0.069771
# 4  {'product_id': 'B008LN8KDM', 'product_name': '...  0.068694
# Product name BlueRigger Digital Optical Audio Toslink Cable (3.3 Feet / 1 Meter) With 8 Channel (7.1) Audio Support (for Home Theatre, Xbox, Playstation etc.) not found in recommendations.
# Product name Havells OFR 13 Wave Fin with PTC Fan Heater 2900 Watts (Black) not found in recommendations.
# User 617 has 3 interactions in the test_data.
#                                              Product     Score
# 0  {'product_id': 'B07PFJ5VQD', 'product_name': '...  0.500000
# 1  {'product_id': 'B0BFWGBX61', 'product_name': '...  0.237843
# 2  {'product_id': 'B0B4DT8MKT', 'product_name': '...  0.187186
# 3  {'product_id': 'B09YLXYP7Y', 'product_name': '...  0.181761
# 4  {'product_id': 'B094JNXNPV', 'product_name': '...  0.181761
# Product name Ambrane Unbreakable 60W / 3A Fast Charging 1.5m Braided Type C Cable for Smartphones, Tablets, Laptops & other Type C devices, PD Technology, 480Mbps Data Sync, Quick Charge 3.0 (RCT15A, Black) not found in recommendations.
# Product name Boult Audio BassBuds X1 in-Ear Wired Earphones with 10mm Extra Bass Driver and HD Sound with mic(Black) not found in recommendations.
# User 7164 has 2 interactions in the test_data.
#                                              Product     Score
# 0  {'product_id': 'B078W65FJ7', 'product_name': '...  0.500000
# 1  {'product_id': 'B08MTLLSL8', 'product_name': '...  0.500000
# 2  {'product_id': 'B08CFJBZRK', 'product_name': '...  0.075940
# 3  {'product_id': 'B07KY3FNQP', 'product_name': '...  0.068524
# 4  {'product_id': 'B07TXCY3YK', 'product_name': '...  0.068524
# Product name Bajaj Rex 750W Mixer Grinder with Nutri Pro Feature, 4 Jars, White not found in recommendations.
# User 7313 has 2 interactions in the test_data.
#                                              Product     Score
# 0  {'product_id': 'B07L9FW9GF', 'product_name': '...  0.500000
# 1  {'product_id': 'B098K3H92Z', 'product_name': '...  0.277777
# 2  {'product_id': 'B086Q3QMFS', 'product_name': '...  0.222223
# 3  {'product_id': 'B08CTQP51L', 'product_name': '...  0.222223
# 4  {'product_id': 'B075DB1F13', 'product_name': '...  0.110922
# Product name Duracell Plus AAA Rechargeable Batteries (750 mAh) Pack of 4 not found in recommendations.
# User 6049 has 3 interactions in the test_data.
#                                              Product     Score
# 0  {'product_id': 'B07L9FW9GF', 'product_name': '...  0.500000
# 1  {'product_id': 'B098K3H92Z', 'product_name': '...  0.202576
# 2  {'product_id': 'B00LZLQ624', 'product_name': '...  0.193639
# 3  {'product_id': 'B00P93X6EK', 'product_name': '...  0.193639
# 4  {'product_id': 'B00P93X0VO', 'product_name': '...  0.188697
# Product name Robustrion [Anti-Scratch] & [Smudge Proof] [S Pen Compatible] Premium Tempered Glass Screen Protector for Samsung Tab S6 Lite 10.4 inch SM-P610/615 [Bubble Free] not found in recommendations.
# Product name Classmate Drawing Book - Unruled, 40 Pages, 210 mm x 297 mm - Pack Of 4 not found in recommendations.
# User 235 has 2 interactions in the test_data.
#                                              Product     Score
# 0  {'product_id': 'B087FXHB6J', 'product_name': '...  0.500000
# 1  {'product_id': 'B09NHVCHS9', 'product_name': '...  0.500000
# 2  {'product_id': 'B09ZPL5VYM', 'product_name': '...  0.107667
# 3  {'product_id': 'B01LONQBDG', 'product_name': '...  0.106515
# 4  {'product_id': 'B09PNR6F8Q', 'product_name': '...  0.106515
# Product name Portronics MODESK POR-122 Universal Mobile Tabletop Holder (Black) not found in recommendations.
# User 173 has 2 interactions in the test_data.
#                                              Product     Score
# 0  {'product_id': 'B0148NPH9I', 'product_name': '...  0.500000
# 1  {'product_id': 'B07R99NBVB', 'product_name': '...  0.500000
# 2  {'product_id': 'B00MUTWLW4', 'product_name': '...  0.206395
# 3  {'product_id': 'B00CEQEGPI', 'product_name': '...  0.111409
# 4  {'product_id': 'B087FXHB6J', 'product_name': '...  0.090461
# User 4117 has 2 interactions in the test_data.
#                                              Product     Score
# 0  {'product_id': 'B08WJ86PV2', 'product_name': '...  0.500000
# 1  {'product_id': 'B0819HZPXL', 'product_name': '...  0.500000
# 2  {'product_id': 'B087FXHB6J', 'product_name': '...  0.166231
# 3  {'product_id': 'B08YDFX7Y1', 'product_name': '...  0.158991
# 4  {'product_id': 'B073BRXPZX', 'product_name': '...  0.137176
# Product name Redragon K617 Fizz 60% Wired RGB Gaming Keyboard, 61 Keys Compact Mechanical Keyboard w/White and Grey Color Keycaps, Linear Red Switch, Pro Driver/Software Supported not found in recommendations.
# User 2553 has 2 interactions in the test_data.
#                                              Product     Score
# 0  {'product_id': 'B0B2RBP83P', 'product_name': '...  0.500000
# 1  {'product_id': 'B09XB8GFBQ', 'product_name': '...  0.240932
# 2  {'product_id': 'B09QS8V5N8', 'product_name': '...  0.237850
# 3  {'product_id': 'B09LHYZ3GJ', 'product_name': '...  0.208116
# 4  {'product_id': 'B08VB34KJ1', 'product_name': '...  0.208116
# Product name Redmi 11 Prime 5G (Meadow Green, 4GB RAM 64GB ROM) | Prime Design | MTK Dimensity 700 | 50 MP Dual Cam | 5000mAh | 7 Band 5G not found in recommendations.
# User 5922 has 2 interactions in the test_data.
#                                              Product     Score
# 0  {'product_id': 'B07WKBD37W', 'product_name': '...  0.500000
# 1  {'product_id': 'B00LZLQ624', 'product_name': '...  0.371336
# 2  {'product_id': 'B0819ZZK5K', 'product_name': '...  0.371336
# 3  {'product_id': 'B084PJSSQ1', 'product_name': '...  0.333906
# 4  {'product_id': 'B097C564GC', 'product_name': '...  0.317274
# User 1302 has 2 interactions in the test_data.
#                                              Product     Score
# 0  {'product_id': 'B0819ZZK5K', 'product_name': '...  0.500000
# 1  {'product_id': 'B07WKBD37W', 'product_name': '...  0.500000
# 2  {'product_id': 'B08KDBLMQP', 'product_name': '...  0.104968
# 3  {'product_id': 'B07TXCY3YK', 'product_name': '...  0.101745
# 4  {'product_id': 'B08CFJBZRK', 'product_name': '...  0.101745
# Product name Lifelong LLMG93 500 Watt Duos Mixer Grinder, 2 Stainless Steel Jar (Liquidizing and Chutney Jar)| ABS Body, Stainless Steel Blades, 3 Speed Options with Whip (1 Year Warranty, Black) not found in recommendations.
# User 872 has 2 interactions in the test_data.
#                                              Product     Score
# 0  {'product_id': 'B0148NPH9I', 'product_name': '...  0.500000
# 1  {'product_id': 'B07R99NBVB', 'product_name': '...  0.500000
# 2  {'product_id': 'B09CGLY5CX', 'product_name': '...  0.060515
# 3  {'product_id': 'B09Z6WH2N1', 'product_name': '...  0.060515
# 4  {'product_id': 'B08MTCKDYN', 'product_name': '...  0.055846
# Product name ELV Car Mount Adjustable Car Phone Holder Universal Long Arm, Windshield for Smartphones - Black not found in recommendations.
# User 4502 has 2 interactions in the test_data.
#                                              Product     Score
# 0  {'product_id': 'B017PDR9N0', 'product_name': '...  0.500000
# 1  {'product_id': 'B0926V9CTV', 'product_name': '...  0.500000
# 2  {'product_id': 'B08LHTJTBB', 'product_name': '...  0.140191
# 3  {'product_id': 'B0BCVJ3PVP', 'product_name': '...  0.103106
# 4  {'product_id': 'B09ZPL5VYM', 'product_name': '...  0.098584
# Product name Larrito wooden Cool Mist Humidifiers Essential Oil Diffuser Aroma Air Humidifier with Colorful Change for Car, Office, Babies, humidifiers for home, air humidifier for room (WOODEN HUMIDIFIRE-A) not found in recommendations.
# User 7352 has 2 interactions in the test_data.
#                                              Product     Score
# 0  {'product_id': 'B08H21B6V7', 'product_name': '...  0.500000
# 1  {'product_id': 'B08KDBLMQP', 'product_name': '...  0.086828
# 2  {'product_id': 'B07TXCY3YK', 'product_name': '...  0.086828
# 3  {'product_id': 'B0B9RZ4G4W', 'product_name': '...  0.085732
# 4  {'product_id': 'B0BD3T6Z1D', 'product_name': '...  0.083551
# Product name TTK Prestige Limited Orion Mixer Grinder 500 Watts, 3 Jars (1200ml, 1000ml, 500ml) (Red) not found in recommendations.
# User 5084 has 2 interactions in the test_data.
#                                              Product     Score
# 0  {'product_id': 'B0B9RZ4G4W', 'product_name': '...  0.500000
# ...
# 2  {'product_id': 'B01LONQBDG', 'product_name': '...  0.287531
# 3  {'product_id': 'B097C564GC', 'product_name': '...  0.141407
# 4  {'product_id': 'B09YLXYP7Y', 'product_name': '...  0.139057
# Product name AmazonBasics USB Type-C to USB Type-C 2.0 Cable - 3 Feet Laptop (0.9 Meters) - White not found in recommendations.
# User 7330 has 3 interactions in the test_data.
#                                              Product     Score
# 0  {'product_id': 'B09JPC82QC', 'product_name': '...  0.500000
# 1  {'product_id': 'B09F9YQQ7B', 'product_name': '...  0.215335
# 2  {'product_id': 'B008QTK47Q', 'product_name': '...  0.205140
# 3  {'product_id': 'B07VTFN6HM', 'product_name': '...  0.205140
# 4  {'product_id': 'B07232M876', 'product_name': '...  0.205140
# Product name Boya ByM1 Auxiliary Omnidirectional Lavalier Condenser Microphone with 20ft Audio Cable (Black) not found in recommendations.
# Product name Sennheiser CX 80S in-Ear Wired Headphones with in-line One-Button Smart Remote with Microphone Black not found in recommendations.
# User 5454 has 2 interactions in the test_data.
#                                              Product     Score
# 0  {'product_id': 'B09NVPSCQT', 'product_name': '...  0.500000
# 1  {'product_id': 'B07G3YNLJB', 'product_name': '...  0.339620
# 2  {'product_id': 'B01LONQBDG', 'product_name': '...  0.339620
# 3  {'product_id': 'B098K3H92Z', 'product_name': '...  0.339620
# 4  {'product_id': 'B09PLFJ7ZW', 'product_name': '...  0.176334
# User 7871 has 2 interactions in the test_data.
#                                              Product     Score
# 0  {'product_id': 'B008YW8M0G', 'product_name': '...  0.500000
# 1  {'product_id': 'B008QTK47Q', 'product_name': '...  0.231014
# 2  {'product_id': 'B07VTFN6HM', 'product_name': '...  0.231014
# 3  {'product_id': 'B07232M876', 'product_name': '...  0.231014
# 4  {'product_id': 'B01N6LU1VF', 'product_name': '...  0.231014
# User 6255 has 2 interactions in the test_data.
#                                              Product     Score
# 0  {'product_id': 'B08H21B6V7', 'product_name': '...  0.500000
# 1  {'product_id': 'B0BD3T6Z1D', 'product_name': '...  0.059604
# 2  {'product_id': 'B07L9FW9GF', 'product_name': '...  0.058793
# 3  {'product_id': 'B08FTFXNNB', 'product_name': '...  0.056829
# 4  {'product_id': 'B09QS8V5N8', 'product_name': '...  0.056007
# Product name TATA SKY HD Connection with 1 month basic package and free installation not found in recommendations.
# User 2367 has 2 interactions in the test_data.
#                                              Product     Score
# 0  {'product_id': 'B01M4GGIVU', 'product_name': '...  0.500000
# 1  {'product_id': 'B00LZLPYHW', 'product_name': '...  0.350054
# 2  {'product_id': 'B00P93X6EK', 'product_name': '...  0.350054
# 3  {'product_id': 'B00P93X0VO', 'product_name': '...  0.329141
# 4  {'product_id': 'B06XR9PR5X', 'product_name': '...  0.313951
# Product name Classmate Soft Cover 6 Subject Spiral Binding Notebook, Single Line, 300 Pages not found in recommendations.
# User 2219 has 2 interactions in the test_data.
#                                              Product     Score
# 0  {'product_id': 'B01M4GGIVU', 'product_name': '...  0.500000
# 1  {'product_id': 'B00LZLQ624', 'product_name': '...  0.500000
# 2  {'product_id': 'B0819ZZK5K', 'product_name': '...  0.478517
# 3  {'product_id': 'B07WKBD37W', 'product_name': '...  0.478517
# 4  {'product_id': 'B00LZLPYHW', 'product_name': '...  0.334861
# User 3296 has 2 interactions in the test_data.
#                                              Product     Score
# 0  {'product_id': 'B08YDFX7Y1', 'product_name': '...  0.500000
# 1  {'product_id': 'B00GZLB57U', 'product_name': '...  0.500000
# 2  {'product_id': 'B087FXHB6J', 'product_name': '...  0.158961
# 3  {'product_id': 'B08Y7MXFMK', 'product_name': '...  0.146337
# 4  {'product_id': 'B0819HZPXL', 'product_name': '...  0.143148
# Product name Amozo Ultra Hybrid Camera and Drop Protection Back Cover Case for iPhone 13 (TPU + Polycarbonate | Crystal Transparent) not found in recommendations.
# User 5013 has 2 interactions in the test_data.
#                                              Product     Score
# 0  {'product_id': 'B01HJI0FS2', 'product_name': '...  0.500000
# 1  {'product_id': 'B00GZLB57U', 'product_name': '...  0.183870
# 2  {'product_id': 'B014SZO90Y', 'product_name': '...  0.183870
# 3  {'product_id': 'B08JW1GVS7', 'product_name': '...  0.108558
# 4  {'product_id': 'B098NS6PVG', 'product_name': '...  0.108558
# Product name MI Xiaomi 22.5W Fast USB Type C Charger Combo for Tablets - White not found in recommendations.
# User 6997 has 2 interactions in the test_data.
#                                              Product     Score
# 0  {'product_id': 'B00LUGTJGO', 'product_name': '...  0.500000
# 1  {'product_id': 'B009P2LK08', 'product_name': '...  0.186059
# 2  {'product_id': 'B09B125CFJ', 'product_name': '...  0.115240
# 3  {'product_id': 'B099FDW2ZF', 'product_name': '...  0.102112
# 4  {'product_id': 'B08YXJJW8H', 'product_name': '...  0.102112
# Product name Electvision Remote Control Compatible with Kodak/Thomson Smart led tv (Without Voice) Before Placing Order for verification Contact Our coustmer Care 7738090464 not found in recommendations.
# User 6815 has 2 interactions in the test_data.
#                                              Product     Score
# 0  {'product_id': 'B005LJQMCK', 'product_name': '...  0.500000
# 1  {'product_id': 'B08MZNT7GP', 'product_name': '...  0.500000
# 2  {'product_id': 'B0811VCGL5', 'product_name': '...  0.500000
# 3  {'product_id': 'B07W9KYT62', 'product_name': '...  0.054224
# 4  {'product_id': 'B01I1LDZGA', 'product_name': '...  0.053674
# Product name APC Back-UPS BX600C-IN 600VA / 360W, 230V, UPS System, an Ideal Power Backup & Protection for Home Office, Desktop PC & Home Electronics not found in recommendations.
# User 5123 has 2 interactions in the test_data.
#                                              Product     Score
# 0  {'product_id': 'B07G3YNLJB', 'product_name': '...  0.500000
# 1  {'product_id': 'B09NVPSCQT', 'product_name': '...  0.500000
# 2  {'product_id': 'B09PLFJ7ZW', 'product_name': '...  0.190675
# 3  {'product_id': 'B0B5B6PQCT', 'product_name': '...  0.144983
# 4  {'product_id': 'B097R25DP7', 'product_name': '...  0.144983
# Product name Noise Buds VS402 Truly Wireless in Ear Earbuds, 35-Hours of Playtime, Instacharge, Quad Mic with ENC, Hyper Sync, Low Latency, 10mm Driver, Bluetooth v5.3 and Breathing LED Lights (Neon Black) not found in recommendations.
# User 8852 has 2 interactions in the test_data.
#                                              Product     Score
# 0  {'product_id': 'B084PJSSQ1', 'product_name': '...  0.500000
# 1  {'product_id': 'B0819ZZK5K', 'product_name': '...  0.325923
# 2  {'product_id': 'B09XB8GFBQ', 'product_name': '...  0.265105
# 3  {'product_id': 'B0BBFJ9M3X', 'product_name': '...  0.232659
# 4  {'product_id': 'B09GFPVD9Y', 'product_name': '...  0.220449
# Product name Redmi Note 11 (Space Black, 4GB RAM, 64GB Storage)|90Hz FHD+ AMOLED Display | Qualcomm® Snapdragon™ 680-6nm | 33W Charger Included not found in recommendations.
# User 4514 has 2 interactions in the test_data.
#                                              Product  Score
# 0  {'product_id': 'B083T5G5PM', 'product_name': '...    0.5
# 1  {'product_id': 'B008QTK47Q', 'product_name': '...    0.5
# 2  {'product_id': 'B07VTFN6HM', 'product_name': '...    0.5
# 3  {'product_id': 'B07232M876', 'product_name': '...    0.5
# 4  {'product_id': 'B01N6LU1VF', 'product_name': '...    0.5
# Product name Crucial RAM 8GB DDR4 3200MHz CL22 (or 2933MHz or 2666MHz) Laptop Memory CT8G4SFRA32A not found in recommendations.
# User 155 has 2 interactions in the test_data.
#                                              Product     Score
# 0  {'product_id': 'B09LMMFW3S', 'product_name': '...  0.500000
# 1  {'product_id': 'B09LHYZ3GJ', 'product_name': '...  0.120991
# 2  {'product_id': 'B09FKDH6FS', 'product_name': '...  0.116718
# 3  {'product_id': 'B09QS8V5N8', 'product_name': '...  0.101490
# 4  {'product_id': 'B0BD3T6Z1D', 'product_name': '...  0.098530
# Product name realme narzo 50 (Speed Blue, 4GB RAM+64GB Storage) Helio G96 Processor | 50MP AI Triple Camera | 120Hz Ultra Smooth Display not found in recommendations.
# User 8437 has 2 interactions in the test_data.
#                                              Product     Score
# 0  {'product_id': 'B07Z53L5QL', 'product_name': '...  0.500000
# 1  {'product_id': 'B08KRMK9LZ', 'product_name': '...  0.101627
# 2  {'product_id': 'B08CF3B7N1', 'product_name': '...  0.101627
# 3  {'product_id': 'B078W65FJ7', 'product_name': '...  0.094304
# 4  {'product_id': 'B07JF9B592', 'product_name': '...  0.089327
# Product name Logitech H111 Wired On Ear Headphones With Mic Black not found in recommendations.
# User 8376 has 2 interactions in the test_data.
#                                              Product     Score
# 0  {'product_id': 'B0B5B6PQCT', 'product_name': '...  0.500000
# 1  {'product_id': 'B0949SBKMP', 'product_name': '...  0.116084
# 2  {'product_id': 'B0BNXFDTZ2', 'product_name': '...  0.113342
# 3  {'product_id': 'B09NVPSCQT', 'product_name': '...  0.107709
# 4  {'product_id': 'B0B5LVS732', 'product_name': '...  0.105578
# Product name Cubetek 3 in 1 LCD Display V5.0 Bluetooth Transmitter Receiver, Bypass Audio Adapter with Aux, Optical, Dual Link Support for TV, Home Stereo, PC, Headphones, Speakers, Model: CB-BT27 not found in recommendations.
# User 5210 has 2 interactions in the test_data.
#                                              Product     Score
# 0  {'product_id': 'B0B5B6PQCT', 'product_name': '...  0.500000
# 1  {'product_id': 'B08MVXPTDG', 'product_name': '...  0.122787
# 2  {'product_id': 'B09CGLY5CX', 'product_name': '...  0.108109
# 3  {'product_id': 'B09NFSHCWN', 'product_name': '...  0.100378
# 4  {'product_id': 'B0BMTZ4T1D', 'product_name': '...  0.094079
# Product name Candes Gloster All in One Silent Blower Fan Room Heater Ideal for Small and Medium Area, 2000 Watts (White) not found in recommendations.
# User 8688 has 2 interactions in the test_data.
#                                              Product     Score
# 0  {'product_id': 'B07YL54NVJ', 'product_name': '...  0.500000
# 1  {'product_id': 'B08GYG6T12', 'product_name': '...  0.162533
# 2  {'product_id': 'B097C564GC', 'product_name': '...  0.135461
# 3  {'product_id': 'B07DJLFMPS', 'product_name': '...  0.090303
# 4  {'product_id': 'B07GVGTSLN', 'product_name': '...  0.089648
# Product name SanDisk Extreme SD UHS I 64GB Card for 4K Video for DSLR and Mirrorless Cameras 170MB/s Read & 80MB/s Write not found in recommendations.
# User 2868 has 2 interactions in the test_data.
#                                              Product     Score
# 0  {'product_id': 'B07RZZ1QSW', 'product_name': '...  0.581672
# 1  {'product_id': 'B074CWD7MS', 'product_name': '...  0.500000
# 2  {'product_id': 'B08HD7JQHX', 'product_name': '...  0.138022
# 3  {'product_id': 'B07N42JB4S', 'product_name': '...  0.092436
# 4  {'product_id': 'B00Y4ORQ46', 'product_name': '...  0.085503
# Product name MAONO AU-400 Lavalier Auxiliary Omnidirectional Microphone (Black) not found in recommendations.
# User 437 has 2 interactions in the test_data.
#                                              Product     Score
# 0  {'product_id': 'B07RZZ1QSW', 'product_name': '...  0.500000
# 1  {'product_id': 'B074CWD7MS', 'product_name': '...  0.500000
# 2  {'product_id': 'B0B9BXKBC7', 'product_name': '...  0.154031
# 3  {'product_id': 'B0B2DJ5RVQ', 'product_name': '...  0.131206
# 4  {'product_id': 'B07N42JB4S', 'product_name': '...  0.118789
# User 7715 has 2 interactions in the test_data.
#                                              Product     Score
# 0  {'product_id': 'B07RZZ1QSW', 'product_name': '...  0.500000
# 1  {'product_id': 'B074CWD7MS', 'product_name': '...  0.500000
# 2  {'product_id': 'B0B2DJ5RVQ', 'product_name': '...  0.148415
# 3  {'product_id': 'B0B9BXKBC7', 'product_name': '...  0.136237
# 4  {'product_id': 'B07GNC2592', 'product_name': '...  0.087957
# Product name PrettyKrafts Laundry Basket for clothes with Lid & Handles, Toys Organiser, 75 Ltr Grey not found in recommendations.
# User 4782 has 2 interactions in the test_data.
#                                              Product     Score
# 0  {'product_id': 'B09NHVCHS9', 'product_name': '...  0.500000
# 1  {'product_id': 'B087FXHB6J', 'product_name': '...  0.437500
# 2  {'product_id': 'B08YDFX7Y1', 'product_name': '...  0.160125
# 3  {'product_id': 'B08Y7MXFMK', 'product_name': '...  0.152799
# 4  {'product_id': 'B073BRXPZX', 'product_name': '...  0.149615
# User 2392 has 2 interactions in the test_data.
#                                              Product     Score
# 0  {'product_id': 'B01N6LU1VF', 'product_name': '...  0.500000
# 1  {'product_id': 'B008YW8M0G', 'product_name': '...  0.500000
# 2  {'product_id': 'B099Z83VRC', 'product_name': '...  0.204797
# 3  {'product_id': 'B00F159RIK', 'product_name': '...  0.184258
# 4  {'product_id': 'B08MV82R99', 'product_name': '...  0.074489
# Product name GILTON Egg Boiler Electric Automatic Off 7 Egg Poacher for Steaming, Cooking Also Boiling and Frying, Multi Color not found in recommendations.
# User 4509 has 2 interactions in the test_data.
#                                              Product     Score
# 0  {'product_id': 'B087FXHB6J', 'product_name': '...  0.500000
# 1  {'product_id': 'B09NHVCHS9', 'product_name': '...  0.500000
# 2  {'product_id': 'B08YDFX7Y1', 'product_name': '...  0.162147
# 3  {'product_id': 'B08Y7MXFMK', 'product_name': '...  0.156036
# 4  {'product_id': 'B07L9FW9GF', 'product_name': '...  0.133694
# Product name Myvn 30W Warp/20W Dash Charging Usb Type C Charger Cable Compatible For Cellular Phones Oneplus 8T 8 8Pro 7 Pro / 7T / 7T Pro Nord And Oneplus 3 / 3T / 5 / 5T / 6 / 6T / 7 not found in recommendations.
# User 3040 has 2 interactions in the test_data.
#                                              Product     Score
# 0  {'product_id': 'B09YLXYP7Y', 'product_name': '...  0.500000
# 1  {'product_id': 'B07CD2BN46', 'product_name': '...  0.271740
# 2  {'product_id': 'B07GLNJC25', 'product_name': '...  0.228260
# 3  {'product_id': 'B09ZPL5VYM', 'product_name': '...  0.228260
# 4  {'product_id': 'B08Y1TFSP6', 'product_name': '...  0.134303
# Product name HP 32GB Class 10 MicroSD Memory Card (U1 TF Card 32GB) not found in recommendations.
# User 7024 has 2 interactions in the test_data.
#                                              Product     Score
# 0  {'product_id': 'B084PJSSQ1', 'product_name': '...  0.500000
# 1  {'product_id': 'B0819ZZK5K', 'product_name': '...  0.330820
# 2  {'product_id': 'B09JPC82QC', 'product_name': '...  0.281609
# 3  {'product_id': 'B06XGWRKYT', 'product_name': '...  0.243566
# 4  {'product_id': 'B08CS3BT4L', 'product_name': '...  0.243014
# Product name Redmi 80 cm (32 inches) Android 11 Series HD Ready Smart LED TV | L32M6-RA/L32M7-RA (Black) not found in recommendations.
# User 6944 has 2 interactions in the test_data.
#                                              Product     Score
# 0  {'product_id': 'B01HJI0FS2', 'product_name': '...  0.500000
# 1  {'product_id': 'B07W14CHV8', 'product_name': '...  0.285486
# 2  {'product_id': 'B014SZO90Y', 'product_name': '...  0.183870
# 3  {'product_id': 'B00GZLB57U', 'product_name': '...  0.183870
# 4  {'product_id': 'B0BG62HMDJ', 'product_name': '...  0.127795
# Product name Lapster Caddy for ssd and HDD, Optical Bay 2nd Hard Drive Caddy, Caddy 9.5mm for Laptop not found in recommendations.
# User 7095 has 2 interactions in the test_data.
#                                              Product     Score
# 0  {'product_id': 'B0949SBKMP', 'product_name': '...  0.500000
# 1  {'product_id': 'B07CD2BN46', 'product_name': '...  0.500000
# 2  {'product_id': 'B0B5B6PQCT', 'product_name': '...  0.124857
# 3  {'product_id': 'B097R25DP7', 'product_name': '...  0.124857
# 4  {'product_id': 'B0B5LVS732', 'product_name': '...  0.124857
# Product name GIZGA Club-laptop Neoprene Reversible for 15.6-inches Laptop Sleeve - Black-Red not found in recommendations.
# Length of actual scores: 153
# Length of predicted scores: 153
# Precision for Hybrid System: 0.24958677685950414
# Recall for Hybrid System: 0.5592592592592592
# RMSE for Hybrid System: 3.712298909955772

# %%
print(test.columns)


def precision_at_k(r, k):
    """Return precision at k for a single user's recommendations.
    
    r: list of relevance values. E.g., [0, 1, 1, 0, 1]
    """
    assert k >= 1
    r = np.asarray(r)[:k]
    return np.mean(r)

def average_precision_at_k(r, k):
    """Return average precision at k for a single user's recommendations."""
    r = np.asarray(r)[:k]
    out = [precision_at_k(r, j + 1) for j, rel in enumerate(r) if rel]
    if not out:
        return 0
    return np.mean(out)

def mean_average_precision_at_k(rs, k):
    """Calculate MAP@K over all users (rs: list of lists of relevance values)."""
    return np.mean([average_precision_at_k(r, k) for r in rs])

def ndcg_at_k(r, k):
    """Compute NDCG@K for a single user's ranking."""
    r = np.asarray(r)[:k]
    dcg = np.sum(r / np.log2(np.arange(2, len(r) + 2)))
    idcg = np.sum(np.ones_like(r) / np.log2(np.arange(2, len(r) + 2)))
    return dcg / idcg

# For each user in your test set:
# 1. Get the top-K recommended items' ids.
# 2. Determine the relevance of these items based on true interactions/ratings.
# 3. Calculate MAP@K and NDCG@K

all_users_relevance = []  # List of lists. Each inner list is the relevance values for one user's recommendations.

for user in test:
    # Assuming you've generated top-K recommendations for this user:
    recommended_items = hybrid_recommendation_v2(user) # Replace with your hybrid recommender's function
    print(recommended_items.columns)
    true_relevant_items = test.get(user, [])
    
    # Generate binary relevance values. 1 if the item was truly relevant, 0 otherwise.
    relevance = [1 if item in true_relevant_items else 0 for item in recommended_items]
    all_users_relevance.append(relevance)

# Calculate MAP@K and NDCG@K
k = 10  # or any other value you're interested in
print("MAP@K:", mean_average_precision_at_k(all_users_relevance, k))
print("NDCG@K:", np.mean([ndcg_at_k(r, k) for r in all_users_relevance]))
# Out:
# Index(['review_id', 'user_id', 'product_id', 'review_title', 'review_content',
#        'product_name', 'category', 'discounted_price', 'actual_price',
#        'discount_percentage', 'rating', 'rating_count', 'about_product',
#        'img_link', 'product_link', 'user_name', 'password', 'user_id_encoded'],
#       dtype='object')
# Error: user_id_encoded review_id not found in index.
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Python311\Lib\site-packages\pandas\core\indexes\base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File c:\Python311\Lib\site-packages\pandas\_libs\index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\Python311\Lib\site-packages\pandas\_libs\index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'score_recommendation'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# c:\Users\swapn\Desktop\Final eval\hybrid for eval.ipynb Cell 16 line 4
#      <a href='vscode-notebook-cell:/c%3A/Users/swapn/Desktop/Final%20eval/hybrid%20for%20eval.ipynb#X21sZmlsZQ%3D%3D?line=36'>37</a> all_users_relevance = []  # List of lists. Each inner list is the relevance values for one user's recommendations.
#      <a href='vscode-notebook-cell:/c%3A/Users/swapn/Desktop/Final%20eval/hybrid%20for%20eval.ipynb#X21sZmlsZQ%3D%3D?line=38'>39</a> for user in test:
#      <a href='vscode-notebook-cell:/c%3A/Users/swapn/Desktop/Final%20eval/hybrid%20for%20eval.ipynb#X21sZmlsZQ%3D%3D?line=39'>40</a>     # Assuming you've generated top-K recommendations for this user:
# ---> <a href='vscode-notebook-cell:/c%3A/Users/swapn/Desktop/Final%20eval/hybrid%20for%20eval.ipynb#X21sZmlsZQ%3D%3D?line=40'>41</a>     recommended_items = hybrid_recommendation_v2(user) # Replace with your hybrid recommender's function
#      <a href='vscode-notebook-cell:/c%3A/Users/swapn/Desktop/Final%20eval/hybrid%20for%20eval.ipynb#X21sZmlsZQ%3D%3D?line=41'>42</a>     print(recommended_items.columns)
#      <a href='vscode-notebook-cell:/c%3A/Users/swapn/Desktop/Final%20eval/hybrid%20for%20eval.ipynb#X21sZmlsZQ%3D%3D?line=42'>43</a>     true_relevant_items = test.get(user, [])
#
# c:\Users\swapn\Desktop\Final eval\hybrid for eval.ipynb Cell 16 line 7
#       <a href='vscode-notebook-cell:/c%3A/Users/swapn/Desktop/Final%20eval/hybrid%20for%20eval.ipynb#X21sZmlsZQ%3D%3D?line=3'>4</a> collaborative_recommendations = get_recommendations(user_id_encoded)[:N]
#       <a href='vscode-notebook-cell:/c%3A/Users/swapn/Desktop/Final%20eval/hybrid%20for%20eval.ipynb#X21sZmlsZQ%3D%3D?line=5'>6</a> # Normalize scores for collaborative recommendations using Min-Max scaling
# ----> <a href='vscode-notebook-cell:/c%3A/Users/swapn/Desktop/Final%20eval/hybrid%20for%20eval.ipynb#X21sZmlsZQ%3D%3D?line=6'>7</a> max_collab_score = collaborative_recommendations['score_recommendation'].max()
#       <a href='vscode-notebook-cell:/c%3A/Users/swapn/Desktop/Final%20eval/hybrid%20for%20eval.ipynb#X21sZmlsZQ%3D%3D?line=7'>8</a> collaborative_recommendations['normalized_score'] = collaborative_recommendations['score_recommendation'] / max_collab_score
#      <a href='vscode-notebook-cell:/c%3A/Users/swapn/Desktop/Final%20eval/hybrid%20for%20eval.ipynb#X21sZmlsZQ%3D%3D?line=9'>10</a> # Create a dictionary for both content and collab recommendations for O(1) access
#
# File c:\Python311\Lib\site-packages\pandas\core\frame.py:3761, in DataFrame.__getitem__(self, key)
#    3759 if self.columns.nlevels > 1:
#    3760     return self._getitem_multilevel(key)
# -> 3761 indexer = self.columns.get_loc(key)
#    3762 if is_integer(indexer):
#    3763     indexer = [indexer]
#
# File c:\Python311\Lib\site-packages\pandas\core\indexes\base.py:3655, in Index.get_loc(self, key)
#    3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
# -> 3655     raise KeyError(key) from err
#    3656 except TypeError:
#    3657     # If we have a listlike key, _check_indexing_error will raise
#    3658     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3659     #  the TypeError.
#    3660     self._check_indexing_error(key)
#
# KeyError: 'score_recommendation'
